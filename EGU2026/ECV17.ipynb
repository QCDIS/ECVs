# %%
# !pip install beacon-api --upgrade
# !pip install contextily
# Out:
# Collecting beacon-api
#   Using cached beacon_api-1.2.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: requests>=2.0.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (2.33.1)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (3.0.2)
# Requirement already satisfied: pyarrow!=19.0.0,>=17.0.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (21.0.0)
# Requirement already satisfied: xarray>=2023.1.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (2025.9.0)
# Requirement already satisfied: fsspec>=2023.1.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (2026.3.0)
# Requirement already satisfied: dask>=2023.1.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (2026.3.0)
# Collecting zarr>=2.18 (from beacon-api)
#   Downloading zarr-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: networkx>=3.0.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (3.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (3.10.9)
# Requirement already satisfied: netCDF4>=1.5.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (1.7.4)
# Requirement already satisfied: typing_extensions>=4.10.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (4.15.0)
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (2.4.3)
# Collecting geopandas>=1.1.0 (from beacon-api)
#   Using cached geopandas-1.1.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: deprecated>=1.2.14 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from beacon-api) (1.3.1)
# Requirement already satisfied: click>=8.1 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from dask>=2023.1.0->beacon-api) (8.3.3)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from dask>=2023.1.0->beacon-api) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from dask>=2023.1.0->beacon-api) (26.2)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from dask>=2023.1.0->beacon-api) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from dask>=2023.1.0->beacon-api) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from dask>=2023.1.0->beacon-api) (1.1.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from deprecated>=1.2.14->beacon-api) (2.1.2)
# Collecting pyogrio>=0.7.2 (from geopandas>=1.1.0->beacon-api)
#   Using cached pyogrio-0.12.1-cp314-cp314-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Requirement already satisfied: pyproj>=3.5.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from geopandas>=1.1.0->beacon-api) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from geopandas>=1.1.0->beacon-api) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib>=3.0.0->beacon-api) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib>=3.0.0->beacon-api) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib>=3.0.0->beacon-api) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib>=3.0.0->beacon-api) (1.5.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib>=3.0.0->beacon-api) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib>=3.0.0->beacon-api) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib>=3.0.0->beacon-api) (2.9.0.post0)
# Requirement already satisfied: cftime in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from netCDF4>=1.5.0->beacon-api) (1.6.5)
# Requirement already satisfied: certifi in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from netCDF4>=1.5.0->beacon-api) (2026.4.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests>=2.0.0->beacon-api) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests>=2.0.0->beacon-api) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests>=2.0.0->beacon-api) (2.5.0)
# Collecting donfig>=0.8 (from zarr>=2.18->beacon-api)
#   Using cached donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting google-crc32c>=1.5 (from zarr>=2.18->beacon-api)
#   Using cached google_crc32c-1.8.0-cp314-cp314-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (1.7 kB)
# Collecting numcodecs>=0.14 (from zarr>=2.18->beacon-api)
#   Using cached numcodecs-0.16.5-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: locket in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from partd>=1.4.0->dask>=2023.1.0->beacon-api) (1.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->beacon-api) (1.17.0)
# Using cached beacon_api-1.2.1-py3-none-any.whl (30 kB)
# Using cached geopandas-1.1.3-py3-none-any.whl (342 kB)
# Downloading zarr-3.2.0-py3-none-any.whl (318 kB)
# Using cached donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Using cached google_crc32c-1.8.0-cp314-cp314-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (33 kB)
# Using cached numcodecs-0.16.5-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
# Using cached pyogrio-0.12.1-cp314-cp314-manylinux_2_28_x86_64.whl (32.5 MB)
# Installing collected packages: pyogrio, numcodecs, google-crc32c, donfig, zarr, geopandas, beacon-api
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 0.14.4
#     Uninstalling geopandas-0.14.4:
#       Successfully uninstalled geopandas-0.14.4
# Successfully installed beacon-api-1.2.1 donfig-0.8.1.post1 geopandas-1.1.3 google-crc32c-1.8.0 numcodecs-0.16.5 pyogrio-0.12.1 zarr-3.2.0
# Requirement already satisfied: contextily in /opt/conda/envs/ecvs/lib/python3.14/site-packages (1.7.0)
# Requirement already satisfied: geopy in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from contextily) (3.10.9)
# Requirement already satisfied: mercantile in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from contextily) (12.2.0)
# Requirement already satisfied: rasterio in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from contextily) (1.4.3)
# Requirement already satisfied: requests in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from contextily) (2.33.1)
# Requirement already satisfied: joblib in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from contextily) (1.5.3)
# Requirement already satisfied: xyzservices in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from contextily) (2026.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from geopy->contextily) (2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib->contextily) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib->contextily) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib->contextily) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib->contextily) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib->contextily) (26.2)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib->contextily) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: click>=3.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from mercantile->contextily) (8.3.3)
# Requirement already satisfied: affine in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from rasterio->contextily) (26.1.0)
# Requirement already satisfied: certifi in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from rasterio->contextily) (2026.4.22)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from rasterio->contextily) (1.1.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests->contextily) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests->contextily) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests->contextily) (2.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.17.0)

# %%
from beacon_api import *
import requests
import pandas as pd
import matplotlib.pyplot as plt
import contextily as ctx

# %%
exv_variable = "EXV017"
region = (-10, 45, 30, 60)            # lon_min, lon_max, lat_min, lat_max 
time = ("2020-01-01", "2020-12-31")   # date_min, date_max
depth = (0, 10)                      # depth below the sea level

# %%
BEACON_TOKEN = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczpcL1wvZGF0YS5ibHVlLWNsb3VkLm9yZyIsImF1ZCI6Imh0dHBzOlwvXC9kYXRhLmJsdWUtY2xvdWQub3JnIiwiaWF0IjoxNzU1MTgxNjYzLCJleHAiOjE3ODY3MTc2NjMsInVzciI6MzIsImlkIjoicGF1bEBtYXJpcy5ubCIsImVwX29yZ2FuaXNhdGlvbiI6IkVudnJpLUh1YiBOZXh0In0.Rtk1moa6N9TsRGV6hhPveb4tOQROoh_DxE7CKdQkEkY"
ICOS_client = Client("https://beacon-iriscc.maris.nl")
argo_client = Client("https://beacon-argo.maris.nl", jwt_token=BEACON_TOKEN)
CDI_client = Client("https://beacon-cdi.maris.nl", jwt_token=BEACON_TOKEN)
# Out:
# Connected to: https://beacon-iriscc.maris.nl/ server successfully
# Beacon Version: 1.5.4
# Connected to: https://beacon-argo.maris.nl/ server successfully
# Beacon Version: 1.5.4
# Connected to: https://beacon-cdi.maris.nl/ server successfully
# Beacon Version: 1.5.4

# %%
tables_CDI = CDI_client.list_tables()

df_CDI = (
        tables_CDI["default"]
        .query()
        .add_select_column("LONGITUDE")
        .add_select_column("LATITUDE")
        .add_select_column("TIME")
        .add_select_coalesced(['DEPTH', 'PRES'], "DEPTH")
        .add_select_column("SDN_STATION")
        .add_select_column("SDN_EDMO_CODE")
        .add_select_column("SDN_LOCAL_CDI_ID")
        .add_select_column("subsurface_temperature", exv_variable)
        .add_range_filter("TIME", time[0], time[1])
        .add_range_filter("DEPTH", depth[0], depth[1])
        .add_range_filter("LONGITUDE", region[0], region[1])
        .add_range_filter("LATITUDE", region[2], region[3])
        .add_is_not_null_filter(exv_variable)
        .to_pandas_dataframe()
    )

df_CDI['RI'] = "CDI"
df_CDI
# Out:
# Creating JSONQuery with from: FromTable(table='default')
# Running query: {"output": {"format": "parquet"}, "select": [{"column": "LONGITUDE", "alias": null}, {"column": "LATITUDE", "alias": null}, {"column": "TIME", "alias": null}, {"function": "coalesce", "args": [{"column": "DEPTH", "alias": null}, {"column": "PRES", "alias": null}], "alias": "DEPTH"}, {"column": "SDN_STATION", "alias": null}, {"column": "SDN_EDMO_CODE", "alias": null}, {"column": "SDN_LOCAL_CDI_ID", "alias": null}, {"column": "subsurface_temperature", "alias": "EXV017"}], "filters": [{"column": "TIME", "gt_eq": "2020-01-01", "lt_eq": "2020-12-31"}, {"column": "DEPTH", "gt_eq": 0, "lt_eq": 10}, {"column": "LONGITUDE", "gt_eq": -10, "lt_eq": 45}, {"column": "LATITUDE", "gt_eq": 30, "lt_eq": 60}, {"is_not_null": {"column": "EXV017"}}], "distinct": null, "sort_by": null, "limit": null, "offset": null, "from": "default"}
#          LONGITUDE   LATITUDE                    TIME  DEPTH      SDN_STATION  \
# 0        -4.262357  48.268628 2020-01-14 22:26:59.999  1.500  18038065_PCh_SD
# 1        -4.262357  48.268628 2020-02-21 01:33:00.000  1.500  18038065_PCh_SD
# 2        -4.262357  48.268628 2020-03-03 00:13:00.000  1.500  18038065_PCh_SD
# 3        -4.262357  48.268628 2020-05-27 23:28:59.999  1.500  18038065_PCh_SD
# 4        -4.262357  48.268628 2020-06-12 23:25:00.000  1.500  18038065_PCh_SD
# ...            ...        ...                     ...    ...              ...
# 1479792   7.799930  43.416740 2020-09-27 12:29:10.000  4.030      7900563_8_A
# 1479793   7.799930  43.416740 2020-09-27 12:29:10.000  5.965      7900563_8_A
# 1479794   7.799930  43.416740 2020-09-27 12:29:10.000  6.040      7900563_8_A
# 1479795   7.799930  43.416740 2020-09-27 12:29:10.000  8.050      7900563_8_A
# 1479796   7.799930  43.416740 2020-09-27 12:29:10.000  9.325      7900563_8_A
#
#          SDN_EDMO_CODE  SDN_LOCAL_CDI_ID  EXV017   RI
# 0                  486   18038065_PCh_SD   8.140  CDI
# 1                  486   18038065_PCh_SD   7.280  CDI
# 2                  486   18038065_PCh_SD   6.660  CDI
# 3                  486   18038065_PCh_SD  15.970  CDI
# 4                  486   18038065_PCh_SD  14.750  CDI
# ...                ...               ...     ...  ...
# 1479792            486  ARGO_7900563_8_A  21.030  CDI
# 1479793            486  ARGO_7900563_8_A  21.031  CDI
# 1479794            486  ARGO_7900563_8_A  21.031  CDI
# 1479795            486  ARGO_7900563_8_A  21.031  CDI
# 1479796            486  ARGO_7900563_8_A  21.032  CDI
#
# [1479797 rows x 9 columns]

# %%
datasets_ICOS = ICOS_client.list_datasets()

df_ICOS = (
        datasets_ICOS['icos/icos.bbf']
        .query()
        .add_select_column("Latitude", "LATITUDE")
        .add_select_column("Longitude", "LONGITUDE")
        .add_select_column("Depth [m]", "DEPTH")
        .add_select_column("Temp [degC]", "EXV017")
        .add_select_column("Date/Time", "TIME")
        .add_range_filter("LONGITUDE", region[0], region[1])
        .add_range_filter("LATITUDE", region[2], region[3])
        .add_range_filter("TIME", time[0], time[1])
        .add_range_filter("DEPTH", depth[0], depth[1])
        .add_is_not_null_filter("DEPTH")
        .to_pandas_dataframe()
    )

df_ICOS['RI'] = "ICOS"
df_ICOS
# Out:
# Creating JSONQuery with from: FromBBFDataset(paths=['icos/icos.bbf'])
# Running query: {"output": {"format": "parquet"}, "select": [{"column": "Latitude", "alias": "LATITUDE"}, {"column": "Longitude", "alias": "LONGITUDE"}, {"column": "Depth [m]", "alias": "DEPTH"}, {"column": "Temp [degC]", "alias": "EXV017"}, {"column": "Date/Time", "alias": "TIME"}], "filters": [{"column": "LONGITUDE", "gt_eq": -10, "lt_eq": 45}, {"column": "LATITUDE", "gt_eq": 30, "lt_eq": 60}, {"column": "TIME", "gt_eq": "2020-01-01", "lt_eq": "2020-12-31"}, {"column": "DEPTH", "gt_eq": 0, "lt_eq": 10}, {"is_not_null": {"column": "DEPTH"}}], "distinct": null, "sort_by": null, "limit": null, "offset": null, "from": {"bbf": {"paths": ["icos/icos.bbf"]}}}
#        LATITUDE  LONGITUDE  DEPTH  EXV017                TIME    RI
# 0        58.666     -9.977    5.0   9.790 2020-02-09 10:52:32  ICOS
# 1        58.666     -9.966    5.0   9.802 2020-02-09 10:54:01  ICOS
# 2        58.665     -9.954    5.0   9.815 2020-02-09 10:55:31  ICOS
# 3        58.664     -9.920    5.0   9.794 2020-02-09 11:00:02  ICOS
# 4        58.664     -9.909    5.0   9.783 2020-02-09 11:01:31  ICOS
# ...         ...        ...    ...     ...                 ...   ...
# 18244    51.442      3.044    5.0  10.710 2020-11-25 09:04:45  ICOS
# 18245    51.442      3.043    5.0  10.713 2020-11-25 09:05:00  ICOS
# 18246    51.442      3.042    5.0  10.715 2020-11-25 09:05:15  ICOS
# 18247    51.442      3.041    5.0  10.717 2020-11-25 09:05:30  ICOS
# 18248    51.441      3.041    5.0  10.720 2020-11-25 09:05:45  ICOS
#
# [18249 rows x 6 columns]

# %% [markdown]
# SPARQL query to retrieve the Argo parameters related to EXV

# %%
def execute_sparql_query(endpoint, sparql_query):
    response = requests.get(
        endpoint,
        params={"query": sparql_query, "format": "application/sparql-results+json"},
        headers={"Accept": "application/sparql-results+json"}
    )
    
    response.raise_for_status()

    results = response.json()
    
    return results

def exv_to_r03(exv_code: str, cache: bool = True) -> List[str]:
    cache_key = f"exv_to_r03_{exv_code}"
       
    exv_identifiers = map(lambda exv_code: f'<http://vocab.nerc.ac.uk/collection/EXV/current/{exv_code}/>', [exv_code])
    exv_identifiers = "\n".join(exv_identifiers)
    sparql_query = f"""
        PREFIX dce: <http://purl.org/dc/elements/1.1/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        PREFIX iadopt: <https://w3id.org/iadopt/ont#> 
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX owl: <http://www.w3.org/2002/07/owl#>

        SELECT DISTINCT ?r03 ?prefLabel ?notation
        WHERE {{
            VALUES ?exv {{
                {exv_identifiers}
            }}

            OPTIONAL {{?exv iadopt:hasApplicableMatrix ?matrix .}}
            # ?exv iadopt:hasApplicableObjectOfInterest ?ooi .
            # ?exv iadopt:hasApplicableProperty ?property .

            <http://vocab.nerc.ac.uk/collection/P01/current/> skos:member ?p01 .

            OPTIONAL {{ ?p01 iadopt:hasMatrix ?matrix . }}
            # ?p01 iadopt:hasObjectOfInterest ?ooi .
            # ?p01 iadopt:hasProperty ?property .

            <http://vocab.nerc.ac.uk/collection/R03/current/> skos:member ?r03 .
            
            # ?r03 owl:sameAs ?p01 .
      
            OPTIONAL {{ ?r03 skos:prefLabel ?prefLabel .
                FILTER(LANG(?prefLabel) = "en")
            }}
            OPTIONAL {{ ?r03 skos:notation ?notation . }}
        }}
    """

    results = execute_sparql_query("https://vocab.nerc.ac.uk/sparql", sparql_query)

    r03s = []

    for result in results["results"]["bindings"]:
        uri = result.get("r03", {}).get("value", "")
        r03s.append(uri.rstrip("/").split("/")[-1])
        
    return r03s

# %%
argo_variable = exv_to_r03("EXV017")
argo_variable
# Out:
# ['TEMP']

# %%
argo_tables = argo_client.list_tables()

df_argo = (
        argo_tables["argo"]
        .query()
        .add_select_column("LONGITUDE")
        .add_select_column("LATITUDE")
        .add_select_column("JULD", "TIME")
        .add_select_column("PRES", "DEPTH")
        .add_select_coalesced(argo_variable, exv_variable)
        .add_select_column("WMO_INST_TYPE")
        .add_select_column("FLOAT_SERIAL_NO")
        .add_select_column("CYCLE_NUMBER")
        .add_select_column("PLATFORM_TYPE")
        .add_select_column("PLATFORM_NUMBER")
        .add_select_column("DATA_TYPE")
        .add_range_filter("TIME", time[0], time[1])
        .add_range_filter("DEPTH", depth[0], depth[1])
        .add_range_filter("LONGITUDE", region[0], region[1])
        .add_range_filter("LATITUDE", region[2], region[3])
        .add_is_not_null_filter(exv_variable)
        .to_pandas_dataframe()
    )

df_argo['RI'] = "Argo"
df_argo
# Out:
# Creating JSONQuery with from: FromTable(table='argo')
# Running query: {"output": {"format": "parquet"}, "select": [{"column": "LONGITUDE", "alias": null}, {"column": "LATITUDE", "alias": null}, {"column": "JULD", "alias": "TIME"}, {"column": "PRES", "alias": "DEPTH"}, {"function": "coalesce", "args": [{"column": "TEMP", "alias": null}], "alias": "EXV017"}, {"column": "WMO_INST_TYPE", "alias": null}, {"column": "FLOAT_SERIAL_NO", "alias": null}, {"column": "CYCLE_NUMBER", "alias": null}, {"column": "PLATFORM_TYPE", "alias": null}, {"column": "PLATFORM_NUMBER", "alias": null}, {"column": "DATA_TYPE", "alias": null}], "filters": [{"column": "TIME", "gt_eq": "2020-01-01", "lt_eq": "2020-12-31"}, {"column": "DEPTH", "gt_eq": 0, "lt_eq": 10}, {"column": "LONGITUDE", "gt_eq": -10, "lt_eq": 45}, {"column": "LATITUDE", "gt_eq": 30, "lt_eq": 60}, {"is_not_null": {"column": "EXV017"}}], "distinct": null, "sort_by": null, "limit": null, "offset": null, "from": "argo"}
#         LONGITUDE   LATITUDE                    TIME  DEPTH     EXV017  \
# 0       19.147095  55.509598 2020-01-02 09:18:29.999   0.07   6.046000
# 1       19.147095  55.509598 2020-01-02 09:18:29.999   0.30   6.046000
# 2       19.147095  55.509598 2020-01-02 09:18:29.999   0.77   6.045329
# 3       19.147095  55.509598 2020-01-02 09:18:29.999   1.00   6.045000
# 4       19.147095  55.509598 2020-01-02 09:18:29.999   2.00   6.045000
# ...           ...        ...                     ...    ...        ...
# 149549  18.185938  42.088702 2020-12-27 13:14:00.000   9.90  15.794000
# 149550  18.185938  42.088702 2020-12-27 13:14:00.000   9.90  15.780000
# 149551  18.185938  42.088702 2020-12-27 13:14:00.000  10.00  15.770000
# 149552  18.185938  42.088702 2020-12-27 13:14:00.000   9.90  15.758000
# 149553  18.185938  42.088702 2020-12-27 13:14:00.000   9.90  15.752000
#
#        WMO_INST_TYPE FLOAT_SERIAL_NO  CYCLE_NUMBER PLATFORM_TYPE  \
# 0                844  AI2632-18EU005           249         ARVOR
# 1                844  AI2632-18EU005           249         ARVOR
# 2                844  AI2632-18EU005           249         ARVOR
# 3                844  AI2632-18EU005           249         ARVOR
# 4                844  AI2632-18EU005           249         ARVOR
# ...              ...             ...           ...           ...
# 149549           836  P41308-18IT001           176    PROVOR_III
# 149550           836  P41308-18IT001           176    PROVOR_III
# 149551           836  P41308-18IT001           176    PROVOR_III
# 149552           836  P41308-18IT001           176    PROVOR_III
# 149553           836  P41308-18IT001           176    PROVOR_III
#
#        PLATFORM_NUMBER               DATA_TYPE    RI
# 0              3902106  Argo synthetic profile  Argo
# 1              3902106  Argo synthetic profile  Argo
# 2              3902106  Argo synthetic profile  Argo
# 3              3902106  Argo synthetic profile  Argo
# 4              3902106  Argo synthetic profile  Argo
# ...                ...                     ...   ...
# 149549         6903250            Argo profile  Argo
# 149550         6903250            Argo profile  Argo
# 149551         6903250            Argo profile  Argo
# 149552         6903250            Argo profile  Argo
# 149553         6903250            Argo profile  Argo
#
# [149554 rows x 12 columns]

# %%
df_merged = pd.concat([df_CDI, df_argo, df_ICOS], axis=0)
df_merged = df_merged.sort_values(by='TIME').reset_index(drop=True)
df_merged
# Out:
#          LONGITUDE   LATITUDE                    TIME  DEPTH   SDN_STATION  \
# 0        18.763457  42.436750 2020-01-01 00:00:00.000    7.0          S006
# 1        18.763534  42.436664 2020-01-01 00:00:32.553    1.0          S007
# 2        18.763534  42.436664 2020-01-01 00:01:32.554    1.0          S007
# 3        18.763534  42.436664 2020-01-01 00:02:32.553    1.0          S007
# 4        18.763534  42.436664 2020-01-01 00:03:32.552    1.0          S007
# ...            ...        ...                     ...    ...           ...
# 1647595  -4.654850  36.092530 2020-12-30 23:58:30.000   10.0  6903016_76_A
# 1647596  -4.654850  36.092530 2020-12-30 23:58:30.000    2.9  6903016_76_A
# 1647597  -4.654850  36.092530 2020-12-30 23:58:30.000    7.3  6903016_76_A
# 1647598  -4.654850  36.092530 2020-12-30 23:58:30.000    2.0  6903016_76_A
# 1647599  18.763534  42.436664 2020-12-30 23:59:16.997    1.0          S007
#
#          SDN_EDMO_CODE   SDN_LOCAL_CDI_ID  EXV017   RI WMO_INST_TYPE  \
# 0               2432.0             S00601  18.820  CDI           NaN
# 1               2432.0         S007201912  14.986  CDI           NaN
# 2               2432.0         S007201912  15.049  CDI           NaN
# 3               2432.0         S007201912  15.099  CDI           NaN
# 4               2432.0         S007201912  15.076  CDI           NaN
# ...                ...                ...     ...  ...           ...
# 1647595          486.0  ARGO_6903016_76_A  16.615  CDI           NaN
# 1647596          486.0  ARGO_6903016_76_A  16.636  CDI           NaN
# 1647597          486.0  ARGO_6903016_76_A  16.616  CDI           NaN
# 1647598          486.0  ARGO_6903016_76_A  16.638  CDI           NaN
# 1647599         2432.0         S007202012  16.538  CDI           NaN
#
#         FLOAT_SERIAL_NO  CYCLE_NUMBER PLATFORM_TYPE PLATFORM_NUMBER DATA_TYPE
# 0                   NaN           NaN           NaN             NaN       NaN
# 1                   NaN           NaN           NaN             NaN       NaN
# 2                   NaN           NaN           NaN             NaN       NaN
# 3                   NaN           NaN           NaN             NaN       NaN
# 4                   NaN           NaN           NaN             NaN       NaN
# ...                 ...           ...           ...             ...       ...
# 1647595             NaN           NaN           NaN             NaN       NaN
# 1647596             NaN           NaN           NaN             NaN       NaN
# 1647597             NaN           NaN           NaN             NaN       NaN
# 1647598             NaN           NaN           NaN             NaN       NaN
# 1647599             NaN           NaN           NaN             NaN       NaN
#
# [1647600 rows x 15 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 8), dpi=200)

markers = ["o", "s", "^"]  # circle, square, triangle

groups = list(df_merged.groupby("RI", observed=True))
groups = sorted(groups, key=lambda x: x[0] == "ICOS")

for (ri, group), marker in zip(groups, markers):

    is_icos = ri == "ICOS"

    sc = ax.scatter(
        group["LONGITUDE"],
        group["LATITUDE"],
        c=group["EXV017"],
        cmap="viridis",
        s=30 if is_icos else 4,
        alpha=1.0 if is_icos else 0.6,
        edgecolors="black",
        linewidths=0.1,
        marker=marker,
        label=ri,
        vmin=0,
        vmax=40,
        zorder=3 if is_icos else 2
    )

xmin, xmax = df_merged["LONGITUDE"].min(), df_merged["LONGITUDE"].max()
ymin, ymax = df_merged["LATITUDE"].min(), df_merged["LATITUDE"].max()
pad_x = (xmax - xmin) * 0.1
pad_y = (ymax - ymin) * 0.1

ax.set_xlim(xmin - pad_x, xmax + pad_x)
ax.set_ylim(ymin - pad_y, ymax + pad_y)

ctx.add_basemap(
    ax,
    source=ctx.providers.CartoDB.Voyager,
    crs="EPSG:4326"
)

ax.legend(title="Collection (RI)")

ax.set_title("EXV17")
ax.set_xlabel("lon")
ax.set_ylabel("lat")

cbar = fig.colorbar(sc, ax=ax, fraction=0.035, pad=0.04)
cbar.set_label("sst_temp")

plt.tight_layout()
plt.show()

# %%
df_merged['RI'] = pd.Categorical(df_merged['RI'], categories=['CDI', 'Argo', 'ICOS'], ordered=True)

for source, group in df_merged.groupby('RI', observed=True):
    plt.plot(group['TIME'], group['EXV017'], label=source)

plt.xlabel('Time')
plt.ylabel('Temperature [C]')
plt.legend(title='RI type')
plt.title('EXV17 timeseries by RI type')
plt.show()
