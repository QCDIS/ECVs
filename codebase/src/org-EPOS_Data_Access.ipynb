# %% [markdown]
# # ENVRI-Hub NEXT - Hand On the EPOS API

# %% [markdown]
# ## Prerequisites
# Install python libraries

# %%
! pip install requests --break-system-packages
! pip install owslib --break-system-packages
! pip install pyproj --break-system-packages
! pip install geopandas --break-system-packages

! pip list
# Out:
# Requirement already satisfied: requests in /opt/conda/envs/ecvs/lib/python3.14/site-packages (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests) (2026.4.22)
# Collecting owslib
#   Downloading owslib-0.35.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting lxml (from owslib)
#   Downloading lxml-6.1.0-cp314-cp314-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: python-dateutil in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from owslib) (2.9.0.post0)
# Requirement already satisfied: pyyaml in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from owslib) (6.0.3)
# Requirement already satisfied: requests in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from owslib) (2.33.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from python-dateutil->owslib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests->owslib) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests->owslib) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests->owslib) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from requests->owslib) (2026.4.22)
# Downloading owslib-0.35.0-py3-none-any.whl (240 kB)
# Downloading lxml-6.1.0-cp314-cp314-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 3.8 MB/s eta 0:00:00eta 0:00:01
# Installing collected packages: lxml, owslib
# Successfully installed lxml-6.1.0 owslib-0.35.0
# Collecting pyproj
#   Using cached pyproj-3.7.2-cp314-cp314-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: certifi in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from pyproj) (2026.4.22)
# Using cached pyproj-3.7.2-cp314-cp314-manylinux_2_28_x86_64.whl (9.5 MB)
# Installing collected packages: pyproj
# Successfully installed pyproj-3.7.2
# Collecting geopandas
#   Using cached geopandas-1.1.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from geopandas) (2.4.3)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Using cached pyogrio-0.12.1-cp314-cp314-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from geopandas) (26.2)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from geopandas) (3.0.2)
# Requirement already satisfied: pyproj>=3.5.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: certifi in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from pyogrio>=0.7.2->geopandas) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/ecvs/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Using cached geopandas-1.1.3-py3-none-any.whl (342 kB)
# Using cached pyogrio-0.12.1-cp314-cp314-manylinux_2_28_x86_64.whl (32.5 MB)
# Installing collected packages: pyogrio, geopandas
# Successfully installed geopandas-1.1.3 pyogrio-0.12.1
# Package                   Version
# ------------------------- ------------
# aiohappyeyeballs          2.6.1
# aiohttp                   3.12.15
# aiosignal                 1.4.0
# annotated-types           0.7.0
# anyio                     4.13.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# argopy                    1.4.0
# asttokens                 3.0.1
# async-timeout             5.0.1
# attrs                     26.1.0
# Brotli                    1.2.0
# cached-property           1.5.2
# certifi                   2026.4.22
# cffi                      2.0.0
# cftime                    1.6.5
# chardet                   7.4.3
# charset-normalizer        3.4.7
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.20
# decorator                 5.2.1
# envrihub                  0.1.3
# erddapy                   3.1.1
# exceptiongroup            1.3.1
# executing                 2.2.1
# fonttools                 4.62.1
# frozenlist                1.7.0
# fsspec                    2026.3.0
# geopandas                 1.1.3
# h11                       0.16.0
# h2                        4.3.0
# h5netcdf                  1.8.1
# h5py                      3.16.0
# hpack                     4.1.0
# httpcore                  1.0.9
# httpx                     0.28.1
# hyperframe                6.1.0
# idna                      3.13
# ipykernel                 6.29.5
# ipython                   9.13.0
# ipython_pygments_lexers   1.1.1
# isodate                   0.7.2
# jedi                      0.19.2
# jsonschema                4.26.0
# jsonschema-path           0.4.6
# jsonschema-specifications 2025.9.1
# jupyter_client            8.8.0
# jupyter_core              5.9.1
# kiwisolver                1.5.0
# lazy-object-proxy         1.12.0
# lxml                      6.1.0
# matplotlib                3.10.9
# matplotlib-inline         0.2.1
# minio                     7.2.15
# multidict                 6.7.1
# munkres                   1.1.4
# nest_asyncio              1.6.0
# netCDF4                   1.7.4
# numpy                     2.4.3
# openapi-schema-validator  0.8.1
# openapi-spec-validator    0.8.5
# OWSLib                    0.35.0
# packaging                 26.2
# pandas                    3.0.2
# parso                     0.8.6
# pathable                  0.5.0
# pexpect                   4.9.0
# pillow                    12.2.0
# pip                       25.0.1
# platformdirs              4.9.6
# prance                    25.4.8.0
# prompt_toolkit            3.0.52
# propcache                 0.3.1
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# py                        1.11.0
# pycparser                 2.22
# pycryptodome              3.23.0
# pydantic                  2.13.3
# pydantic_core             2.46.3
# pydantic-settings         2.14.0
# Pygments                  2.20.0
# pyogrio                   0.12.1
# pyparsing                 3.3.2
# pyproj                    3.7.2
# PySide6                   6.9.2
# PySocks                   1.7.1
# python-dateutil           2.9.0.post0
# python-dotenv             1.2.2
# pytz                      2026.1.post1
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# rdflib                    7.6.0
# referencing               0.37.0
# requests                  2.33.1
# retry                     0.9.2
# rfc3339-validator         0.1.4
# rpds-py                   0.30.0
# ruamel.yaml               0.19.1
# scipy                     1.17.1
# SecretsProvider           2.0.3
# setuptools                82.0.1
# shapely                   2.1.2
# shiboken6                 6.9.2
# six                       1.17.0
# sniffio                   1.3.1
# SPARQLWrapper             2.0.0
# stack_data                0.6.3
# toolz                     1.1.0
# tornado                   6.5.5
# traitlets                 5.14.3
# typing_extensions         4.15.0
# typing-inspection         0.4.2
# unicodedata2              17.0.1
# urllib3                   2.6.3
# wcwidth                   0.6.0
# xarray                    2025.9.0
# yarl                      1.23.0

# %% [markdown]
# ## Search
# The search function of the EPOS API allows users to query the database of metadata contained into the EPOS. The API uses a RESTful architecture, which means that users can send HTTP requests to the API endpoints and receive responses in JSON.
#
# *import requests* is a Python statement that imports the *requests* library, which is a popular Python library for making HTTP requests. The *requests* library provides an interface for sending HTTP requests and handling their responses, making it a popular good choice for RESTful API access.

# %%
import requests

# %% [markdown]
# *api_url* is assigned to 'https://www.ics-c.epos-eu.org/api/v1'. This represents the base URL for the EPOS API. Documentation: 'https://www.ics-c.epos-eu.org/api/v1/ui/'

# %%
api_url = 'https://www.ics-c.epos-eu.org/api/v1'

# %% [markdown]
# From the *EXV* using the EPOS Vocabulary tool (https://registry.epos-eu.org/ncl/ui/sparql-form#) to retrieve the value to be used in the EPOS API. (TODO)

# %%
exv_variable = 'http://vocab.nerc.ac.uk/collection/EXV/current/EXV023/'

# %% [markdown]
# We can use the *requests* library to send an HTTP GET request to the EPOS API search endpoint, and then extract the JSON data from the response.
# The parameters in the query for this request:
# - *facets* is set to false, this parameter is set to true when the client want the API to return the information in a categorized structure, it can  show the information as in different category on multiple levels.
# - *q* is the search by free text, it narrows down the results based on which resource contains in the title or in the description or as keyword the specific string

# %%
search_endpoint = api_url + '/resources/search?q=&facets=false'

response_search = requests.get(search_endpoint)
data = response_search.json()

# %% [markdown]
# This is a JSON object with two key:
#
# 1. "*filters*" which has an array of four objects as its value: "*keyword*", "*organisations*", "*sciencedomains*" and "*servicetype*". Each object represents a filter category and has two key-value pairs:
#     - "*name*": a string that represents the name of the filter category.
#     - "*children*": an array of objects that represent the subcategories for the filter category. Each subcategory object has two key-value pairs:
#         - "*id*": a string that represents a unique identifier for the subcategory.
#         - "*name*": a string that represents the name of the subcategory.
# 2. "*results*" that holds an array named *distributions* that is an array of object representing all the resources available in the system.

# %% [markdown]
# Each one of the *results* object has these properties:
# - "**availableFormats**": an array of elements each representing a file format that can be downloaded for this resource, including the format type, the url to get the resource with that specific format, a label, and type which define if the format is natively available of it needs a conversion.
# - "**description**": a string containing a detailed description of the dataset, including the purpose, content, and objectives.
# - "**href**": a string representing the URL where the EPOS ICS-C API serve the details of the resources.
# - "**hrefExtended**": a string representing the URL where the EPOS ICS-C API serve the more deeper details of the resources.
# - "**id**": a string representing the unique identifier of this dataset.
# - "**status**": an integer representing the status of the resource.
# - "**title**": a string representing the title of the resource.
# - "**uid**": a string representing the unique identifier of the resource.

# %% [markdown]
# Here it is an instance of the first resource:

# %%
data['results']['distributions'][0]
# Out:
# {'availableFormats': [{'format': 'application/epos.geo+json',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/120f993e-430c-45a5-a9b0-099dc8a240c3?format=GeoJSON',
#    'label': 'GEOJSON (GeoJSON)',
#    'originalFormat': 'GeoJSON',
#    'type': 'ORIGINAL'},
#   {'format': 'JSON',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/120f993e-430c-45a5-a9b0-099dc8a240c3?format=JSON',
#    'label': 'JSON',
#    'originalFormat': 'JSON',
#    'type': 'ORIGINAL'}],
#  'dataServiceProvider': {'dataProviderLegalName': 'IMO - Icelandic Meteorological Office',
#   'dataProviderUrl': 'https://en.vedur.is',
#   'instanceid': 'f2dfed56-65dd-47af-bda6-12331892d16b'},
#  'description': 'The service allows to open static maps showing the probabilistic hazard due to tephra fallout for selected Icelandic volcanoes; e.g. Hekla, Katla, Öræfajökull, Snæfellsjökull and Eldfell (Vestmannaeyjar). The maps are provided for selected tephra ground loading thresholds (typically 1, 10, 100 kg/m2) and have been produced for eruptive scenarios of reference. The numerical model VOL-CALPUFF has been used to simulate the dispersal of tephra in the atmosphere and 10 years of meteorological data (downloaded from ECMWF center) have been processed to get a statistic in the atmospheric parameters.',
#  'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/120f993e-430c-45a5-a9b0-099dc8a240c3',
#  'hrefExtended': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/120f993e-430c-45a5-a9b0-099dc8a240c3?extended=true',
#  'id': '120f993e-430c-45a5-a9b0-099dc8a240c3',
#  'metaId': '07daa929-cb76-4572-af87-d2e2f7e66349',
#  'status': 1,
#  'statusTimestamp': '2026-05-01T10:44:33Z',
#  'statusURL': 'https://epos-services.vm.fedcloud.eu/monitoring/?sha=91899d3c14ba64d3e070b6676f6e3fc570838752f58e8441d7b3b8c4f79e1eb1',
#  'title': 'Tephra fallout hazard maps Iceland',
#  'uid': 'file:///www.epos-eu.org/epos-dcat-ap/Volcano_observations/Dataset/058/WSDistribution'}

# %% [markdown]
# ## Details
#
# The details function of the EPOS API allows users to retrieve detailed information about a specific seismic event. Users can query the API using the unique ID assigned to each resource in the database.
#
# To retrieve all the detailed information about this resource is enough to do a GET request, using also this time the *requests* library, on the *href* property.

# %%
response_detail = requests.get(data['results']['distributions'][0]['href'])
data_details = response_detail.json()

# %% [markdown]
# The details response payload have this structure:
# - **availableFormats**: an array that contains multiple object with details about the available format for the data, one for each available format.
# - **dataProvider**: an array that contains objects with details about the data provider of the resource, one resource can have multiple dataprovider and each one of these can have multiple dataproviders related, also, if available is present an url to the page of the dataprovider.
# - **description**: a string that describes the purpose and objectives of the resource.
# - **downloadURL**: This property contains a URL that is a direct link to a downloadable file in a given format. An empty string indicating that there is no download URL available.
# - **endpoint**: a string that provides the URL endpoint for accessing the data.
# - **frequencyUpdate**: a string that indicates the frequency or the strategy of updates to the data.
# - **hasQualityAnnotation**: a string that provides a link to information about the quality assurance of the data.
# - **href**: a string that provides a link to the details of the resource.
# - **id**: a string that serves as a unique identifier for the resource.
# - **internalID**: an array that contains the internal identifier for the resource.
# - **keywords**: an array of strings that contain keywords related to the data.
# - **license**: a string that provides a link to the license agreement for accessing the data.
# - **operationid**: a string that provides a link to the operation of the resource, it contains the unique identifier of the operation.
# - **scienceDomain**: an array that provides the science domain of the resource.
# - **serviceDescription**: a string that describes the purpose of the web service.
# - **serviceDocumentation**: a string that provides a link to the documentation for the web service.
# - **serviceEndpoint**: a string that provides the URL endpoint for accessing the web service.
# - **serviceName**: a string that provides the name of the web service.
# - **serviceParameters**: an array that contains an object with details about the parameters required to use the web service (in this case, the parameter "start" is required and has a default value of "19821001").
# - **serviceProvider**: an object with details about the service provider of the resource, one resource can have one service provider and each one of these can have multiple service providers related, also, if available is present an url to the page of the serviceprovider.
# - **serviceSpatial**: an object that contains spatial information about the service like a path of coordinates.
# - **serviceTemporalCoverage**: an object that provides temporal coverage information for the service.
# - **serviceType**: an array that provides the type of the service.
# - **spatial**: an object that contains spatial information about the resource like a path defined by a set of coordinates.
# - **temporalCoverage**: an object that provides temporal coverage information for the resource.
# - **title**: a string that provides the title of the resource.
# - **type**: a string that provides the type of the resource.
# - **uid**: a string that serves as a unique identifier of the resource.

# %%
data_details
# Out:
# {'accessRights': 'https://publications.europa.eu/resource/authority/access-right/PUBLIC',
#  'availableContactPoints': [{'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=120f993e-430c-45a5-a9b0-099dc8a240c3&contactType=SERVICEPROVIDERS',
#    'type': 'SERVICEPROVIDERS'},
#   {'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=120f993e-430c-45a5-a9b0-099dc8a240c3&contactType=DATAPROVIDERS',
#    'type': 'DATAPROVIDERS'},
#   {'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=120f993e-430c-45a5-a9b0-099dc8a240c3&contactType=ALL',
#    'type': 'ALL'}],
#  'availableFormats': [{'format': 'application/epos.geo+json',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/120f993e-430c-45a5-a9b0-099dc8a240c3?format=GeoJSON',
#    'label': 'GEOJSON (GeoJSON)',
#    'originalFormat': 'GeoJSON',
#    'type': 'ORIGINAL'},
#   {'format': 'JSON',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/120f993e-430c-45a5-a9b0-099dc8a240c3?format=JSON',
#    'label': 'JSON',
#    'originalFormat': 'JSON',
#    'type': 'ORIGINAL'}],
#  'categories': {'children': [{'children': [{'ddss': 'category:geohazards',
#       'name': 'Geohazards'}],
#     'code': 'VO',
#     'color': '#e70802',
#     'id': '4',
#     'imgUrl': 'assets/img/logo/VOLCANO_logo.png',
#     'linkUrl': 'https://www.epos-eu.org/tcs/volcano-observations',
#     'name': 'Volcano Observations'}],
#   'name': 'domains'},
#  'dataProvider': [{'country': 'IS',
#    'dataProviderLegalName': 'IMO - Icelandic Meteorological Office',
#    'dataProviderUrl': 'https://en.vedur.is',
#    'instanceid': 'f2dfed56-65dd-47af-bda6-12331892d16b',
#    'metaid': 'f2dfed56-65dd-47af-bda6-12331892d16b',
#    'uid': 'f2dfed56-65dd-47af-bda6-12331892d16b'}],
#  'description': 'The service allows to open static maps showing the probabilistic hazard due to tephra fallout for selected Icelandic volcanoes; e.g. Hekla, Katla, Öræfajökull, Snæfellsjökull and Eldfell (Vestmannaeyjar). The maps are provided for selected tephra ground loading thresholds (typically 1, 10, 100 kg/m2) and have been produced for eruptive scenarios of reference. The numerical model VOL-CALPUFF has been used to simulate the dispersal of tephra in the atmosphere and 10 years of meteorological data (downloaded from ECMWF center) have been processed to get a statistic in the atmospheric parameters.',
#  'editorId': 'ingestor',
#  'endpoint': 'https://api.vedur.is/epos/hazard/maps/probabilistic-modelling-based/tephra{?format_type}&bbox={minlatitude, minlongitude, maxlatitude, maxlongitude}',
#  'frequencyUpdate': 'http://purl.org/cld/freq/irregular',
#  'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/120f993e-430c-45a5-a9b0-099dc8a240c3',
#  'hrefExtended': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/120f993e-430c-45a5-a9b0-099dc8a240c3?extended=true',
#  'id': '120f993e-430c-45a5-a9b0-099dc8a240c3',
#  'internalID': ['WP11-DDSS-058'],
#  'keywords': ['geohazards',
#   'hazard map',
#   'hazard assessment',
#   'volcanic hazard',
#   'imo',
#   'tephra fallout',
#   'probabilistic map',
#   'explosive eruption'],
#  'license': 'https://creativecommons.org/licenses/by-sa/4.0/',
#  'metaId': '07daa929-cb76-4572-af87-d2e2f7e66349',
#  'operationid': 'file:///www.epos-eu.org/epos-dcat-ap/Volcano_observations/Dataset/058/Volcanic-hazardmaps-warning-operation',
#  'qualityAssurance': 'https://data.epos-iceland.is/files/quality_assurance/Quality_Assurance_V1.0_IMO_Hazard_Maps.pdf',
#  'scienceDomain': ['Geohazards'],
#  'serviceDescription': 'The service allows to access selected maps showing the probability to exceed tephra loadings at ground for selected eruptive scenarios in Iceland.',
#  'serviceDocumentation': 'https://api.vedur.is/epos/#/hazard-maps/tephra',
#  'serviceEndpoint': 'https://api.vedur.is/epos/hazard/maps/probabilistic-modelling-based/tephra',
#  'serviceName': 'Tephra fallout hazard maps for explosive volcanoes in Iceland',
#  'serviceParameters': [{'Enum': ['GeoJSON', 'JSON'],
#    'defaultValue': 'GeoJSON',
#    'label': 'Formatted result',
#    'multipleValue': 'false',
#    'name': 'format_type',
#    'property': 'schema:encodingFormat',
#    'readOnlyValue': 'false',
#    'required': False,
#    'type': 'string'},
#   {'defaultValue': '-10.0',
#    'label': 'Maximum Longitude',
#    'maxValue': '180.0',
#    'minValue': '-180.0',
#    'multipleValue': 'false',
#    'name': 'maxlongitude',
#    'property': 'epos:easternmostLongitude',
#    'readOnlyValue': 'false',
#    'required': True,
#    'type': 'float'},
#   {'defaultValue': '68.5',
#    'label': 'Maximum Latitude',
#    'maxValue': '90.0',
#    'minValue': '-90.0',
#    'multipleValue': 'false',
#    'name': 'maxlatitude',
#    'property': 'epos:northernmostLatitude',
#    'readOnlyValue': 'false',
#    'required': True,
#    'type': 'float'},
#   {'defaultValue': '-25.0',
#    'label': 'Minimum Longitude',
#    'maxValue': '180.0',
#    'minValue': '-180.0',
#    'multipleValue': 'false',
#    'name': 'minlongitude',
#    'property': 'epos:westernmostLongitude',
#    'readOnlyValue': 'false',
#    'required': True,
#    'type': 'float'},
#   {'defaultValue': '63.0',
#    'label': 'Minimum Latitude',
#    'maxValue': '90.0',
#    'minValue': '-90.0',
#    'multipleValue': 'false',
#    'name': 'minlatitude',
#    'property': 'epos:southernmostLatitude',
#    'readOnlyValue': 'false',
#    'required': True,
#    'type': 'float'}],
#  'serviceProvider': {'country': 'IS',
#   'dataProviderLegalName': 'IMO - Icelandic Meteorological Office',
#   'dataProviderUrl': 'https://en.vedur.is',
#   'instanceid': 'f2dfed56-65dd-47af-bda6-12331892d16b',
#   'metaid': 'f2dfed56-65dd-47af-bda6-12331892d16b',
#   'uid': 'f2dfed56-65dd-47af-bda6-12331892d16b'},
#  'serviceSpatial': {'paths': [[[-25.0, 63.0],
#     [-25.0, 68.5],
#     [-10.0, 68.5],
#     [-10.0, 63.0],
#     [-25.0, 63.0]]],
#   'wkid': 4326},
#  'serviceTemporalCoverage': {'startDate': '2018-11-30T00:00:00Z'},
#  'spatial': {'paths': [[[-25.0, 63.0],
#     [-25.0, 68.5],
#     [-10.0, 68.5],
#     [-10.0, 63.0],
#     [-25.0, 63.0]]],
#   'wkid': 4326},
#  'temporalCoverage': {'endDate': '1990-01-01T00:00:00Z',
#   'startDate': '1980-01-01T00:00:00Z'},
#  'title': 'Tephra fallout hazard maps Iceland',
#  'type': 'WEB_SERVICE',
#  'uid': 'file:///www.epos-eu.org/epos-dcat-ap/Volcano_observations/Dataset/058/WSDistribution',
#  'versioningStatus': 'PUBLISHED'}

# %% [markdown]
# ## Download original data
#
# To download the original data of one of the resource is enough to use the *requests* to execute a GET request using the id of  the resource and on the original URL endpoint

# %%
import urllib.parse
response_original_url = requests.get(api_url + '/getoriginalurl/' + urllib.parse.quote(data_details['id'].encode('utf8')))
data_original_url = response_original_url.json()

# %% [markdown]
# The response is a Json Object with only one property: *url*.
# The url is where the resource is located.

# %%
data_original_url
# Out:
# {'url': 'https://api.vedur.is/epos/hazard/maps/probabilistic-modelling-based/tephra?&bbox=63.0,-25.0,68.5,-10.0'}

# %% [markdown]
# Using *requests* is possible to get the information located at that URL

# %%
response_original_data = requests.get(data_original_url['url'])
original_data = response_original_data.content
original_data
# Out:
# b'[{"name":"Probabilistic maps for tephra fallout","functionality":"The map shows the likelihood that different places in the country will be affected by a deposit thicker than a specific threshold","category":"map","item_type":"png","authors":"Icelandic Meteorological Office","product_reference":"https://doi.org/10.3389/feart.2018.00196","dependencies":"None","hazard":{"type":"tephra fallout","data_source":"numerical simulations","model_name":"VOL-CALPUFF","scenario_definition":"constant mass flow-rate; variable wind conditions","product_type":"Probabilistic","parameter":"Ground loading","percentile":"NA","threshold":"1000","units":"kg/m2"},"geographical_location":{"country":"Iceland","volcano":{"volcano_name":"\xc3\x96r\xc3\xa6faj\xc3\xb6kull","primary_volcano_type_(SI)":"","volcano_id":"374010","volcano_lat":"64.05","volcano_long":"-16.633"},"ll_grid_point_(product_reference_system)":"250416, 260890","ur_grid_point_(product_reference_system)":"762022, 738092","ll_grid_point_(ll)":"62.77N, 23.89W","ur_grid_point_(ll)":"67.02N, 12.98W","grid_unit_(product_reference_system)":"m"},"language":"English","dates":{"date_of_creation":"9/6/2019","range_of_validity":"NA","date_of_event":"NA"},"temporal_extension":{"initial_date_of_temporal_coverage_of_the_volcanological_dataset":"1362","final_date_of_temporal_coverage_of_the_volcanological_dataset":"1362","initial_date_of_temporal_coverage_of_the_meteo_dataset":"1980","final_date_of_temporal_coverage_of_the_meteo_dataset":"1990"},"reference_system":"ISN93","additional_data":"10 years of meteorological data provided by ECMWF","url":"https://data.epos-iceland.is/files/hazard/maps/probabilistic_modeling/tephra/ORA/20190819_prob_grload_1000_runs396.png"},{"name":"Probabilistic maps for tephra fallout","functionality":"The map shows the likelihood that different places in the country will be affected by a deposit thicker than a specific threshold","category":"map","item_type":"png","authors":"Icelandic Meteorological Office","product_reference":"https://doi.org/10.3389/feart.2018.00196","dependencies":"None","hazard":{"type":"tephra fallout","data_source":"numerical simulations","model_name":"VOL-CALPUFF","scenario_definition":"constant mass flow-rate; variable wind conditions","product_type":"Probabilistic","parameter":"Ground loading","percentile":"NA","threshold":"1","units":"kg/m2"},"geographical_location":{"country":"Iceland","volcano":{"volcano_name":"\xc3\x96r\xc3\xa6faj\xc3\xb6kull","primary_volcano_type_(SI)":"","volcano_id":"374010","volcano_lat":"64.05","volcano_long":"-16.633"},"ll_grid_point_(product_reference_system)":"250416, 260890","ur_grid_point_(product_reference_system)":"762022, 738092","ll_grid_point_(ll)":"62.77N, 23.89W","ur_grid_point_(ll)":"67.02N, 12.98W","grid_unit_(product_reference_system)":"m"},"language":"English","dates":{"date_of_creation":"9/6/2019","range_of_validity":"NA","date_of_event":"NA"},"temporal_extension":{"initial_date_of_temporal_coverage_of_the_volcanological_dataset":"1362","final_date_of_temporal_coverage_of_the_volcanological_dataset":"1362","initial_date_of_temporal_coverage_of_the_meteo_dataset":"1980","final_date_of_temporal_coverage_of_the_meteo_dataset":"1990"},"reference_system":"ISN93","additional_data":"10 years of meteorological data provided by ECMWF","url":"https://data.epos-iceland.is/files/hazard/maps/probabilistic_modeling/tephra/ORA/20190906_prob_grload_1_runs396.png"},{"name":"Probabilistic maps for tephra fallout","functionality":"The map shows the likelihood that different places in the country will be affected by a deposit thicker than a specific threshold","category":"map","item_type":"png","authors":"Icelandic Meteorological Office","product_reference":"https://doi.org/10.3389/feart.2018.00196","dependencies":"None","hazard":{"type":"tephra fallout","data_source":"numerical simulations","model_name":"VOL-CALPUFF","scenario_definition":"constant mass flow-rate; variable wind conditions","product_type":"Probabilistic"," ...

# %% [markdown]
# ## Access the RI’s data - Use Case
#
# A user want to do some analysis on some Sea Level Time Series Data using the station code

# %% [markdown]
# ### Search of the data
#
# The user do the search request asking to filter on this string: "sealevel" (The string needs to be url encoded)

# %%
response_search_filtered = requests.get(api_url + "/resources/search?q=" + urllib.parse.quote('sealevel'.encode('utf8')) + "&facets=false")
filtered_data = response_search_filtered.json()
filtered_data
# Out:
# {'filters': [{'children': [{'id': 'cmVhbCB0aW1l', 'name': 'real time'},
#     {'id': 'c2VhbGV2ZWxz', 'name': 'sealevels'},
#     {'id': 'c3RhdGlvbnM=', 'name': 'stations'}],
#    'name': 'keywords'},
#   {'children': [{'id': '39eb54f7-9536-40d6-91fc-b10379aa1ac0',
#      'name': 'VLIZ - Vlaams Insitituut voor de Zee'},
#     {'id': '0200add1-f171-4999-8bf7-7f350809a86a',
#      'name': "Agence Nationale de l'Aviation Civile et de la Météorologie"},
#     {'id': '4d4e0fb1-26dc-4366-bafc-139aa22d0e9a',
#      'name': 'Agency for Meteorology, Climatology and Geophysics'},
#     {'id': '2f215737-c37a-4e94-9f7e-348c2be26048',
#      'name': 'Agentschap voor Maritieme Dienstverlening en Kust'},
#     {'id': 'dec769d3-351e-49ac-a092-6cbcfaa74d85',
#      'name': 'Anguilla Department of Disaster Management'},
#     {'id': '3e886457-fa9d-4939-af68-a0dee4e4253f',
#      'name': 'Antigua & Barbuda Meteorological Services'},
#     {'id': '24ecce21-5edf-4a62-aebf-937f1876914d',
#      'name': 'Aqaba Marine Reserve, Research and studies division'},
#     {'id': '6816c63e-f62e-47da-b403-cbf17e75b62f',
#      'name': 'Asian Disaster Preparedness Center'},
#     {'id': '0f924035-9a78-49fc-a3bb-ce2563c9921f',
#      'name': 'Bahamas Department of Meteorology'},
#     {'id': '66bf9c5b-2953-48d0-beec-cd7829102915',
#      'name': 'Bangladesh Navy Hydrographic & Oceanographic Center'},
#     {'id': 'a99f69db-ca6d-44cc-b49c-d864a17c6d4e',
#      'name': 'Barbados Meteorological Services'},
#     {'id': '19bbd88e-9ea2-4324-b37b-e578fc4fbe85',
#      'name': 'Brazilian Coastal Monitoring System'},
#     {'id': 'c509c831-a85b-402e-8bbd-78f45fd01a93',
#      'name': 'Brazilian Institute of Geography and Statistics'},
#     {'id': '426fc9a8-a673-4bb0-87c5-8b80fb792bb8',
#      'name': 'British Antarctic Survey'},
#     {'id': 'ead9cdf6-268c-4da5-8f15-d445777e4159',
#      'name': 'Bureau of Meteorology'},
#     {'id': 'c4557b41-a3c8-47b5-9034-0bf32359dfb4',
#      'name': 'Campbell Scientific'},
#     {'id': 'e34ad7e3-566b-4142-ad6c-6017dd108cc5',
#      'name': 'Caribbean Community Climate Change Centre'},
#     {'id': '6ed3cf2f-5e3d-426c-862f-2ec388aa464d',
#      'name': 'Caribbean Institute for Meteorology and Hydrology'},
#     {'id': '572ee01a-0d5c-496d-8cec-64dc8a46745c',
#      'name': 'Central American Tsunami Advisory Center'},
#     {'id': '596f81d1-7c01-4e5d-88b0-c7ed63ed75a0',
#      'name': 'Central Weather Administration'},
#     {'id': '7fc3ae6c-1d94-4c7c-b053-dbc29855ab2c',
#      'name': 'Centre National pour la Recherche Scientifique et Technique'},
#     {'id': 'c1bdba4d-33ee-4fd5-92fb-9605cd32e51a',
#      'name': 'Channel Coastal Observatory'},
#     {'id': '3916baec-f6b0-43af-a1d0-af07ab0907b1',
#      'name': 'China Meteorological Administration'},
#     {'id': '2360212a-caea-40da-9198-44b6d5cafd6a',
#      'name': 'Civil Aviation Authority'},
#     {'id': '866de5f8-c3fe-4c73-a1b0-484bb7bf6171',
#      'name': 'Coastal Zone Management Unit'},
#     {'id': '728ede5c-2768-4ce1-b04d-8313d0513c6c',
#      'name': 'Collectivité de Saint-Martin'},
#     {'id': 'a4774898-8b8d-431c-ac67-6cec6a487a9c',
#      'name': 'Collectivité Territoriale de Martinique '},
#     {'id': '88d4a20e-00e1-46fe-b234-40def12a4562',
#      'name': "Commissariat à l'énergie atomique et aux énergies alternatives"},
#     {'id': 'da1dd02e-a7b2-4d44-8880-c27153f59848',
#      'name': 'Cyprus Marine and Maritime Institute'},
#     {'id': '535d1d6f-85b5-4366-aee4-5f439f80a10c',
#      'name': 'Cyprus Oceanography Center'},
#     {'id': '24e22407-39eb-42f5-b749-8d41fc5c5f0a',
#      'name': 'Cyprus University of Technology'},
#     {'id': 'df920615-0936-4d90-bc8b-ea6c1e52d757',
#      'name': 'Danish Meteorological Institute'},
#     {'id': '41205828-d402-41f8-a8b3-482c50866f5e',
#      'name': 'Departamento Meteorologico Aruba'},
#     {'id': '0d79fb4b-5042-4a11-a0ea-a3b7046c781a',
#      'name': 'Department of Agriculture Food and the Marine'},
#     {'id': '3fa7b0d0-183b-4bb6-b6d8-3d9e86bce21a',
#      'name': 'Department of Disaster Management and Emergencies'},
#     {'id': '54a4c6ce-cc0b-4cfb-a2b5-b708c2fff1ee',
#      'name': 'Department of Earth and Environmental Sciences'},
#     {'id': 'c2f8e230-760c-4c3e-91cd-6824b0b80c2b',
#      'name': 'Department of Fisheries and Oceans'},
#     {'id': '26f0102a-ef37-42d8-b738-689771d23c65',
#      'name': 'Department of Geology, Mines and Water Resources'},
#     {'id': '82c7094a-f04e-4ad6-96d0-a1bbbac4402f',
#      'name': 'Department of Land and Survey'},
#     {'id': '94b5e23a-90fb-44e6-8e0a-20d57a5fa1b6',
#      'name': 'Department of Meteorology and Hydrology'},
#     {'id': 'e500b315-c009-4f7a-8fcf-d919d83e8b73',
#      'name': 'Department of Physics and Astronomy \\'},
#     {'id': '56c24be2-8f81-4cde-9805-2c5805591a53',
#      'name': 'Department of Public Safety Communications'},
#     {'id': 'fe837c94-aeae-4d8c-b22b-2f3e070a5dca',
#      'name': 'Department of Survey and Mapping'},
#     {'id': 'dab31325-aa55-4374-b431-745cf909886c',
#      'name': 'Department of Water Resources'},
#     {'id': '8e509953-a7db-47a6-bd73-bb6834a87ea5',
#      'name': 'Dirección de Hidrografía y Navegación'},
#     {'id': '0e9c9770-d007-4d5c-b702-eb7bcf49b130',
#      'name': 'Dirección General Marítima'},
#     {'id': 'ab332117-a09d-47a7-8d09-96d4e8942a3d',
#      'name': "Direction des Territoires, de l'Alimentation et de la Mer à Saint-Pierre-et-Miquelon"},
#     {'id': 'dd233310-6f33-4c63-82af-3146279b5380',
#      'name': 'Direction Générale de la Météorologie'},
#     {'id': '8782a90d-0812-44ef-bc3c-7184b91bbc1d',
#      'name': 'Directorate General Meteorology and Air Navigation'},
#     {'id': '05b5245f-5531-41fc-8121-471ffc8286c3',
#      'name': 'Dominica Meteorological Service'},
#     {'id': '434cf708-2af8-4a54-9e01-ea925daa0633', 'name': 'DTU Space'},
#     {'id': '26ed110b-933f-4336-8d46-786798c3862e',
#      'name': 'Empresa de pesquisa agropecuária e extensão rural de Santa Catarina'},
#     {'id': 'b856b792-336b-4802-9e66-2345636d8063',
#      'name': 'Ensenada Center for Scientific Research and Higher Education'},
#     {'id': '641be6f0-3f12-4f06-9778-4909094abae6',
#      'name': 'Faculty of Science; Department of Geophysics'},
#     {'id': '936f47ac-9ef0-4aea-87ac-947eb2f92357',
#      'name': 'Federal Service of Russia for Hydrometeorology and Environmental Monitoring'},
#     {'id': '6efd6267-d7f8-4020-b585-a387d7d2947b',
#      'name': 'Fiji Meteorological Service'},
#     {'id': '51b7e4d3-1537-42e8-972e-c9d5f73c89be',
#      'name': 'General Directorate of Mapping'},
#     {'id': '8917c90b-bbde-4a83-9689-19613ba4cd1a',
#      'name': 'Geospatial Information Agency'},
#     {'id': '45c80521-8caf-414f-936f-8aff6bab9d84',
#      'name': 'German Research Centre for Geosciences'},
#     {'id': '1be088aa-e39b-40ab-b3f0-d0c476540ffd', 'name': 'GNS Science'},
#     {'id': '33ff3ab5-7102-42d0-95a3-6507efba3924',
#      'name': 'Goddard Earth Science and Technology Center'},
#     {'id': '30dd3d3f-5ec1-44d7-bab7-36539a1bc32b',
#      'name': 'Gwadar Port Authority and Hydrographic Department'},
#     {'id': 'de6cc860-e4a2-4170-9c1d-fd71c305270f',
#      'name': 'Hazard Management Cayman Islands'},
#     {'id': 'ebdb5ac5-9672-4c51-ba14-250e7940d71a',
#      'name': 'Hellenic Navy Hydrographic Service'},
#     {'id': 'bdcd0f53-ee85-4761-b0cd-406bbab16e06',
#      'name': 'Hong Kong Observatory'},
#     {'id': '7593cc12-1628-44ef-8fb4-0db340787e5e',
#      'name': 'Hydrographic Department of the National Cartographic Center'},
#     {'id': '2cf3e168-aaac-4ec5-9a64-49ae445a0e3e',
#      'name': 'Icelandic Coast Guard Hydrographic Department'},
#     {'id': '391fb269-5224-45cf-9bb8-5f1b8c8ec1de',
#      'name': 'Indian National Centre for Ocean Information Services'},
#     {'id': '0e623238-c67b-419a-a044-f76bf708195f',
#      'name': 'Informationstechnikzentrum Bund'},
#     {'id': '45e0745f-e20c-403b-b51e-1f1d6b2cdbc3',
#      'name': 'Institut de Physique du Globe de Paris'},
#     {'id': '083fe3a5-a40e-4bc8-bf6d-cd7bc1ac9bbd',
#      'name': 'Institut de Recherche pour le Développement'},
#     {'id': '110366de-a42a-4a1e-b7fc-98eb3e9be2c0',
#      'name': 'Institute of Oceanography and Fisheries'},
#     {'id': 'd8572372-f510-4155-9861-bdd5acb84640',
#      'name': 'Instituto de Geociencias- Universidad de Panamá'},
#     {'id': '872f8ceb-e9fc-449b-93a0-9b0c76d6cf2c',
#      'name': 'Instituto Dominicano De Meteorología'},
#     {'id': '1153f8e9-111d-4069-b9b7-08dd4d7a4e83',
#      'name': 'Instituto Español de Oceanografía'},
#     {'id': 'fca09163-1a85-46b6-b71a-3513daf506d1',
#      'name': 'Instituto Geográfico Nacional'},
#     {'id': 'edcb9e30-66ae-4aec-a510-3b1451cda4fd',
#      'name': 'Instituto Geográfico Português'},
#     {'id': '70ece37d-f7ca-476b-afb7-11c747bad786',
#      'name': 'Instituto Hidrográfico'},
#     {'id': 'bb55c40d-dbae-4ba1-b2f0-8f47b232e022',
#      'name': 'Instituto Nacional de Hidrografia e Navegação'},
#     {'id': '94203546-1692-4884-8e9f-fea535e85fe5',
#      'name': 'Instituto Nacional de Meteorologia e Geofisica de Cabo Verde'},
#     {'id': '0dd39b1a-f6c0-48ee-8fbe-f721e7f481a1',
#      'name': 'Instituto Nacional de Sismología, Vulcanología, Meteorología e Hidrología'},
#     {'id': '3c27ba63-5559-41bf-8561-141182231e5c',
#      'name': 'Instituto Nicaragüense de Estudios Territoriales'},
#     {'id': 'b2c3f06a-4808-4cbc-8b33-caec989ea6aa',
#      'name': 'Instituto Oceanografico de la Armada'},
#     {'id': 'c25d1b58-3628-4635-aa9e-face2925cc6c',
#      'name': 'International Tsunami Information Center Caribbean Office'},
#     {'id': '3b174da1-397f-454f-9f2d-5092c9630258',
#      'name': 'Israel Oceanographic and Limnological Research Ltd.'},
#     {'id': 'cd67d432-19c3-4aea-bc0a-985835170ea4',
#      'name': 'Istituto Nazionale di Geofisica e Vulcanologia'},
#     {'id': '98425ed6-c64e-4c9f-809b-78842d0c7d31',
#      'name': 'Italian National Institute for Environmental Protection and Research'},
#     {'id': '5c597fc3-b2a9-4f88-9d57-dfab75a297cc',
#      'name': 'Jamaican Meteorological Service'},
#     {'id': '7fd88c71-a843-4ef4-a1c3-4584ce650e32',
#      'name': 'Japan Coast Guard'},
#     {'id': '2909a39c-1fc7-4e8c-a12b-2908a9f7fb07',
#      'name': 'Japan Meteorological Agency'},
#     {'id': '99503c17-0675-4958-80e0-81bcaa7eca5a',
#      'name': 'Joint Research Centre'},
#     {'id': '7fe6ca51-a2d3-4821-9d0f-cfa9944fb9ee',
#      'name': 'Kandilli Observatory and Earthquake Research Institute'},
#     {'id': 'cd2e6d4f-fcf0-4217-bb12-8b0840216de4',
#      'name': 'Karachi Port Trust'},
#     {'id': '9db2eeca-516a-4b93-8972-a84b0662c9c0',
#      'name': 'Kenya Marine and Fisheries Research Institute Mombasa Centre'},
#     {'id': '1bcc5657-068a-465e-9698-fd5e5b5b0348',
#      'name': 'Kiribati Meteorological Service '},
#     {'id': '756d70aa-44f0-4308-97b2-23e5ecc8e685',
#      'name': 'Korea Environmental Industry and Technology Institute'},
#     {'id': 'ebd2c214-c074-493c-9343-810480f6c415',
#      'name': 'Korea Hydrographic and Oceanographic Agency'},
#     {'id': '5d337db3-6d1e-4a44-b9fa-3ebf864abc9a',
#      'name': 'Korea Institute of Ocean Science and Technology'},
#     {'id': 'd743ba4c-0edb-406e-9acd-fce555075e5f',
#      'name': 'Kuwait Institute for Scientific Research'},
#     {'id': 'd43a450f-af6e-4897-bea7-18393ca4a0bb',
#      'name': 'Laboratoire d’Études en Géophysique et Océanographie Spatiales'},
#     {'id': '52780556-7ac3-4a28-9d31-cdcf34ad774d',
#      'name': 'Land and Surveys Division, Hydrographic Unit '},
#     {'id': '457ae516-bb95-4d55-852a-ecbe3b3dec93',
#      'name': 'Land Information New Zealand'},
#     {'id': 'e424b5a6-363e-41de-8bb5-9078a3b4d916',
#      'name': 'Malaysian Meteorological Department '},
#     {'id': '0e6b763b-cadb-4a89-b1df-54f6efb79f30',
#      'name': 'Maldives Meteorological Department'},
#     {'id': 'cfa6574e-a9ee-4644-ae9f-01eacd2e2ad1',
#      'name': 'Marine Hydrophysical Institute'},
#     {'id': 'db97521d-882e-4341-b33d-0d041c46fd43',
#      'name': 'Marine Institute Ireland'},
#     {'id': '1b92580a-3516-405f-bead-47c1803a3ab1',
#      'name': 'Maritime and Port Authority of Singapore'},
#     {'id': '67943bf1-fe92-4ff0-9160-9f20e716522b',
#      'name': 'Mauritius Meteorological Service'},
#     {'id': '33f9b6d3-b3e5-4f57-ad56-31fa73133de8',
#      'name': 'Meteorological Department Curaçao'},
#     {'id': '50dc0760-ef9a-4c7f-928d-763d8773d447',
#      'name': 'Meteorological Services Division '},
#     {'id': 'f05d8ccb-ae3b-4fa5-9bac-4d04e14b9f1a',
#      'name': 'Ministerio de Medio Ambiente y Recursos Naturales'},
#     {'id': '411e5450-c9c8-46ec-8742-97395d715a82',
#      'name': 'Ministry of Maritime Affairs and Fisheries'},
#     {'id': 'a86c459b-d40d-4d0e-99ce-7124147fe17f',
#      'name': 'Ministry of the Environment and Forests'},
#     {'id': '1e56a5b9-1ed1-4244-9541-b4b5abd2419a',
#      'name': 'Namibian Ports Authority'},
#     {'id': '6b9c3e4c-3377-4f9c-bf91-3428755af3b0',
#      'name': 'National Antarctic Scientific Centre'},
#     {'id': '1949a285-45e2-4e06-b48b-48e8e2625242',
#      'name': 'National Aquatic Resources Research and Development Agency'},
#     {'id': 'a51d5bee-f831-4fbd-a713-980f1511cbe7',
#      'name': 'National Centre for Geophysical Research'},
#     {'id': 'a2db9c4d-b53e-4c30-a649-8114c843a8ca',
#      'name': 'National Centre for Hydro-Meteorological Forecasting'},
#     {'id': '22089f4d-0aae-4504-98ca-091fce701c15',
#      'name': 'National Emergency Management Agency'},
#     {'id': 'ae32d18f-949f-49c6-aeeb-341303aeca07',
#      'name': 'National Emergency Management Organization'},
#     {'id': '8ad447bf-6b3a-4f69-bd56-c2b64c46c368',
#      'name': 'National Institute for Earth Physics'},
#     {'id': '0b151f18-f2a1-40e5-9061-e745d38ab070',
#      'name': 'National Institute for Marine Research and Development \\'},
#     {'id': '4ba664d0-7203-4e1b-8d7a-b26b3cb58a5b',
#      'name': 'National Institute of Oceanography and Fisheries'},
#     {'id': 'bd5ad050-7234-4943-a645-59de1cdc8b68',
#      'name': 'National Mapping and Resource Information Authority'},
#     {'id': 'ba2d5a80-2115-48d4-ab34-79a7ab184de9',
#      'name': 'National Meteorological Service of Belize'},
#     {'id': '803f6c1f-3e0f-48d0-848d-0a5e1991d40e',
#      'name': 'National Observatory of Athens'},
#     {'id': '6923fede-4539-4752-bf22-5167cc6b1d21',
#      'name': 'National Oceanography Centre'},
#     {'id': '0dcf2e65-3adc-4c75-9c0e-3d4f90d1994e',
#      'name': 'National Technical University of Athens'},
#     {'id': '91a11f06-270d-49ee-b377-e131872c5963',
#      'name': 'Navy Hydrography Center - Marine Meteorological Service'},
#     {'id': '1f305515-cf98-47f3-8a91-e65af401a6d6',
#      'name': 'Nigerian Institute for Oceanography and Marine Research'},
#     {'id': '6f10ef5a-c443-4258-89de-b30c115bb80a',
#      'name': 'NOAA National Ocean Service'},
#     {'id': '44fb70e2-c583-4190-8848-6e68254328b4',
#      'name': 'Norwegian Hydrographic Service'},
#     {'id': '58bc6a1b-9e1a-4647-a388-d15722206dd6',
#      'name': 'Nouakchott Autonomous Port'},
#     {'id': 'c0e4d3bb-45a3-43af-a2de-276f8963a889', 'name': 'OceanWise'},
#     {'id': 'f2c85c6f-bd8d-4591-bd14-ce553be59d7e',
#      'name': 'Office National de la Météorologie'},
#     {'id': 'a2e86a11-f888-421e-a153-e43b40b927bd',
#      'name': 'Office of Public Works'},
#     {'id': 'dc65650c-f511-4b7a-9654-65d1c40a753a',
#      'name': 'Office of the Port Director'},
#     {'id': '6891ab99-ead6-41fb-8696-00ad2ca6fb94',
#      'name': 'Pacific Tsunami Warning Center'},
#     {'id': '41645580-745d-4b6f-b579-4647db4ce319',
#      'name': 'Pakistan Navy Hydrographic Department'},
#     {'id': 'fa052542-a89f-4c52-be76-c1b0459f6231',
#      'name': 'Port Autonome de Pointe Noire'},
#     {'id': '90ec36d7-ca40-43bb-a1b6-871a64d67c32', 'name': 'Port of Djibouti'},
#     {'id': '3a36de47-307b-461e-8dff-41e60139cfd5',
#      'name': 'Portuguese Institute of the Sea and Atmosphere'},
#     {'id': '98198a7e-b5cf-4e06-8849-31ebec3d760a',
#      'name': "Principauté de Monaco - Direction de l'Environnement "},
#     {'id': '7e189b4d-0d69-4b3c-8cb2-058cd0da2e0e',
#      'name': 'Puerto Rico Seismic Network '},
#     {'id': 'a0a3927d-3856-4299-9355-d34177e8d079',
#      'name': 'Puertos del Estado'},
#     {'id': 'b5ec7737-ae89-4c97-bb65-c8001906d015', 'name': 'Rijkswaterstaat'},
#     {'id': 'e66caf75-a2fc-4274-81e0-361ba3e592d4', 'name': 'Royal Thai Navy '},
#     {'id': '6d617a67-454b-4807-97f3-50ddc22de89e',
#      'name': 'Saint Lucia Meteorological Services'},
#     {'id': '8a080edf-e880-417a-b2b3-252a57f32a5a',
#      'name': 'SARAO Hartebeesthoek Radio Astronomy Observatory'},
#     {'id': '2aeabf5f-7c8e-4369-80a2-4cbd24e3ac0a',
#      'name': 'Service Hydrographique et Océanographique de la Marine'},
#     {'id': 'c07ae62f-1895-46d4-acc2-f9f4edce01f4',
#      'name': 'Service Maritime et de Navigation d´Haiti'},
#     {'id': 'a4d31b03-af3f-446b-982b-fbc8fd8f1fca',
#      'name': 'Servicio de Hidrografía Naval'},
#     {'id': '9b155b46-5c1f-490f-97f4-76af6a57c1b0',
#      'name': 'Servicio Hidrográfico y Oceanográfico de la Armada'},
#     {'id': 'db9c0e0a-3edd-4706-8ef8-68c94ed1b2eb',
#      'name': 'Seychelles National Meteorological Services'},
#     {'id': 'f65bc9c4-ce62-4447-868f-ccb0636ca655',
#      'name': 'Smithsonian Marine Station'},
#     {'id': '76e04f62-55c3-4313-a2c0-cf2a421e1b9f',
#      'name': 'Smithsonian Tropical Research Institute'},
#     {'id': 'd52bd888-03d9-467f-9cc6-e6f02ddb52b6',
#      'name': 'Societé National de Raffinage'},
#     {'id': '27a7eaa8-7064-4de5-94c1-83ab8c89b8f3',
#      'name': 'South African Hydrographic Office'},
#     {'id': '83dbf2f4-263d-4b95-b4bf-a91e524d4bfa',
#      'name': 'Standing Committee on Contingencies'},
#     {'id': 'c438d5bc-a07d-423d-93bf-2f662b36d0b2',
#      'name': 'State Meteorological Agency'},
#     {'id': 'e32438a4-00cd-4111-b6b8-d555752d614d',
#      'name': 'Survey of Bangladesh, Ministry of Defense'},
#     {'id': '380d26ea-9429-4ef1-be20-8443e8ae2e9d',
#      'name': 'Swedish Maritime Administration'},
#     {'id': 'b71e35b1-ad8a-4b79-8d2f-e2a062f452aa',
#      'name': 'Swedish Meteorological and Hydrological Institute'},
#     {'id': '46234de8-bcc0-466e-9dc6-4a9195319745',
#      'name': 'Tanzania Ports Authority'},
#     {'id': '0a0012d5-9254-41fb-b866-d0797cebd7eb',
#      'name': 'The Centre De Recherches Océanographiques De Dakar-Thiaroye'},
#     {'id': '7d155087-c72d-4c5f-92d9-ddb29fed285f',
#      'name': 'The Federal Waterways and Shipping Administration'},
#     {'id': '69f10b6a-102b-4538-8bab-c25110377359', 'name': 'UNAVCO'},
#     {'id': '28d76651-a004-457a-ae04-5e00e66616f1',
#      'name': 'United Kingdom Hydrographic Office'},
#     {'id': '06a811c9-1989-438c-90e3-4b612a92e2f4',
#      'name': 'Universidad Nacional Autónoma de México'},
#     {'id': '8c6b8eb8-fef6-43e1-89e9-3a4f9f58fe53',
#      'name': 'Universidad Nacional Costa Rica, SINAMOT '},
#     {'id': '7b8499b1-1ce1-4645-a64a-90a7afa35ea4',
#      'name': 'University of French Polynesia'},
#     {'id': 'e0a182fa-d38f-4754-9758-a9a586671f35',
#      'name': 'University of Hawaii Sea Level Center '},
#     {'id': '75d2c2ff-7060-4f43-8a47-5ef4342f73f6',
#      'name': 'University of Malta'},
#     {'id': 'ff24fdde-9055-4bbe-820b-6f078f98dfae',
#      'name': 'University of Puerto Rico'},
#     {'id': 'dc9ba6d3-8358-403e-90a4-5e65ab21646a',
#      'name': 'University of the Balearic Islands'},
#     {'id': '3f624220-f687-4a10-aaaa-b2ef327e39b5',
#      'name': 'Yap Weather Service Office'},
#     {'id': '753d2cb1-0abc-4f82-b735-bef3b373dc6d',
#      'name': 'Yemen Gulf of Aden Ports Corporation'},
#     {'id': '6b1c2b93-3596-4c8c-98a5-d84b0030a51c',
#      'name': 'Yildiz Technical University'},
#     {'id': '0200add1-f171-4999-8bf7-7f350809a86a',
#      'name': "Agence Nationale de l'Aviation Civile et de la Météorologie"},
#     {'id': '4d4e0fb1-26dc-4366-bafc-139aa22d0e9a',
#      'name': 'Agency for Meteorology, Climatology and Geophysics'},
#     {'id': '2f215737-c37a-4e94-9f7e-348c2be26048',
#      'name': 'Agentschap voor Maritieme Dienstverlening en Kust'},
#     {'id': 'dec769d3-351e-49ac-a092-6cbcfaa74d85',
#      'name': 'Anguilla Department of Disaster Management'},
#     {'id': '3e886457-fa9d-4939-af68-a0dee4e4253f',
#      'name': 'Antigua & Barbuda Meteorological Services'},
#     {'id': '24ecce21-5edf-4a62-aebf-937f1876914d',
#      'name': 'Aqaba Marine Reserve, Research and studies division'},
#     {'id': '6816c63e-f62e-47da-b403-cbf17e75b62f',
#      'name': 'Asian Disaster Preparedness Center'},
#     {'id': '0f924035-9a78-49fc-a3bb-ce2563c9921f',
#      'name': 'Bahamas Department of Meteorology'},
#     {'id': '66bf9c5b-2953-48d0-beec-cd7829102915',
#      'name': 'Bangladesh Navy Hydrographic & Oceanographic Center'},
#     {'id': 'a99f69db-ca6d-44cc-b49c-d864a17c6d4e',
#      'name': 'Barbados Meteorological Services'},
#     {'id': '19bbd88e-9ea2-4324-b37b-e578fc4fbe85',
#      'name': 'Brazilian Coastal Monitoring System'},
#     {'id': 'c509c831-a85b-402e-8bbd-78f45fd01a93',
#      'name': 'Brazilian Institute of Geography and Statistics'},
#     {'id': '426fc9a8-a673-4bb0-87c5-8b80fb792bb8',
#      'name': 'British Antarctic Survey'},
#     {'id': 'ead9cdf6-268c-4da5-8f15-d445777e4159',
#      'name': 'Bureau of Meteorology'},
#     {'id': 'c4557b41-a3c8-47b5-9034-0bf32359dfb4',
#      'name': 'Campbell Scientific'},
#     {'id': 'e34ad7e3-566b-4142-ad6c-6017dd108cc5',
#      'name': 'Caribbean Community Climate Change Centre'},
#     {'id': '6ed3cf2f-5e3d-426c-862f-2ec388aa464d',
#      'name': 'Caribbean Institute for Meteorology and Hydrology'},
#     {'id': '572ee01a-0d5c-496d-8cec-64dc8a46745c',
#      'name': 'Central American Tsunami Advisory Center'},
#     {'id': '596f81d1-7c01-4e5d-88b0-c7ed63ed75a0',
#      'name': 'Central Weather Administration'},
#     {'id': '7fc3ae6c-1d94-4c7c-b053-dbc29855ab2c',
#      'name': 'Centre National pour la Recherche Scientifique et Technique'},
#     {'id': 'c1bdba4d-33ee-4fd5-92fb-9605cd32e51a',
#      'name': 'Channel Coastal Observatory'},
#     {'id': '3916baec-f6b0-43af-a1d0-af07ab0907b1',
#      'name': 'China Meteorological Administration'},
#     {'id': '2360212a-caea-40da-9198-44b6d5cafd6a',
#      'name': 'Civil Aviation Authority'},
#     {'id': '866de5f8-c3fe-4c73-a1b0-484bb7bf6171',
#      'name': 'Coastal Zone Management Unit'},
#     {'id': '728ede5c-2768-4ce1-b04d-8313d0513c6c',
#      'name': 'Collectivité de Saint-Martin'},
#     {'id': 'a4774898-8b8d-431c-ac67-6cec6a487a9c',
#      'name': 'Collectivité Territoriale de Martinique '},
#     {'id': '88d4a20e-00e1-46fe-b234-40def12a4562',
#      'name': "Commissariat à l'énergie atomique et aux énergies alternatives"},
#     {'id': 'da1dd02e-a7b2-4d44-8880-c27153f59848',
#      'name': 'Cyprus Marine and Maritime Institute'},
#     {'id': '535d1d6f-85b5-4366-aee4-5f439f80a10c',
#      'name': 'Cyprus Oceanography Center'},
#     {'id': '24e22407-39eb-42f5-b749-8d41fc5c5f0a',
#      'name': 'Cyprus University of Technology'},
#     {'id': 'df920615-0936-4d90-bc8b-ea6c1e52d757',
#      'name': 'Danish Meteorological Institute'},
#     {'id': '41205828-d402-41f8-a8b3-482c50866f5e',
#      'name': 'Departamento Meteorologico Aruba'},
#     {'id': '0d79fb4b-5042-4a11-a0ea-a3b7046c781a',
#      'name': 'Department of Agriculture Food and the Marine'},
#     {'id': '3fa7b0d0-183b-4bb6-b6d8-3d9e86bce21a',
#      'name': 'Department of Disaster Management and Emergencies'},
#     {'id': '54a4c6ce-cc0b-4cfb-a2b5-b708c2fff1ee',
#      'name': 'Department of Earth and Environmental Sciences'},
#     {'id': 'c2f8e230-760c-4c3e-91cd-6824b0b80c2b',
#      'name': 'Department of Fisheries and Oceans'},
#     {'id': '26f0102a-ef37-42d8-b738-689771d23c65',
#      'name': 'Department of Geology, Mines and Water Resources'},
#     {'id': '82c7094a-f04e-4ad6-96d0-a1bbbac4402f',
#      'name': 'Department of Land and Survey'},
#     {'id': '94b5e23a-90fb-44e6-8e0a-20d57a5fa1b6',
#      'name': 'Department of Meteorology and Hydrology'},
#     {'id': 'e500b315-c009-4f7a-8fcf-d919d83e8b73',
#      'name': 'Department of Physics and Astronomy \\'},
#     {'id': '56c24be2-8f81-4cde-9805-2c5805591a53',
#      'name': 'Department of Public Safety Communications'},
#     {'id': 'fe837c94-aeae-4d8c-b22b-2f3e070a5dca',
#      'name': 'Department of Survey and Mapping'},
#     {'id': 'dab31325-aa55-4374-b431-745cf909886c',
#      'name': 'Department of Water Resources'},
#     {'id': '8e509953-a7db-47a6-bd73-bb6834a87ea5',
#      'name': 'Dirección de Hidrografía y Navegación'},
#     {'id': '0e9c9770-d007-4d5c-b702-eb7bcf49b130',
#      'name': 'Dirección General Marítima'},
#     {'id': 'ab332117-a09d-47a7-8d09-96d4e8942a3d',
#      'name': "Direction des Territoires, de l'Alimentation et de la Mer à Saint-Pierre-et-Miquelon"},
#     {'id': 'dd233310-6f33-4c63-82af-3146279b5380',
#      'name': 'Direction Générale de la Météorologie'},
#     {'id': '8782a90d-0812-44ef-bc3c-7184b91bbc1d',
#      'name': 'Directorate General Meteorology and Air Navigation'},
#     {'id': '05b5245f-5531-41fc-8121-471ffc8286c3',
#      'name': 'Dominica Meteorological Service'},
#     {'id': '434cf708-2af8-4a54-9e01-ea925daa0633', 'name': 'DTU Space'},
#     {'id': '26ed110b-933f-4336-8d46-786798c3862e',
#      'name': 'Empresa de pesquisa agropecuária e extensão rural de Santa Catarina'},
#     {'id': 'b856b792-336b-4802-9e66-2345636d8063',
#      'name': 'Ensenada Center for Scientific Research and Higher Education'},
#     {'id': '641be6f0-3f12-4f06-9778-4909094abae6',
#      'name': 'Faculty of Science; Department of Geophysics'},
#     {'id': '936f47ac-9ef0-4aea-87ac-947eb2f92357',
#      'name': 'Federal Service of Russia for Hydrometeorology and Environmental Monitoring'},
#     {'id': '6efd6267-d7f8-4020-b585-a387d7d2947b',
#      'name': 'Fiji Meteorological Service'},
#     {'id': '51b7e4d3-1537-42e8-972e-c9d5f73c89be',
#      'name': 'General Directorate of Mapping'},
#     {'id': '8917c90b-bbde-4a83-9689-19613ba4cd1a',
#      'name': 'Geospatial Information Agency'},
#     {'id': '45c80521-8caf-414f-936f-8aff6bab9d84',
#      'name': 'German Research Centre for Geosciences'},
#     {'id': '1be088aa-e39b-40ab-b3f0-d0c476540ffd', 'name': 'GNS Science'},
#     {'id': '33ff3ab5-7102-42d0-95a3-6507efba3924',
#      'name': 'Goddard Earth Science and Technology Center'},
#     {'id': '30dd3d3f-5ec1-44d7-bab7-36539a1bc32b',
#      'name': 'Gwadar Port Authority and Hydrographic Department'},
#     {'id': 'de6cc860-e4a2-4170-9c1d-fd71c305270f',
#      'name': 'Hazard Management Cayman Islands'},
#     {'id': 'ebdb5ac5-9672-4c51-ba14-250e7940d71a',
#      'name': 'Hellenic Navy Hydrographic Service'},
#     {'id': 'bdcd0f53-ee85-4761-b0cd-406bbab16e06',
#      'name': 'Hong Kong Observatory'},
#     {'id': '7593cc12-1628-44ef-8fb4-0db340787e5e',
#      'name': 'Hydrographic Department of the National Cartographic Center'},
#     {'id': '2cf3e168-aaac-4ec5-9a64-49ae445a0e3e',
#      'name': 'Icelandic Coast Guard Hydrographic Department'},
#     {'id': '391fb269-5224-45cf-9bb8-5f1b8c8ec1de',
#      'name': 'Indian National Centre for Ocean Information Services'},
#     {'id': '0e623238-c67b-419a-a044-f76bf708195f',
#      'name': 'Informationstechnikzentrum Bund'},
#     {'id': '45e0745f-e20c-403b-b51e-1f1d6b2cdbc3',
#      'name': 'Institut de Physique du Globe de Paris'},
#     {'id': '083fe3a5-a40e-4bc8-bf6d-cd7bc1ac9bbd',
#      'name': 'Institut de Recherche pour le Développement'},
#     {'id': '110366de-a42a-4a1e-b7fc-98eb3e9be2c0',
#      'name': 'Institute of Oceanography and Fisheries'},
#     {'id': 'd8572372-f510-4155-9861-bdd5acb84640',
#      'name': 'Instituto de Geociencias- Universidad de Panamá'},
#     {'id': '872f8ceb-e9fc-449b-93a0-9b0c76d6cf2c',
#      'name': 'Instituto Dominicano De Meteorología'},
#     {'id': '1153f8e9-111d-4069-b9b7-08dd4d7a4e83',
#      'name': 'Instituto Español de Oceanografía'},
#     {'id': 'fca09163-1a85-46b6-b71a-3513daf506d1',
#      'name': 'Instituto Geográfico Nacional'},
#     {'id': 'edcb9e30-66ae-4aec-a510-3b1451cda4fd',
#      'name': 'Instituto Geográfico Português'},
#     {'id': '70ece37d-f7ca-476b-afb7-11c747bad786',
#      'name': 'Instituto Hidrográfico'},
#     {'id': 'bb55c40d-dbae-4ba1-b2f0-8f47b232e022',
#      'name': 'Instituto Nacional de Hidrografia e Navegação'},
#     {'id': '94203546-1692-4884-8e9f-fea535e85fe5',
#      'name': 'Instituto Nacional de Meteorologia e Geofisica de Cabo Verde'},
#     {'id': '0dd39b1a-f6c0-48ee-8fbe-f721e7f481a1',
#      'name': 'Instituto Nacional de Sismología, Vulcanología, Meteorología e Hidrología'},
#     {'id': '3c27ba63-5559-41bf-8561-141182231e5c',
#      'name': 'Instituto Nicaragüense de Estudios Territoriales'},
#     {'id': 'b2c3f06a-4808-4cbc-8b33-caec989ea6aa',
#      'name': 'Instituto Oceanografico de la Armada'},
#     {'id': 'c25d1b58-3628-4635-aa9e-face2925cc6c',
#      'name': 'International Tsunami Information Center Caribbean Office'},
#     {'id': '3b174da1-397f-454f-9f2d-5092c9630258',
#      'name': 'Israel Oceanographic and Limnological Research Ltd.'},
#     {'id': 'cd67d432-19c3-4aea-bc0a-985835170ea4',
#      'name': 'Istituto Nazionale di Geofisica e Vulcanologia'},
#     {'id': '98425ed6-c64e-4c9f-809b-78842d0c7d31',
#      'name': 'Italian National Institute for Environmental Protection and Research'},
#     {'id': '5c597fc3-b2a9-4f88-9d57-dfab75a297cc',
#      'name': 'Jamaican Meteorological Service'},
#     {'id': '7fd88c71-a843-4ef4-a1c3-4584ce650e32',
#      'name': 'Japan Coast Guard'},
#     {'id': '2909a39c-1fc7-4e8c-a12b-2908a9f7fb07',
#      'name': 'Japan Meteorological Agency'},
#     {'id': '99503c17-0675-4958-80e0-81bcaa7eca5a',
#      'name': 'Joint Research Centre'},
#     {'id': '7fe6ca51-a2d3-4821-9d0f-cfa9944fb9ee',
#      'name': 'Kandilli Observatory and Earthquake Research Institute'},
#     {'id': 'cd2e6d4f-fcf0-4217-bb12-8b0840216de4',
#      'name': 'Karachi Port Trust'},
#     {'id': '9db2eeca-516a-4b93-8972-a84b0662c9c0',
#      'name': 'Kenya Marine and Fisheries Research Institute Mombasa Centre'},
#     {'id': '1bcc5657-068a-465e-9698-fd5e5b5b0348',
#      'name': 'Kiribati Meteorological Service '},
#     {'id': '756d70aa-44f0-4308-97b2-23e5ecc8e685',
#      'name': 'Korea Environmental Industry and Technology Institute'},
#     {'id': 'ebd2c214-c074-493c-9343-810480f6c415',
#      'name': 'Korea Hydrographic and Oceanographic Agency'},
#     {'id': '5d337db3-6d1e-4a44-b9fa-3ebf864abc9a',
#      'name': 'Korea Institute of Ocean Science and Technology'},
#     {'id': 'd743ba4c-0edb-406e-9acd-fce555075e5f',
#      'name': 'Kuwait Institute for Scientific Research'},
#     {'id': 'd43a450f-af6e-4897-bea7-18393ca4a0bb',
#      'name': 'Laboratoire d’Études en Géophysique et Océanographie Spatiales'},
#     {'id': '52780556-7ac3-4a28-9d31-cdcf34ad774d',
#      'name': 'Land and Surveys Division, Hydrographic Unit '},
#     {'id': '457ae516-bb95-4d55-852a-ecbe3b3dec93',
#      'name': 'Land Information New Zealand'},
#     {'id': 'e424b5a6-363e-41de-8bb5-9078a3b4d916',
#      'name': 'Malaysian Meteorological Department '},
#     {'id': '0e6b763b-cadb-4a89-b1df-54f6efb79f30',
#      'name': 'Maldives Meteorological Department'},
#     {'id': 'cfa6574e-a9ee-4644-ae9f-01eacd2e2ad1',
#      'name': 'Marine Hydrophysical Institute'},
#     {'id': 'db97521d-882e-4341-b33d-0d041c46fd43',
#      'name': 'Marine Institute Ireland'},
#     {'id': '1b92580a-3516-405f-bead-47c1803a3ab1',
#      'name': 'Maritime and Port Authority of Singapore'},
#     {'id': '67943bf1-fe92-4ff0-9160-9f20e716522b',
#      'name': 'Mauritius Meteorological Service'},
#     {'id': '33f9b6d3-b3e5-4f57-ad56-31fa73133de8',
#      'name': 'Meteorological Department Curaçao'},
#     {'id': '50dc0760-ef9a-4c7f-928d-763d8773d447',
#      'name': 'Meteorological Services Division '},
#     {'id': 'f05d8ccb-ae3b-4fa5-9bac-4d04e14b9f1a',
#      'name': 'Ministerio de Medio Ambiente y Recursos Naturales'},
#     {'id': '411e5450-c9c8-46ec-8742-97395d715a82',
#      'name': 'Ministry of Maritime Affairs and Fisheries'},
#     {'id': 'a86c459b-d40d-4d0e-99ce-7124147fe17f',
#      'name': 'Ministry of the Environment and Forests'},
#     {'id': '1e56a5b9-1ed1-4244-9541-b4b5abd2419a',
#      'name': 'Namibian Ports Authority'},
#     {'id': '6b9c3e4c-3377-4f9c-bf91-3428755af3b0',
#      'name': 'National Antarctic Scientific Centre'},
#     {'id': '1949a285-45e2-4e06-b48b-48e8e2625242',
#      'name': 'National Aquatic Resources Research and Development Agency'},
#     {'id': 'a51d5bee-f831-4fbd-a713-980f1511cbe7',
#      'name': 'National Centre for Geophysical Research'},
#     {'id': 'a2db9c4d-b53e-4c30-a649-8114c843a8ca',
#      'name': 'National Centre for Hydro-Meteorological Forecasting'},
#     {'id': '22089f4d-0aae-4504-98ca-091fce701c15',
#      'name': 'National Emergency Management Agency'},
#     {'id': 'ae32d18f-949f-49c6-aeeb-341303aeca07',
#      'name': 'National Emergency Management Organization'},
#     {'id': '8ad447bf-6b3a-4f69-bd56-c2b64c46c368',
#      'name': 'National Institute for Earth Physics'},
#     {'id': '0b151f18-f2a1-40e5-9061-e745d38ab070',
#      'name': 'National Institute for Marine Research and Development \\'},
#     {'id': '4ba664d0-7203-4e1b-8d7a-b26b3cb58a5b',
#      'name': 'National Institute of Oceanography and Fisheries'},
#     {'id': 'bd5ad050-7234-4943-a645-59de1cdc8b68',
#      'name': 'National Mapping and Resource Information Authority'},
#     {'id': 'ba2d5a80-2115-48d4-ab34-79a7ab184de9',
#      'name': 'National Meteorological Service of Belize'},
#     {'id': '803f6c1f-3e0f-48d0-848d-0a5e1991d40e',
#      'name': 'National Observatory of Athens'},
#     {'id': '6923fede-4539-4752-bf22-5167cc6b1d21',
#      'name': 'National Oceanography Centre'},
#     {'id': '0dcf2e65-3adc-4c75-9c0e-3d4f90d1994e',
#      'name': 'National Technical University of Athens'},
#     {'id': '91a11f06-270d-49ee-b377-e131872c5963',
#      'name': 'Navy Hydrography Center - Marine Meteorological Service'},
#     {'id': '1f305515-cf98-47f3-8a91-e65af401a6d6',
#      'name': 'Nigerian Institute for Oceanography and Marine Research'},
#     {'id': '6f10ef5a-c443-4258-89de-b30c115bb80a',
#      'name': 'NOAA National Ocean Service'},
#     {'id': '44fb70e2-c583-4190-8848-6e68254328b4',
#      'name': 'Norwegian Hydrographic Service'},
#     {'id': '58bc6a1b-9e1a-4647-a388-d15722206dd6',
#      'name': 'Nouakchott Autonomous Port'},
#     {'id': 'c0e4d3bb-45a3-43af-a2de-276f8963a889', 'name': 'OceanWise'},
#     {'id': 'f2c85c6f-bd8d-4591-bd14-ce553be59d7e',
#      'name': 'Office National de la Météorologie'},
#     {'id': 'a2e86a11-f888-421e-a153-e43b40b927bd',
#      'name': 'Office of Public Works'},
#     {'id': 'dc65650c-f511-4b7a-9654-65d1c40a753a',
#      'name': 'Office of the Port Director'},
#     {'id': '6891ab99-ead6-41fb-8696-00ad2ca6fb94',
#      'name': 'Pacific Tsunami Warning Center'},
#     {'id': '41645580-745d-4b6f-b579-4647db4ce319',
#      'name': 'Pakistan Navy Hydrographic Department'},
#     {'id': 'fa052542-a89f-4c52-be76-c1b0459f6231',
#      'name': 'Port Autonome de Pointe Noire'},
#     {'id': '90ec36d7-ca40-43bb-a1b6-871a64d67c32', 'name': 'Port of Djibouti'},
#     {'id': '3a36de47-307b-461e-8dff-41e60139cfd5',
#      'name': 'Portuguese Institute of the Sea and Atmosphere'},
#     {'id': '98198a7e-b5cf-4e06-8849-31ebec3d760a',
#      'name': "Principauté de Monaco - Direction de l'Environnement "},
#     {'id': '7e189b4d-0d69-4b3c-8cb2-058cd0da2e0e',
#      'name': 'Puerto Rico Seismic Network '},
#     {'id': 'a0a3927d-3856-4299-9355-d34177e8d079',
#      'name': 'Puertos del Estado'},
#     {'id': 'b5ec7737-ae89-4c97-bb65-c8001906d015', 'name': 'Rijkswaterstaat'},
#     {'id': 'e66caf75-a2fc-4274-81e0-361ba3e592d4', 'name': 'Royal Thai Navy '},
#     {'id': '6d617a67-454b-4807-97f3-50ddc22de89e',
#      'name': 'Saint Lucia Meteorological Services'},
#     {'id': '8a080edf-e880-417a-b2b3-252a57f32a5a',
#      'name': 'SARAO Hartebeesthoek Radio Astronomy Observatory'},
#     {'id': '2aeabf5f-7c8e-4369-80a2-4cbd24e3ac0a',
#      'name': 'Service Hydrographique et Océanographique de la Marine'},
#     {'id': 'c07ae62f-1895-46d4-acc2-f9f4edce01f4',
#      'name': 'Service Maritime et de Navigation d´Haiti'},
#     {'id': 'a4d31b03-af3f-446b-982b-fbc8fd8f1fca',
#      'name': 'Servicio de Hidrografía Naval'},
#     {'id': '9b155b46-5c1f-490f-97f4-76af6a57c1b0',
#      'name': 'Servicio Hidrográfico y Oceanográfico de la Armada'},
#     {'id': 'db9c0e0a-3edd-4706-8ef8-68c94ed1b2eb',
#      'name': 'Seychelles National Meteorological Services'},
#     {'id': 'f65bc9c4-ce62-4447-868f-ccb0636ca655',
#      'name': 'Smithsonian Marine Station'},
#     {'id': '76e04f62-55c3-4313-a2c0-cf2a421e1b9f',
#      'name': 'Smithsonian Tropical Research Institute'},
#     {'id': 'd52bd888-03d9-467f-9cc6-e6f02ddb52b6',
#      'name': 'Societé National de Raffinage'},
#     {'id': '27a7eaa8-7064-4de5-94c1-83ab8c89b8f3',
#      'name': 'South African Hydrographic Office'},
#     {'id': '83dbf2f4-263d-4b95-b4bf-a91e524d4bfa',
#      'name': 'Standing Committee on Contingencies'},
#     {'id': 'c438d5bc-a07d-423d-93bf-2f662b36d0b2',
#      'name': 'State Meteorological Agency'},
#     {'id': 'e32438a4-00cd-4111-b6b8-d555752d614d',
#      'name': 'Survey of Bangladesh, Ministry of Defense'},
#     {'id': '380d26ea-9429-4ef1-be20-8443e8ae2e9d',
#      'name': 'Swedish Maritime Administration'},
#     {'id': 'b71e35b1-ad8a-4b79-8d2f-e2a062f452aa',
#      'name': 'Swedish Meteorological and Hydrological Institute'},
#     {'id': '46234de8-bcc0-466e-9dc6-4a9195319745',
#      'name': 'Tanzania Ports Authority'},
#     {'id': '0a0012d5-9254-41fb-b866-d0797cebd7eb',
#      'name': 'The Centre De Recherches Océanographiques De Dakar-Thiaroye'},
#     {'id': '7d155087-c72d-4c5f-92d9-ddb29fed285f',
#      'name': 'The Federal Waterways and Shipping Administration'},
#     {'id': '69f10b6a-102b-4538-8bab-c25110377359', 'name': 'UNAVCO'},
#     {'id': '28d76651-a004-457a-ae04-5e00e66616f1',
#      'name': 'United Kingdom Hydrographic Office'},
#     {'id': '06a811c9-1989-438c-90e3-4b612a92e2f4',
#      'name': 'Universidad Nacional Autónoma de México'},
#     {'id': '8c6b8eb8-fef6-43e1-89e9-3a4f9f58fe53',
#      'name': 'Universidad Nacional Costa Rica, SINAMOT '},
#     {'id': '7b8499b1-1ce1-4645-a64a-90a7afa35ea4',
#      'name': 'University of French Polynesia'},
#     {'id': 'e0a182fa-d38f-4754-9758-a9a586671f35',
#      'name': 'University of Hawaii Sea Level Center '},
#     {'id': '75d2c2ff-7060-4f43-8a47-5ef4342f73f6',
#      'name': 'University of Malta'},
#     {'id': 'ff24fdde-9055-4bbe-820b-6f078f98dfae',
#      'name': 'University of Puerto Rico'},
#     {'id': 'dc9ba6d3-8358-403e-90a4-5e65ab21646a',
#      'name': 'University of the Balearic Islands'},
#     {'id': '3f624220-f687-4a10-aaaa-b2ef327e39b5',
#      'name': 'Yap Weather Service Office'},
#     {'id': '753d2cb1-0abc-4f82-b735-bef3b373dc6d',
#      'name': 'Yemen Gulf of Aden Ports Corporation'},
#     {'id': '6b1c2b93-3596-4c8c-98a5-d84b0030a51c',
#      'name': 'Yildiz Technical University'}],
#    'name': 'organisations'},
#   {'name': 'sciencedomains'},
#   {'name': 'servicetypes'}],
#  'results': {'distributions': [{'availableFormats': [{'format': 'application/vnd.ogc.wms_xml',
#       'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/b44828ed-02c5-4aa8-a7ec-f61cd492b170',
#       'label': 'WMS',
#       'originalFormat': 'image/gif',
#       'type': 'ORIGINAL'},
#      {'format': 'application/vnd.ogc.wms_xml',
#       'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/b44828ed-02c5-4aa8-a7ec-f61cd492b170',
#       'label': 'WMS',
#       'originalFormat': 'image/png',
#       'type': 'ORIGINAL'},
#      {'format': 'application/vnd.ogc.wms_xml',
#       'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/b44828ed-02c5-4aa8-a7ec-f61cd492b170',
#       'label': 'WMS',
#       'originalFormat': 'image/vnd.jpeg-png',
#       'type': 'ORIGINAL'}],
#     'dataServiceProvider': {'dataProviderLegalName': 'VLIZ - Vlaams Insitituut voor de Zee',
#      'dataProviderUrl': 'https://www.vliz.be/',
#      'instanceid': '39eb54f7-9536-40d6-91fc-b10379aa1ac0'},
#     'description': 'This WMS layer allows adding the the station-list into OGC compliant GIS tools. The list of dataproviders can be found on http://www.ioc-sealevelmonitoring.org',
#     'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/b44828ed-02c5-4aa8-a7ec-f61cd492b170',
#     'hrefExtended': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/b44828ed-02c5-4aa8-a7ec-f61cd492b170?extended=true',
#     'id': 'b44828ed-02c5-4aa8-a7ec-f61cd492b170',
#     'metaId': '7dcbb90a-a550-4f10-afd2-4075696a0241',
#     'status': 1,
#     'statusTimestamp': '2026-05-01T10:44:07Z',
#     'statusURL': 'https://epos-services.vm.fedcloud.eu/monitoring/?sha=5ca80ce5ff9ca89f6ca17d9e1c699a1871e0e0ea28baf6654ef03e4dab52f715',
#     'title': 'IOC Sealevel Monitoring Station List (as OGC WMS layer)',
#     'uid': 'file:///sealevels_dist_stations_wms'}]}}

# %%
num_result = len(filtered_data['results']['distributions'])
num_result
# Out:
# 1

# %% [markdown]
# It returned only one result

# %% [markdown]
# ### Get the data
#
# The user get the data of the resource from the source. Before he get from the EPOS API the url of the original resource, then he queries the service to get the actual data.
# In our case we want to select the image/png available format.

# %%
details_sealevel_result = requests.get(api_url + '/resources/details/' + filtered_data['results']['distributions'][0]['id'])
json_sealevel_result = details_sealevel_result.json()
json_sealevel_result
# Out:
# {'accessRights': 'https://publications.europa.eu/resource/authority/access-right/PUBLIC',
#  'availableContactPoints': [{'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=b44828ed-02c5-4aa8-a7ec-f61cd492b170&contactType=SERVICEPROVIDERS',
#    'type': 'SERVICEPROVIDERS'},
#   {'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=b44828ed-02c5-4aa8-a7ec-f61cd492b170&contactType=DATAPROVIDERS',
#    'type': 'DATAPROVIDERS'},
#   {'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=b44828ed-02c5-4aa8-a7ec-f61cd492b170&contactType=ALL',
#    'type': 'ALL'}],
#  'availableFormats': [{'format': 'application/vnd.ogc.wms_xml',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/b44828ed-02c5-4aa8-a7ec-f61cd492b170',
#    'label': 'WMS',
#    'originalFormat': 'image/png',
#    'type': 'ORIGINAL'},
#   {'format': 'application/vnd.ogc.wms_xml',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/b44828ed-02c5-4aa8-a7ec-f61cd492b170',
#    'label': 'WMS',
#    'originalFormat': 'image/vnd.jpeg-png',
#    'type': 'ORIGINAL'},
#   {'format': 'application/vnd.ogc.wms_xml',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/b44828ed-02c5-4aa8-a7ec-f61cd492b170',
#    'label': 'WMS',
#    'originalFormat': 'image/gif',
#    'type': 'ORIGINAL'}],
#  'categories': {'children': [{'children': [{'ddss': 'category:tsunamidata',
#       'name': 'Tsunami Data'}],
#     'code': 'TSU',
#     'color': '#6f9ea8',
#     'id': '10',
#     'imgUrl': 'assets/img/logo/TSU_logo.png',
#     'linkUrl': 'https://www.epos-eu.org/tcs/tsunami',
#     'name': 'Tsunami'}],
#   'name': 'domains'},
#  'dataProvider': [{'country': 'BE',
#    'dataProviderLegalName': 'VLIZ - Vlaams Insitituut voor de Zee',
#    'dataProviderUrl': 'https://www.vliz.be/',
#    'instanceid': '39eb54f7-9536-40d6-91fc-b10379aa1ac0',
#    'metaid': '39eb54f7-9536-40d6-91fc-b10379aa1ac0',
#    'relatedDataServiceProvider': [{'country': 'SN',
#      'dataProviderLegalName': "Agence Nationale de l'Aviation Civile et de la Météorologie",
#      'dataProviderUrl': 'http://www.anacim.sn/',
#      'instanceid': '0200add1-f171-4999-8bf7-7f350809a86a',
#      'metaid': '0200add1-f171-4999-8bf7-7f350809a86a',
#      'uid': '0200add1-f171-4999-8bf7-7f350809a86a'},
#     {'country': 'ID',
#      'dataProviderLegalName': 'Agency for Meteorology, Climatology and Geophysics',
#      'dataProviderUrl': 'https://www.bmkg.go.id/',
#      'instanceid': '4d4e0fb1-26dc-4366-bafc-139aa22d0e9a',
#      'metaid': '4d4e0fb1-26dc-4366-bafc-139aa22d0e9a',
#      'uid': '4d4e0fb1-26dc-4366-bafc-139aa22d0e9a'},
#     {'country': 'BE',
#      'dataProviderLegalName': 'Agentschap voor Maritieme Dienstverlening en Kust',
#      'dataProviderUrl': 'www.agentschapmdk.be/',
#      'instanceid': '2f215737-c37a-4e94-9f7e-348c2be26048',
#      'metaid': '2f215737-c37a-4e94-9f7e-348c2be26048',
#      'uid': '2f215737-c37a-4e94-9f7e-348c2be26048'},
#     {'country': 'AI',
#      'dataProviderLegalName': 'Anguilla Department of Disaster Management',
#      'dataProviderUrl': 'https://www.gov.ai/ministry/he-the-governor/disaster-management',
#      'instanceid': 'dec769d3-351e-49ac-a092-6cbcfaa74d85',
#      'metaid': 'dec769d3-351e-49ac-a092-6cbcfaa74d85',
#      'uid': 'dec769d3-351e-49ac-a092-6cbcfaa74d85'},
#     {'country': 'AG',
#      'dataProviderLegalName': 'Antigua & Barbuda Meteorological Services',
#      'dataProviderUrl': 'https://www.antiguamet.com/',
#      'instanceid': '3e886457-fa9d-4939-af68-a0dee4e4253f',
#      'metaid': '3e886457-fa9d-4939-af68-a0dee4e4253f',
#      'uid': '3e886457-fa9d-4939-af68-a0dee4e4253f'},
#     {'country': 'JO',
#      'dataProviderLegalName': 'Aqaba Marine Reserve, Research and studies division',
#      'dataProviderUrl': 'https://aseza.jo/Default/Ar',
#      'instanceid': '24ecce21-5edf-4a62-aebf-937f1876914d',
#      'metaid': '24ecce21-5edf-4a62-aebf-937f1876914d',
#      'uid': '24ecce21-5edf-4a62-aebf-937f1876914d'},
#     {'country': 'TH',
#      'dataProviderLegalName': 'Asian Disaster Preparedness Center',
#      'dataProviderUrl': 'https://www.adpc.net/',
#      'instanceid': '6816c63e-f62e-47da-b403-cbf17e75b62f',
#      'metaid': '6816c63e-f62e-47da-b403-cbf17e75b62f',
#      'uid': '6816c63e-f62e-47da-b403-cbf17e75b62f'},
#     {'country': 'BS',
#      'dataProviderLegalName': 'Bahamas Department of Meteorology',
#      'dataProviderUrl': 'https://met.gov.bs/',
#      'instanceid': '0f924035-9a78-49fc-a3bb-ce2563c9921f',
#      'metaid': '0f924035-9a78-49fc-a3bb-ce2563c9921f',
#      'uid': '0f924035-9a78-49fc-a3bb-ce2563c9921f'},
#     {'country': 'BD',
#      'dataProviderLegalName': 'Bangladesh Navy Hydrographic & Oceanographic Center',
#      'dataProviderUrl': 'http://bnhoc.navy.mil.bd/',
#      'instanceid': '66bf9c5b-2953-48d0-beec-cd7829102915',
#      'metaid': '66bf9c5b-2953-48d0-beec-cd7829102915',
#      'uid': '66bf9c5b-2953-48d0-beec-cd7829102915'},
#     {'country': 'BB',
#      'dataProviderLegalName': 'Barbados Meteorological Services',
#      'dataProviderUrl': 'https://agriculture.gov.bb/Departments/Meteorological-Services',
#      'instanceid': 'a99f69db-ca6d-44cc-b49c-d864a17c6d4e',
#      'metaid': 'a99f69db-ca6d-44cc-b49c-d864a17c6d4e',
#      'uid': 'a99f69db-ca6d-44cc-b49c-d864a17c6d4e'},
#     {'country': 'BR',
#      'dataProviderLegalName': 'Brazilian Coastal Monitoring System',
#      'dataProviderUrl': 'https://simcosta.furg.br/home',
#      'instanceid': '19bbd88e-9ea2-4324-b37b-e578fc4fbe85',
#      'metaid': '19bbd88e-9ea2-4324-b37b-e578fc4fbe85',
#      'uid': '19bbd88e-9ea2-4324-b37b-e578fc4fbe85'},
#     {'country': 'BR',
#      'dataProviderLegalName': 'Brazilian Institute of Geography and Statistics',
#      'dataProviderUrl': 'https://www.ibge.gov.br/en/home-eng.html',
#      'instanceid': 'c509c831-a85b-402e-8bbd-78f45fd01a93',
#      'metaid': 'c509c831-a85b-402e-8bbd-78f45fd01a93',
#      'uid': 'c509c831-a85b-402e-8bbd-78f45fd01a93'},
#     {'country': 'GB',
#      'dataProviderLegalName': 'British Antarctic Survey',
#      'dataProviderUrl': 'https://www.bas.ac.uk/',
#      'instanceid': '426fc9a8-a673-4bb0-87c5-8b80fb792bb8',
#      'metaid': '426fc9a8-a673-4bb0-87c5-8b80fb792bb8',
#      'uid': '426fc9a8-a673-4bb0-87c5-8b80fb792bb8'},
#     {'country': 'AU',
#      'dataProviderLegalName': 'Bureau of Meteorology',
#      'dataProviderUrl': 'http://www.bom.gov.au/',
#      'instanceid': 'ead9cdf6-268c-4da5-8f15-d445777e4159',
#      'metaid': 'ead9cdf6-268c-4da5-8f15-d445777e4159',
#      'uid': 'ead9cdf6-268c-4da5-8f15-d445777e4159'},
#     {'country': 'CR',
#      'dataProviderLegalName': 'Campbell Scientific',
#      'dataProviderUrl': 'https://www.campbellsci.cc/',
#      'instanceid': 'c4557b41-a3c8-47b5-9034-0bf32359dfb4',
#      'metaid': 'c4557b41-a3c8-47b5-9034-0bf32359dfb4',
#      'uid': 'c4557b41-a3c8-47b5-9034-0bf32359dfb4'},
#     {'country': 'BZ',
#      'dataProviderLegalName': 'Caribbean Community Climate Change Centre',
#      'dataProviderUrl': 'https://caribbeanclimate.org/',
#      'instanceid': 'e34ad7e3-566b-4142-ad6c-6017dd108cc5',
#      'metaid': 'e34ad7e3-566b-4142-ad6c-6017dd108cc5',
#      'uid': 'e34ad7e3-566b-4142-ad6c-6017dd108cc5'},
#     {'country': 'BB',
#      'dataProviderLegalName': 'Caribbean Institute for Meteorology and Hydrology',
#      'dataProviderUrl': 'https://www.cimh.edu.bb/',
#      'instanceid': '6ed3cf2f-5e3d-426c-862f-2ec388aa464d',
#      'metaid': '6ed3cf2f-5e3d-426c-862f-2ec388aa464d',
#      'uid': '6ed3cf2f-5e3d-426c-862f-2ec388aa464d'},
#     {'country': 'NI',
#      'dataProviderLegalName': 'Central American Tsunami Advisory Center',
#      'dataProviderUrl': 'http://catac.ineter.gob.ni/',
#      'instanceid': '572ee01a-0d5c-496d-8cec-64dc8a46745c',
#      'metaid': '572ee01a-0d5c-496d-8cec-64dc8a46745c',
#      'uid': '572ee01a-0d5c-496d-8cec-64dc8a46745c'},
#     {'country': 'TW',
#      'dataProviderLegalName': 'Central Weather Administration',
#      'dataProviderUrl': 'https://www.cwa.gov.tw/eng/',
#      'instanceid': '596f81d1-7c01-4e5d-88b0-c7ed63ed75a0',
#      'metaid': '596f81d1-7c01-4e5d-88b0-c7ed63ed75a0',
#      'uid': '596f81d1-7c01-4e5d-88b0-c7ed63ed75a0'},
#     {'country': 'MA',
#      'dataProviderLegalName': 'Centre National pour la Recherche Scientifique et Technique',
#      'dataProviderUrl': 'https://www.cnrst.ma',
#      'instanceid': '7fc3ae6c-1d94-4c7c-b053-dbc29855ab2c',
#      'metaid': '7fc3ae6c-1d94-4c7c-b053-dbc29855ab2c',
#      'uid': '7fc3ae6c-1d94-4c7c-b053-dbc29855ab2c'},
#     {'country': 'GB',
#      'dataProviderLegalName': 'Channel Coastal Observatory',
#      'dataProviderUrl': 'https://coastalmonitoring.org/',
#      'instanceid': 'c1bdba4d-33ee-4fd5-92fb-9605cd32e51a',
#      'metaid': 'c1bdba4d-33ee-4fd5-92fb-9605cd32e51a',
#      'uid': 'c1bdba4d-33ee-4fd5-92fb-9605cd32e51a'},
#     {'country': 'CN',
#      'dataProviderLegalName': 'China Meteorological Administration',
#      'dataProviderUrl': 'http://www.cma.gov.cn/en2014/',
#      'instanceid': '3916baec-f6b0-43af-a1d0-af07ab0907b1',
#      'metaid': '3916baec-f6b0-43af-a1d0-af07ab0907b1',
#      'uid': '3916baec-f6b0-43af-a1d0-af07ab0907b1'},
#     {'country': 'OM',
#      'dataProviderLegalName': 'Civil Aviation Authority',
#      'dataProviderUrl': 'https://met.caa.gov.om/',
#      'instanceid': '2360212a-caea-40da-9198-44b6d5cafd6a',
#      'metaid': '2360212a-caea-40da-9198-44b6d5cafd6a',
#      'uid': '2360212a-caea-40da-9198-44b6d5cafd6a'},
#     {'country': 'BB',
#      'dataProviderLegalName': 'Coastal Zone Management Unit',
#      'dataProviderUrl': 'www.coastal.gov.bb/',
#      'instanceid': '866de5f8-c3fe-4c73-a1b0-484bb7bf6171',
#      'metaid': '866de5f8-c3fe-4c73-a1b0-484bb7bf6171',
#      'uid': '866de5f8-c3fe-4c73-a1b0-484bb7bf6171'},
#     {'country': 'MF',
#      'dataProviderLegalName': 'Collectivité de Saint-Martin',
#      'dataProviderUrl': 'https://www.comstmartin.fr/en',
#      'instanceid': '728ede5c-2768-4ce1-b04d-8313d0513c6c',
#      'metaid': '728ede5c-2768-4ce1-b04d-8313d0513c6c',
#      'uid': '728ede5c-2768-4ce1-b04d-8313d0513c6c'},
#     {'country': 'MQ',
#      'dataProviderLegalName': 'Collectivité Territoriale de Martinique ',
#      'dataProviderUrl': 'https://www.collectivitedemartinique.mq/',
#      'instanceid': 'a4774898-8b8d-431c-ac67-6cec6a487a9c',
#      'metaid': 'a4774898-8b8d-431c-ac67-6cec6a487a9c',
#      'uid': 'a4774898-8b8d-431c-ac67-6cec6a487a9c'},
#     {'country': 'FR',
#      'dataProviderLegalName': "Commissariat à l'énergie atomique et aux énergies alternatives",
#      'dataProviderUrl': 'https://www.cea.fr/',
#      'instanceid': '88d4a20e-00e1-46fe-b234-40def12a4562',
#      'metaid': '88d4a20e-00e1-46fe-b234-40def12a4562',
#      'uid': '88d4a20e-00e1-46fe-b234-40def12a4562'},
#     {'country': 'CY',
#      'dataProviderLegalName': 'Cyprus Marine and Maritime Institute',
#      'dataProviderUrl': 'https://www.cmmi.blue/',
#      'instanceid': 'da1dd02e-a7b2-4d44-8880-c27153f59848',
#      'metaid': 'da1dd02e-a7b2-4d44-8880-c27153f59848',
#      'uid': 'da1dd02e-a7b2-4d44-8880-c27153f59848'},
#     {'country': 'CY',
#      'dataProviderLegalName': 'Cyprus Oceanography Center',
#      'dataProviderUrl': 'https://www.ucy.ac.cy/oceanography/',
#      'instanceid': '535d1d6f-85b5-4366-aee4-5f439f80a10c',
#      'metaid': '535d1d6f-85b5-4366-aee4-5f439f80a10c',
#      'uid': '535d1d6f-85b5-4366-aee4-5f439f80a10c'},
#     {'country': 'CY',
#      'dataProviderLegalName': 'Cyprus University of Technology',
#      'dataProviderUrl': 'https://www.cut.ac.cy/',
#      'instanceid': '24e22407-39eb-42f5-b749-8d41fc5c5f0a',
#      'metaid': '24e22407-39eb-42f5-b749-8d41fc5c5f0a',
#      'uid': '24e22407-39eb-42f5-b749-8d41fc5c5f0a'},
#     {'country': 'DK',
#      'dataProviderLegalName': 'Danish Meteorological Institute',
#      'dataProviderUrl': 'www.dmi.dk',
#      'instanceid': 'df920615-0936-4d90-bc8b-ea6c1e52d757',
#      'metaid': 'df920615-0936-4d90-bc8b-ea6c1e52d757',
#      'uid': 'df920615-0936-4d90-bc8b-ea6c1e52d757'},
#     {'country': 'AW',
#      'dataProviderLegalName': 'Departamento Meteorologico Aruba',
#      'dataProviderUrl': 'https://www.meteo.aw/',
#      'instanceid': '41205828-d402-41f8-a8b3-482c50866f5e',
#      'metaid': '41205828-d402-41f8-a8b3-482c50866f5e',
#      'uid': '41205828-d402-41f8-a8b3-482c50866f5e'},
#     {'country': 'IE',
#      'dataProviderLegalName': 'Department of Agriculture Food and the Marine',
#      'dataProviderUrl': 'http://www.agriculture.gov.ie/',
#      'instanceid': '0d79fb4b-5042-4a11-a0ea-a3b7046c781a',
#      'metaid': '0d79fb4b-5042-4a11-a0ea-a3b7046c781a',
#      'uid': '0d79fb4b-5042-4a11-a0ea-a3b7046c781a'},
#     {'country': 'TC',
#      'dataProviderLegalName': 'Department of Disaster Management and Emergencies',
#      'dataProviderUrl': 'https://www.gov.tc/ddme/',
#      'instanceid': '3fa7b0d0-183b-4bb6-b6d8-3d9e86bce21a',
#      'metaid': '3fa7b0d0-183b-4bb6-b6d8-3d9e86bce21a',
#      'uid': '3fa7b0d0-183b-4bb6-b6d8-3d9e86bce21a'},
#     {'country': 'IT',
#      'dataProviderLegalName': 'Department of Earth and Environmental Sciences',
#      'dataProviderUrl': 'https://www.uniba.it/it/ricerca/dipartimenti/geo',
#      'instanceid': '54a4c6ce-cc0b-4cfb-a2b5-b708c2fff1ee',
#      'metaid': '54a4c6ce-cc0b-4cfb-a2b5-b708c2fff1ee',
#      'uid': '54a4c6ce-cc0b-4cfb-a2b5-b708c2fff1ee'},
#     {'country': 'CA',
#      'dataProviderLegalName': 'Department of Fisheries and Oceans',
#      'dataProviderUrl': 'www.dfo-mpo.gc.ca/',
#      'instanceid': 'c2f8e230-760c-4c3e-91cd-6824b0b80c2b',
#      'metaid': 'c2f8e230-760c-4c3e-91cd-6824b0b80c2b',
#      'uid': 'c2f8e230-760c-4c3e-91cd-6824b0b80c2b'},
#     {'country': 'VU',
#      'dataProviderLegalName': 'Department of Geology, Mines and Water Resources',
#      'dataProviderUrl': 'https://mol.gov.vu/index.php/geology-mines',
#      'instanceid': '26f0102a-ef37-42d8-b738-689771d23c65',
#      'metaid': '26f0102a-ef37-42d8-b738-689771d23c65',
#      'uid': '26f0102a-ef37-42d8-b738-689771d23c65'},
#     {'country': 'TZ',
#      'dataProviderLegalName': 'Department of Land and Survey',
#      'dataProviderUrl': 'https://www.lands.go.tz/',
#      'instanceid': '82c7094a-f04e-4ad6-96d0-a1bbbac4402f',
#      'metaid': '82c7094a-f04e-4ad6-96d0-a1bbbac4402f',
#      'uid': '82c7094a-f04e-4ad6-96d0-a1bbbac4402f'},
#     {'country': 'MM',
#      'dataProviderLegalName': 'Department of Meteorology and Hydrology',
#      'dataProviderUrl': 'https://www.moezala.gov.mm/',
#      'instanceid': '94b5e23a-90fb-44e6-8e0a-20d57a5fa1b6',
#      'metaid': '94b5e23a-90fb-44e6-8e0a-20d57a5fa1b6',
#      'uid': '94b5e23a-90fb-44e6-8e0a-20d57a5fa1b6'},
#     {'country': 'IT',
#      'dataProviderLegalName': 'Department of Physics and Astronomy \\',
#      'dataProviderUrl': 'https://fisica-astronomia.unibo.it/it',
#      'instanceid': 'e500b315-c009-4f7a-8fcf-d919d83e8b73',
#      'metaid': 'e500b315-c009-4f7a-8fcf-d919d83e8b73',
#      'uid': 'e500b315-c009-4f7a-8fcf-d919d83e8b73'},
#     {'country': 'KY',
#      'dataProviderLegalName': 'Department of Public Safety Communications',
#      'dataProviderUrl': 'https://www.gov.ky/mha/PSC',
#      'instanceid': '56c24be2-8f81-4cde-9805-2c5805591a53',
#      'metaid': '56c24be2-8f81-4cde-9805-2c5805591a53',
#      'uid': '56c24be2-8f81-4cde-9805-2c5805591a53'},
#     {'country': 'MY',
#      'dataProviderLegalName': 'Department of Survey and Mapping',
#      'dataProviderUrl': 'http://www.jupem.gov.my/',
#      'instanceid': 'fe837c94-aeae-4d8c-b22b-2f3e070a5dca',
#      'metaid': 'fe837c94-aeae-4d8c-b22b-2f3e070a5dca',
#      'uid': 'fe837c94-aeae-4d8c-b22b-2f3e070a5dca'},
#     {'country': 'GM',
#      'dataProviderLegalName': 'Department of Water Resources',
#      'dataProviderUrl': 'https://meteogambia.gm/',
#      'instanceid': 'dab31325-aa55-4374-b431-745cf909886c',
#      'metaid': 'dab31325-aa55-4374-b431-745cf909886c',
#      'uid': 'dab31325-aa55-4374-b431-745cf909886c'},
#     {'country': 'PE',
#      'dataProviderLegalName': 'Dirección de Hidrografía y Navegación',
#      'dataProviderUrl': 'https://www.dhn.mil.pe/portal/',
#      'instanceid': '8e509953-a7db-47a6-bd73-bb6834a87ea5',
#      'metaid': '8e509953-a7db-47a6-bd73-bb6834a87ea5',
#      'uid': '8e509953-a7db-47a6-bd73-bb6834a87ea5'},
#     {'country': 'CO',
#      'dataProviderLegalName': 'Dirección General Marítima',
#      'dataProviderUrl': 'https://www.dimar.mil.co',
#      'instanceid': '0e9c9770-d007-4d5c-b702-eb7bcf49b130',
#      'metaid': '0e9c9770-d007-4d5c-b702-eb7bcf49b130',
#      'uid': '0e9c9770-d007-4d5c-b702-eb7bcf49b130'},
#     {'country': 'FR',
#      'dataProviderLegalName': "Direction des Territoires, de l'Alimentation et de la Mer à Saint-Pierre-et-Miquelon",
#      'dataProviderUrl': 'https://www.saint-pierre-et-miquelon.developpement-durable.gouv.fr/',
#      'instanceid': 'ab332117-a09d-47a7-8d09-96d4e8942a3d',
#      'metaid': 'ab332117-a09d-47a7-8d09-96d4e8942a3d',
#      'uid': 'ab332117-a09d-47a7-8d09-96d4e8942a3d'},
#     {'country': 'MG',
#      'dataProviderLegalName': 'Direction Générale de la Météorologie',
#      'dataProviderUrl': 'https://www.meteomadagascar.mg/meteo-madagascar/organisations/',
#      'instanceid': 'dd233310-6f33-4c63-82af-3146279b5380',
#      'metaid': 'dd233310-6f33-4c63-82af-3146279b5380',
#      'uid': 'dd233310-6f33-4c63-82af-3146279b5380'},
#     {'country': 'OM',
#      'dataProviderLegalName': 'Directorate General Meteorology and Air Navigation',
#      'dataProviderUrl': 'https://met.gov.om/opencms/export/sites/default/dgman/en/about-us/',
#      'instanceid': '8782a90d-0812-44ef-bc3c-7184b91bbc1d',
#      'metaid': '8782a90d-0812-44ef-bc3c-7184b91bbc1d',
#      'uid': '8782a90d-0812-44ef-bc3c-7184b91bbc1d'},
#     {'country': 'DM',
#      'dataProviderLegalName': 'Dominica Meteorological Service',
#      'dataProviderUrl': 'https://weather.ictu.gov.dm/index.php?lang=en',
#      'instanceid': '05b5245f-5531-41fc-8121-471ffc8286c3',
#      'metaid': '05b5245f-5531-41fc-8121-471ffc8286c3',
#      'uid': '05b5245f-5531-41fc-8121-471ffc8286c3'},
#     {'country': 'DK',
#      'dataProviderLegalName': 'DTU Space',
#      'dataProviderUrl': 'https://www.space.dtu.dk/english',
#      'instanceid': '434cf708-2af8-4a54-9e01-ea925daa0633',
#      'metaid': '434cf708-2af8-4a54-9e01-ea925daa0633',
#      'uid': '434cf708-2af8-4a54-9e01-ea925daa0633'},
#     {'country': 'BR',
#      'dataProviderLegalName': 'Empresa de pesquisa agropecuária e extensão rural de Santa Catarina',
#      'dataProviderUrl': 'http://www.epagri.sc.gov.br/',
#      'instanceid': '26ed110b-933f-4336-8d46-786798c3862e',
#      'metaid': '26ed110b-933f-4336-8d46-786798c3862e',
#      'uid': '26ed110b-933f-4336-8d46-786798c3862e'},
#     {'country': 'MX',
#      'dataProviderLegalName': 'Ensenada Center for Scientific Research and Higher Education',
#      'dataProviderUrl': 'www.cicese.edu.mx/',
#      'instanceid': 'b856b792-336b-4802-9e66-2345636d8063',
#      'metaid': 'b856b792-336b-4802-9e66-2345636d8063',
#      'uid': 'b856b792-336b-4802-9e66-2345636d8063'},
#     {'country': 'HR',
#      'dataProviderLegalName': 'Faculty of Science; Department of Geophysics',
#      'dataProviderUrl': 'https://www.pmf.unizg.hr/geof/en',
#      'instanceid': '641be6f0-3f12-4f06-9778-4909094abae6',
#      'metaid': '641be6f0-3f12-4f06-9778-4909094abae6',
#      'uid': '641be6f0-3f12-4f06-9778-4909094abae6'},
#     {'country': 'RU',
#      'dataProviderLegalName': 'Federal Service of Russia for Hydrometeorology and Environmental Monitoring',
#      'dataProviderUrl': 'https://meteoinfo.ru/en/about-us-eng',
#      'instanceid': '936f47ac-9ef0-4aea-87ac-947eb2f92357',
#      'metaid': '936f47ac-9ef0-4aea-87ac-947eb2f92357',
#      'uid': '936f47ac-9ef0-4aea-87ac-947eb2f92357'},
#     {'country': 'FJ',
#      'dataProviderLegalName': 'Fiji Meteorological Service',
#      'dataProviderUrl': 'https://www.met.gov.fj/',
#      'instanceid': '6efd6267-d7f8-4020-b585-a387d7d2947b',
#      'metaid': '6efd6267-d7f8-4020-b585-a387d7d2947b',
#      'uid': '6efd6267-d7f8-4020-b585-a387d7d2947b'},
#     {'country': 'TR',
#      'dataProviderLegalName': 'General Directorate of Mapping',
#      'dataProviderUrl': 'https://www.harita.gov.tr/',
#      'instanceid': '51b7e4d3-1537-42e8-972e-c9d5f73c89be',
#      'metaid': '51b7e4d3-1537-42e8-972e-c9d5f73c89be',
#      'uid': '51b7e4d3-1537-42e8-972e-c9d5f73c89be'},
#     {'country': 'ID',
#      'dataProviderLegalName': 'Geospatial Information Agency',
#      'dataProviderUrl': 'https://www.big.go.id/',
#      'instanceid': '8917c90b-bbde-4a83-9689-19613ba4cd1a',
#      'metaid': '8917c90b-bbde-4a83-9689-19613ba4cd1a',
#      'uid': '8917c90b-bbde-4a83-9689-19613ba4cd1a'},
#     {'country': 'DE',
#      'dataProviderLegalName': 'German Research Centre for Geosciences',
#      'dataProviderUrl': 'https://www.gfz-potsdam.de/',
#      'instanceid': '45c80521-8caf-414f-936f-8aff6bab9d84',
#      'metaid': '45c80521-8caf-414f-936f-8aff6bab9d84',
#      'uid': '45c80521-8caf-414f-936f-8aff6bab9d84'},
#     {'country': 'NZ',
#      'dataProviderLegalName': 'GNS Science',
#      'dataProviderUrl': 'https://gns.cri.nz/',
#      'instanceid': '1be088aa-e39b-40ab-b3f0-d0c476540ffd',
#      'metaid': '1be088aa-e39b-40ab-b3f0-d0c476540ffd',
#      'uid': '1be088aa-e39b-40ab-b3f0-d0c476540ffd'},
#     {'country': 'US',
#      'dataProviderLegalName': 'Goddard Earth Science and Technology Center',
#      'dataProviderUrl': 'https://gestar2.umbc.edu/',
#      'instanceid': '33ff3ab5-7102-42d0-95a3-6507efba3924',
#      'metaid': '33ff3ab5-7102-42d0-95a3-6507efba3924',
#      'uid': '33ff3ab5-7102-42d0-95a3-6507efba3924'},
#     {'country': 'PK',
#      'dataProviderLegalName': 'Gwadar Port Authority and Hydrographic Department',
#      'dataProviderUrl': 'https://gwadarport.gov.pk/',
#      'instanceid': '30dd3d3f-5ec1-44d7-bab7-36539a1bc32b',
#      'metaid': '30dd3d3f-5ec1-44d7-bab7-36539a1bc32b',
#      'uid': '30dd3d3f-5ec1-44d7-bab7-36539a1bc32b'},
#     {'country': 'KY',
#      'dataProviderLegalName': 'Hazard Management Cayman Islands',
#      'dataProviderUrl': 'https://www.caymanprepared.ky/',
#      'instanceid': 'de6cc860-e4a2-4170-9c1d-fd71c305270f',
#      'metaid': 'de6cc860-e4a2-4170-9c1d-fd71c305270f',
#      'uid': 'de6cc860-e4a2-4170-9c1d-fd71c305270f'},
#     {'country': 'GR',
#      'dataProviderLegalName': 'Hellenic Navy Hydrographic Service',
#      'dataProviderUrl': 'https://hnhs.gr/en/',
#      'instanceid': 'ebdb5ac5-9672-4c51-ba14-250e7940d71a',
#      'metaid': 'ebdb5ac5-9672-4c51-ba14-250e7940d71a',
#      'uid': 'ebdb5ac5-9672-4c51-ba14-250e7940d71a'},
#     {'country': 'HK',
#      'dataProviderLegalName': 'Hong Kong Observatory',
#      'dataProviderUrl': 'https://www.hko.gov.hk/en/index.html',
#      'instanceid': 'bdcd0f53-ee85-4761-b0cd-406bbab16e06',
#      'metaid': 'bdcd0f53-ee85-4761-b0cd-406bbab16e06',
#      'uid': 'bdcd0f53-ee85-4761-b0cd-406bbab16e06'},
#     {'country': 'IR',
#      'dataProviderLegalName': 'Hydrographic Department of the National Cartographic Center',
#      'dataProviderUrl': 'https://en.ncc.gov.ir/',
#      'instanceid': '7593cc12-1628-44ef-8fb4-0db340787e5e',
#      'metaid': '7593cc12-1628-44ef-8fb4-0db340787e5e',
#      'uid': '7593cc12-1628-44ef-8fb4-0db340787e5e'},
#     {'country': 'IS',
#      'dataProviderLegalName': 'Icelandic Coast Guard Hydrographic Department',
#      'dataProviderUrl': 'https://www.lhg.is/english/hydrographic-department/',
#      'instanceid': '2cf3e168-aaac-4ec5-9a64-49ae445a0e3e',
#      'metaid': '2cf3e168-aaac-4ec5-9a64-49ae445a0e3e',
#      'uid': '2cf3e168-aaac-4ec5-9a64-49ae445a0e3e'},
#     {'country': 'IN',
#      'dataProviderLegalName': 'Indian National Centre for Ocean Information Services',
#      'dataProviderUrl': 'www.incois.gov.in',
#      'instanceid': '391fb269-5224-45cf-9bb8-5f1b8c8ec1de',
#      'metaid': '391fb269-5224-45cf-9bb8-5f1b8c8ec1de',
#      'uid': '391fb269-5224-45cf-9bb8-5f1b8c8ec1de'},
#     {'country': 'DE',
#      'dataProviderLegalName': 'Informationstechnikzentrum Bund',
#      'dataProviderUrl': 'https://www.itzbund.de/DE/home/home_node.html',
#      'instanceid': '0e623238-c67b-419a-a044-f76bf708195f',
#      'metaid': '0e623238-c67b-419a-a044-f76bf708195f',
#      'uid': '0e623238-c67b-419a-a044-f76bf708195f'},
#     {'country': 'FR',
#      'dataProviderLegalName': 'Institut de Physique du Globe de Paris',
#      'dataProviderUrl': 'beaufix.ipgp.jussieu.fr',
#      'instanceid': '45e0745f-e20c-403b-b51e-1f1d6b2cdbc3',
#      'metaid': '45e0745f-e20c-403b-b51e-1f1d6b2cdbc3',
#      'uid': '45e0745f-e20c-403b-b51e-1f1d6b2cdbc3'},
#     {'country': 'FR',
#      'dataProviderLegalName': 'Institut de Recherche pour le Développement',
#      'dataProviderUrl': 'www.ird.fr',
#      'instanceid': '083fe3a5-a40e-4bc8-bf6d-cd7bc1ac9bbd',
#      'metaid': '083fe3a5-a40e-4bc8-bf6d-cd7bc1ac9bbd',
#      'uid': '083fe3a5-a40e-4bc8-bf6d-cd7bc1ac9bbd'},
#     {'country': 'HR',
#      'dataProviderLegalName': 'Institute of Oceanography and Fisheries',
#      'dataProviderUrl': 'www.izor.hr',
#      'instanceid': '110366de-a42a-4a1e-b7fc-98eb3e9be2c0',
#      'metaid': '110366de-a42a-4a1e-b7fc-98eb3e9be2c0',
#      'uid': '110366de-a42a-4a1e-b7fc-98eb3e9be2c0'},
#     {'country': 'PA',
#      'dataProviderLegalName': 'Instituto de Geociencias- Universidad de Panamá',
#      'dataProviderUrl': 'https://geociencias.up.ac.pa/',
#      'instanceid': 'd8572372-f510-4155-9861-bdd5acb84640',
#      'metaid': 'd8572372-f510-4155-9861-bdd5acb84640',
#      'uid': 'd8572372-f510-4155-9861-bdd5acb84640'},
#     {'country': 'DO',
#      'dataProviderLegalName': 'Instituto Dominicano De Meteorología',
#      'dataProviderUrl': 'https://indomet.gob.do/',
#      'instanceid': '872f8ceb-e9fc-449b-93a0-9b0c76d6cf2c',
#      'metaid': '872f8ceb-e9fc-449b-93a0-9b0c76d6cf2c',
#      'uid': '872f8ceb-e9fc-449b-93a0-9b0c76d6cf2c'},
#     {'country': 'ES',
#      'dataProviderLegalName': 'Instituto Español de Oceanografía',
#      'dataProviderUrl': 'www.ieo.es',
#      'instanceid': '1153f8e9-111d-4069-b9b7-08dd4d7a4e83',
#      'metaid': '1153f8e9-111d-4069-b9b7-08dd4d7a4e83',
#      'uid': '1153f8e9-111d-4069-b9b7-08dd4d7a4e83'},
#     {'country': 'ES',
#      'dataProviderLegalName': 'Instituto Geográfico Nacional',
#      'dataProviderUrl': 'http://www.ign.es',
#      'instanceid': 'fca09163-1a85-46b6-b71a-3513daf506d1',
#      'metaid': 'fca09163-1a85-46b6-b71a-3513daf506d1',
#      'uid': 'fca09163-1a85-46b6-b71a-3513daf506d1'},
#     {'country': 'PT',
#      'dataProviderLegalName': 'Instituto Geográfico Português',
#      'dataProviderUrl': 'https://www.dgterritorio.gov.pt',
#      'instanceid': 'edcb9e30-66ae-4aec-a510-3b1451cda4fd',
#      'metaid': 'edcb9e30-66ae-4aec-a510-3b1451cda4fd',
#      'uid': 'edcb9e30-66ae-4aec-a510-3b1451cda4fd'},
#     {'country': 'PT',
#      'dataProviderLegalName': 'Instituto Hidrográfico',
#      'dataProviderUrl': 'https://hidrografico.pt',
#      'instanceid': '70ece37d-f7ca-476b-afb7-11c747bad786',
#      'metaid': '70ece37d-f7ca-476b-afb7-11c747bad786',
#      'uid': '70ece37d-f7ca-476b-afb7-11c747bad786'},
#     {'country': 'MZ',
#      'dataProviderLegalName': 'Instituto Nacional de Hidrografia e Navegação',
#      'dataProviderUrl': 'https://www.mtc.gov.mz/',
#      'instanceid': 'bb55c40d-dbae-4ba1-b2f0-8f47b232e022',
#      'metaid': 'bb55c40d-dbae-4ba1-b2f0-8f47b232e022',
#      'uid': 'bb55c40d-dbae-4ba1-b2f0-8f47b232e022'},
#     {'country': 'CV',
#      'dataProviderLegalName': 'Instituto Nacional de Meteorologia e Geofisica de Cabo Verde',
#      'dataProviderUrl': 'https://www.inmg.gov.cv/',
#      'instanceid': '94203546-1692-4884-8e9f-fea535e85fe5',
#      'metaid': '94203546-1692-4884-8e9f-fea535e85fe5',
#      'uid': '94203546-1692-4884-8e9f-fea535e85fe5'},
#     {'country': 'GT',
#      'dataProviderLegalName': 'Instituto Nacional de Sismología, Vulcanología, Meteorología e Hidrología',
#      'dataProviderUrl': 'https://insivumeh.gob.gt/',
#      'instanceid': '0dd39b1a-f6c0-48ee-8fbe-f721e7f481a1',
#      'metaid': '0dd39b1a-f6c0-48ee-8fbe-f721e7f481a1',
#      'uid': '0dd39b1a-f6c0-48ee-8fbe-f721e7f481a1'},
#     {'country': 'NI',
#      'dataProviderLegalName': 'Instituto Nicaragüense de Estudios Territoriales',
#      'dataProviderUrl': 'https://www.ineter.gob.ni/',
#      'instanceid': '3c27ba63-5559-41bf-8561-141182231e5c',
#      'metaid': '3c27ba63-5559-41bf-8561-141182231e5c',
#      'uid': '3c27ba63-5559-41bf-8561-141182231e5c'},
#     {'country': 'EC',
#      'dataProviderLegalName': 'Instituto Oceanografico de la Armada',
#      'dataProviderUrl': 'www.inocar.mil.ec',
#      'instanceid': 'b2c3f06a-4808-4cbc-8b33-caec989ea6aa',
#      'metaid': 'b2c3f06a-4808-4cbc-8b33-caec989ea6aa',
#      'uid': 'b2c3f06a-4808-4cbc-8b33-caec989ea6aa'},
#     {'country': 'PR',
#      'dataProviderLegalName': 'International Tsunami Information Center Caribbean Office',
#      'dataProviderUrl': 'https://www.tsunami.gov/?page=itic',
#      'instanceid': 'c25d1b58-3628-4635-aa9e-face2925cc6c',
#      'metaid': 'c25d1b58-3628-4635-aa9e-face2925cc6c',
#      'uid': 'c25d1b58-3628-4635-aa9e-face2925cc6c'},
#     {'country': 'IL',
#      'dataProviderLegalName': 'Israel Oceanographic and Limnological Research Ltd.',
#      'dataProviderUrl': 'www.ocean.org.il/MainPageEng.asp',
#      'instanceid': '3b174da1-397f-454f-9f2d-5092c9630258',
#      'metaid': '3b174da1-397f-454f-9f2d-5092c9630258',
#      'uid': '3b174da1-397f-454f-9f2d-5092c9630258'},
#     {'country': 'IT',
#      'dataProviderLegalName': 'Istituto Nazionale di Geofisica e Vulcanologia',
#      'dataProviderUrl': 'www.ingv.it',
#      'instanceid': 'cd67d432-19c3-4aea-bc0a-985835170ea4',
#      'metaid': 'cd67d432-19c3-4aea-bc0a-985835170ea4',
#      'uid': 'cd67d432-19c3-4aea-bc0a-985835170ea4'},
#     {'country': 'IT',
#      'dataProviderLegalName': 'Italian National Institute for Environmental Protection and Research',
#      'dataProviderUrl': 'https://www.isprambiente.gov.it/it',
#      'instanceid': '98425ed6-c64e-4c9f-809b-78842d0c7d31',
#      'metaid': '98425ed6-c64e-4c9f-809b-78842d0c7d31',
#      'uid': '98425ed6-c64e-4c9f-809b-78842d0c7d31'},
#     {'country': 'JM',
#      'dataProviderLegalName': 'Jamaican Meteorological Service',
#      'dataProviderUrl': 'https://metservice.gov.jm/',
#      'instanceid': '5c597fc3-b2a9-4f88-9d57-dfab75a297cc',
#      'metaid': '5c597fc3-b2a9-4f88-9d57-dfab75a297cc',
#      'uid': '5c597fc3-b2a9-4f88-9d57-dfab75a297cc'},
#     {'country': 'JP',
#      'dataProviderLegalName': 'Japan Coast Guard',
#      'dataProviderUrl': 'https://www.kaiho.mlit.go.jp',
#      'instanceid': '7fd88c71-a843-4ef4-a1c3-4584ce650e32',
#      'metaid': '7fd88c71-a843-4ef4-a1c3-4584ce650e32',
#      'uid': '7fd88c71-a843-4ef4-a1c3-4584ce650e32'},
#     {'country': 'JP',
#      'dataProviderLegalName': 'Japan Meteorological Agency',
#      'dataProviderUrl': 'https://www.jma.go.jp/jma/indexe.html',
#      'instanceid': '2909a39c-1fc7-4e8c-a12b-2908a9f7fb07',
#      'metaid': '2909a39c-1fc7-4e8c-a12b-2908a9f7fb07',
#      'uid': '2909a39c-1fc7-4e8c-a12b-2908a9f7fb07'},
#     {'country': 'BE',
#      'dataProviderLegalName': 'Joint Research Centre',
#      'dataProviderUrl': 'https://ec.europa.eu/jrc/en',
#      'instanceid': '99503c17-0675-4958-80e0-81bcaa7eca5a',
#      'metaid': '99503c17-0675-4958-80e0-81bcaa7eca5a',
#      'uid': '99503c17-0675-4958-80e0-81bcaa7eca5a'},
#     {'country': 'TR',
#      'dataProviderLegalName': 'Kandilli Observatory and Earthquake Research Institute',
#      'dataProviderUrl': 'http://www.koeri.boun.edu.tr/new/',
#      'instanceid': '7fe6ca51-a2d3-4821-9d0f-cfa9944fb9ee',
#      'metaid': '7fe6ca51-a2d3-4821-9d0f-cfa9944fb9ee',
#      'uid': '7fe6ca51-a2d3-4821-9d0f-cfa9944fb9ee'},
#     {'country': 'PK',
#      'dataProviderLegalName': 'Karachi Port Trust',
#      'dataProviderUrl': 'https://kpt.gov.pk/',
#      'instanceid': 'cd2e6d4f-fcf0-4217-bb12-8b0840216de4',
#      'metaid': 'cd2e6d4f-fcf0-4217-bb12-8b0840216de4',
#      'uid': 'cd2e6d4f-fcf0-4217-bb12-8b0840216de4'},
#     {'country': 'KE',
#      'dataProviderLegalName': 'Kenya Marine and Fisheries Research Institute Mombasa Centre',
#      'dataProviderUrl': 'www.kmfri.co.ke/',
#      'instanceid': '9db2eeca-516a-4b93-8972-a84b0662c9c0',
#      'metaid': '9db2eeca-516a-4b93-8972-a84b0662c9c0',
#      'uid': '9db2eeca-516a-4b93-8972-a84b0662c9c0'},
#     {'country': 'KI',
#      'dataProviderLegalName': 'Kiribati Meteorological Service ',
#      'dataProviderUrl': 'https://www.met.gov.ki/',
#      'instanceid': '1bcc5657-068a-465e-9698-fd5e5b5b0348',
#      'metaid': '1bcc5657-068a-465e-9698-fd5e5b5b0348',
#      'uid': '1bcc5657-068a-465e-9698-fd5e5b5b0348'},
#     {'country': 'KR',
#      'dataProviderLegalName': 'Korea Environmental Industry and Technology Institute',
#      'dataProviderUrl': 'https://www.keiti.re.kr/site/eng/main.do',
#      'instanceid': '756d70aa-44f0-4308-97b2-23e5ecc8e685',
#      'metaid': '756d70aa-44f0-4308-97b2-23e5ecc8e685',
#      'uid': '756d70aa-44f0-4308-97b2-23e5ecc8e685'},
#     {'country': 'KR',
#      'dataProviderLegalName': 'Korea Hydrographic and Oceanographic Agency',
#      'dataProviderUrl': 'https://www.khoa.go.kr',
#      'instanceid': 'ebd2c214-c074-493c-9343-810480f6c415',
#      'metaid': 'ebd2c214-c074-493c-9343-810480f6c415',
#      'uid': 'ebd2c214-c074-493c-9343-810480f6c415'},
#     {'country': 'KR',
#      'dataProviderLegalName': 'Korea Institute of Ocean Science and Technology',
#      'dataProviderUrl': 'http://eng.kiost.ac/',
#      'instanceid': '5d337db3-6d1e-4a44-b9fa-3ebf864abc9a',
#      'metaid': '5d337db3-6d1e-4a44-b9fa-3ebf864abc9a',
#      'uid': '5d337db3-6d1e-4a44-b9fa-3ebf864abc9a'},
#     {'country': 'KW',
#      'dataProviderLegalName': 'Kuwait Institute for Scientific Research',
#      'dataProviderUrl': 'https://www.kisr.edu.kw/en/',
#      'instanceid': 'd743ba4c-0edb-406e-9acd-fce555075e5f',
#      'metaid': 'd743ba4c-0edb-406e-9acd-fce555075e5f',
#      'uid': 'd743ba4c-0edb-406e-9acd-fce555075e5f'},
#     {'country': 'FR',
#      'dataProviderLegalName': 'Laboratoire d’Études en Géophysique et Océanographie Spatiales',
#      'dataProviderUrl': 'https://www.legos.omp.eu',
#      'instanceid': 'd43a450f-af6e-4897-bea7-18393ca4a0bb',
#      'metaid': 'd43a450f-af6e-4897-bea7-18393ca4a0bb',
#      'uid': 'd43a450f-af6e-4897-bea7-18393ca4a0bb'},
#     {'country': 'TT',
#      'dataProviderLegalName': 'Land and Surveys Division, Hydrographic Unit ',
#      'dataProviderUrl': 'https://agriculture.gov.tt/divisions-units/divisions/survey-mapping/archiving-of-hydrographic-charts/',
#      'instanceid': '52780556-7ac3-4a28-9d31-cdcf34ad774d',
#      'metaid': '52780556-7ac3-4a28-9d31-cdcf34ad774d',
#      'uid': '52780556-7ac3-4a28-9d31-cdcf34ad774d'},
#     {'country': 'NZ',
#      'dataProviderLegalName': 'Land Information New Zealand',
#      'dataProviderUrl': 'https://www.linz.govt.nz/',
#      'instanceid': '457ae516-bb95-4d55-852a-ecbe3b3dec93',
#      'metaid': '457ae516-bb95-4d55-852a-ecbe3b3dec93',
#      'uid': '457ae516-bb95-4d55-852a-ecbe3b3dec93'},
#     {'country': 'MY',
#      'dataProviderLegalName': 'Malaysian Meteorological Department ',
#      'dataProviderUrl': 'https://www.met.gov.my/en/',
#      'instanceid': 'e424b5a6-363e-41de-8bb5-9078a3b4d916',
#      'metaid': 'e424b5a6-363e-41de-8bb5-9078a3b4d916',
#      'uid': 'e424b5a6-363e-41de-8bb5-9078a3b4d916'},
#     {'country': 'MV',
#      'dataProviderLegalName': 'Maldives Meteorological Department',
#      'dataProviderUrl': 'https://www.meteorology.gov.mv/',
#      'instanceid': '0e6b763b-cadb-4a89-b1df-54f6efb79f30',
#      'metaid': '0e6b763b-cadb-4a89-b1df-54f6efb79f30',
#      'uid': '0e6b763b-cadb-4a89-b1df-54f6efb79f30'},
#     {'country': 'UA',
#      'dataProviderLegalName': 'Marine Hydrophysical Institute',
#      'dataProviderUrl': 'www.mhi.iuf.net',
#      'instanceid': 'cfa6574e-a9ee-4644-ae9f-01eacd2e2ad1',
#      'metaid': 'cfa6574e-a9ee-4644-ae9f-01eacd2e2ad1',
#      'uid': 'cfa6574e-a9ee-4644-ae9f-01eacd2e2ad1'},
#     {'country': 'IE',
#      'dataProviderLegalName': 'Marine Institute Ireland',
#      'dataProviderUrl': 'www.marine.ie/home',
#      'instanceid': 'db97521d-882e-4341-b33d-0d041c46fd43',
#      'metaid': 'db97521d-882e-4341-b33d-0d041c46fd43',
#      'uid': 'db97521d-882e-4341-b33d-0d041c46fd43'},
#     {'country': 'SG',
#      'dataProviderLegalName': 'Maritime and Port Authority of Singapore',
#      'dataProviderUrl': 'http://www.mpa.gov.sg/',
#      'instanceid': '1b92580a-3516-405f-bead-47c1803a3ab1',
#      'metaid': '1b92580a-3516-405f-bead-47c1803a3ab1',
#      'uid': '1b92580a-3516-405f-bead-47c1803a3ab1'},
#     {'country': 'MU',
#      'dataProviderLegalName': 'Mauritius Meteorological Service',
#      'dataProviderUrl': 'http://metservice.intnet.mu/',
#      'instanceid': '67943bf1-fe92-4ff0-9160-9f20e716522b',
#      'metaid': '67943bf1-fe92-4ff0-9160-9f20e716522b',
#      'uid': '67943bf1-fe92-4ff0-9160-9f20e716522b'},
#     {'country': 'AN',
#      'dataProviderLegalName': 'Meteorological Department Curaçao',
#      'dataProviderUrl': 'https://www.meteo.cw/',
#      'instanceid': '33f9b6d3-b3e5-4f57-ad56-31fa73133de8',
#      'metaid': '33f9b6d3-b3e5-4f57-ad56-31fa73133de8',
#      'uid': '33f9b6d3-b3e5-4f57-ad56-31fa73133de8'},
#     {'country': 'SG',
#      'dataProviderLegalName': 'Meteorological Services Division ',
#      'dataProviderUrl': 'https://www.nea.gov.sg/corporate-functions/who-we-are/groups-and-divisions/meteorological-service-singapore-divisions',
#      'instanceid': '50dc0760-ef9a-4c7f-928d-763d8773d447',
#      'metaid': '50dc0760-ef9a-4c7f-928d-763d8773d447',
#      'uid': '50dc0760-ef9a-4c7f-928d-763d8773d447'},
#     {'country': 'SV',
#      'dataProviderLegalName': 'Ministerio de Medio Ambiente y Recursos Naturales',
#      'dataProviderUrl': 'https://www.marn.gob.sv',
#      'instanceid': 'f05d8ccb-ae3b-4fa5-9bac-4d04e14b9f1a',
#      'metaid': 'f05d8ccb-ae3b-4fa5-9bac-4d04e14b9f1a',
#      'uid': 'f05d8ccb-ae3b-4fa5-9bac-4d04e14b9f1a'},
#     {'country': 'ID',
#      'dataProviderLegalName': 'Ministry of Maritime Affairs and Fisheries',
#      'dataProviderUrl': 'https://www.kkp.go.id/',
#      'instanceid': '411e5450-c9c8-46ec-8742-97395d715a82',
#      'metaid': '411e5450-c9c8-46ec-8742-97395d715a82',
#      'uid': '411e5450-c9c8-46ec-8742-97395d715a82'},
#     {'country': 'RO',
#      'dataProviderLegalName': 'Ministry of the Environment and Forests',
#      'dataProviderUrl': 'https://mmediu.ro/',
#      'instanceid': 'a86c459b-d40d-4d0e-99ce-7124147fe17f',
#      'metaid': 'a86c459b-d40d-4d0e-99ce-7124147fe17f',
#      'uid': 'a86c459b-d40d-4d0e-99ce-7124147fe17f'},
#     {'country': 'NA',
#      'dataProviderLegalName': 'Namibian Ports Authority',
#      'dataProviderUrl': 'https://www.namport.com.na/',
#      'instanceid': '1e56a5b9-1ed1-4244-9541-b4b5abd2419a',
#      'metaid': '1e56a5b9-1ed1-4244-9541-b4b5abd2419a',
#      'uid': '1e56a5b9-1ed1-4244-9541-b4b5abd2419a'},
#     {'country': 'UA',
#      'dataProviderLegalName': 'National Antarctic Scientific Centre',
#      'dataProviderUrl': 'http://uac.gov.ua/',
#      'instanceid': '6b9c3e4c-3377-4f9c-bf91-3428755af3b0',
#      'metaid': '6b9c3e4c-3377-4f9c-bf91-3428755af3b0',
#      'uid': '6b9c3e4c-3377-4f9c-bf91-3428755af3b0'},
#     {'country': 'LK',
#      'dataProviderLegalName': 'National Aquatic Resources Research and Development Agency',
#      'dataProviderUrl': 'http://www.nara.ac.lk/',
#      'instanceid': '1949a285-45e2-4e06-b48b-48e8e2625242',
#      'metaid': '1949a285-45e2-4e06-b48b-48e8e2625242',
#      'uid': '1949a285-45e2-4e06-b48b-48e8e2625242'},
#     {'country': 'LB',
#      'dataProviderLegalName': 'National Centre for Geophysical Research',
#      'dataProviderUrl': 'https://www.cnrs.edu.lb/site/SubPage.aspx?pageid=59',
#      'instanceid': 'a51d5bee-f831-4fbd-a713-980f1511cbe7',
#      'metaid': 'a51d5bee-f831-4fbd-a713-980f1511cbe7',
#      'uid': 'a51d5bee-f831-4fbd-a713-980f1511cbe7'},
#     {'country': 'VN',
#      'dataProviderLegalName': 'National Centre for Hydro-Meteorological Forecasting',
#      'dataProviderUrl': 'https://www.nchmf.gov.vn/KttvsiteE/en-US/2/index.html',
#      'instanceid': 'a2db9c4d-b53e-4c30-a649-8114c843a8ca',
#      'metaid': 'a2db9c4d-b53e-4c30-a649-8114c843a8ca',
#      'uid': 'a2db9c4d-b53e-4c30-a649-8114c843a8ca'},
#     {'country': 'KN',
#      'dataProviderLegalName': 'National Emergency Management Agency',
#      'dataProviderUrl': 'https://www.nema.kn/',
#      'instanceid': '22089f4d-0aae-4504-98ca-091fce701c15',
#      'metaid': '22089f4d-0aae-4504-98ca-091fce701c15',
#      'uid': '22089f4d-0aae-4504-98ca-091fce701c15'},
#     {'country': 'VC',
#      'dataProviderLegalName': 'National Emergency Management Organization',
#      'dataProviderUrl': 'https://nemo.gov.vc/nemo/',
#      'instanceid': 'ae32d18f-949f-49c6-aeeb-341303aeca07',
#      'metaid': 'ae32d18f-949f-49c6-aeeb-341303aeca07',
#      'uid': 'ae32d18f-949f-49c6-aeeb-341303aeca07'},
#     {'country': 'RO',
#      'dataProviderLegalName': 'National Institute for Earth Physics',
#      'dataProviderUrl': 'https://infp.ro/',
#      'instanceid': '8ad447bf-6b3a-4f69-bd56-c2b64c46c368',
#      'metaid': '8ad447bf-6b3a-4f69-bd56-c2b64c46c368',
#      'uid': '8ad447bf-6b3a-4f69-bd56-c2b64c46c368'},
#     {'country': 'RO',
#      'dataProviderLegalName': 'National Institute for Marine Research and Development \\',
#      'dataProviderUrl': 'www.rmri.ro',
#      'instanceid': '0b151f18-f2a1-40e5-9061-e745d38ab070',
#      'metaid': '0b151f18-f2a1-40e5-9061-e745d38ab070',
#      'uid': '0b151f18-f2a1-40e5-9061-e745d38ab070'},
#     {'country': 'EG',
#      'dataProviderLegalName': 'National Institute of Oceanography and Fisheries',
#      'dataProviderUrl': 'www.niof.sci.eg/',
#      'instanceid': '4ba664d0-7203-4e1b-8d7a-b26b3cb58a5b',
#      'metaid': '4ba664d0-7203-4e1b-8d7a-b26b3cb58a5b',
#      'uid': '4ba664d0-7203-4e1b-8d7a-b26b3cb58a5b'},
#     {'country': 'PH',
#      'dataProviderLegalName': 'National Mapping and Resource Information Authority',
#      'dataProviderUrl': 'https://www.namria.gov.ph/#gsc.tab=0',
#      'instanceid': 'bd5ad050-7234-4943-a645-59de1cdc8b68',
#      'metaid': 'bd5ad050-7234-4943-a645-59de1cdc8b68',
#      'uid': 'bd5ad050-7234-4943-a645-59de1cdc8b68'},
#     {'country': 'BZ',
#      'dataProviderLegalName': 'National Meteorological Service of Belize',
#      'dataProviderUrl': 'https://nms.gov.bz/',
#      'instanceid': 'ba2d5a80-2115-48d4-ab34-79a7ab184de9',
#      'metaid': 'ba2d5a80-2115-48d4-ab34-79a7ab184de9',
#      'uid': 'ba2d5a80-2115-48d4-ab34-79a7ab184de9'},
#     {'country': 'GR',
#      'dataProviderLegalName': 'National Observatory of Athens',
#      'dataProviderUrl': 'https://www.noa.gr/en/',
#      'instanceid': '803f6c1f-3e0f-48d0-848d-0a5e1991d40e',
#      'metaid': '803f6c1f-3e0f-48d0-848d-0a5e1991d40e',
#      'uid': '803f6c1f-3e0f-48d0-848d-0a5e1991d40e'},
#     {'country': 'GB',
#      'dataProviderLegalName': 'National Oceanography Centre',
#      'dataProviderUrl': 'www.noc.ac.uk/',
#      'instanceid': '6923fede-4539-4752-bf22-5167cc6b1d21',
#      'metaid': '6923fede-4539-4752-bf22-5167cc6b1d21',
#      'uid': '6923fede-4539-4752-bf22-5167cc6b1d21'},
#     {'country': 'GR',
#      'dataProviderLegalName': 'National Technical University of Athens',
#      'dataProviderUrl': 'www.ntua.gr',
#      'instanceid': '0dcf2e65-3adc-4c75-9c0e-3d4f90d1994e',
#      'metaid': '0dcf2e65-3adc-4c75-9c0e-3d4f90d1994e',
#      'uid': '0dcf2e65-3adc-4c75-9c0e-3d4f90d1994e'},
#     {'country': 'BR',
#      'dataProviderLegalName': 'Navy Hydrography Center - Marine Meteorological Service',
#      'dataProviderUrl': 'https://oceanexpert.org/institution/14418',
#      'instanceid': '91a11f06-270d-49ee-b377-e131872c5963',
#      'metaid': '91a11f06-270d-49ee-b377-e131872c5963',
#      'uid': '91a11f06-270d-49ee-b377-e131872c5963'},
#     {'country': 'NG',
#      'dataProviderLegalName': 'Nigerian Institute for Oceanography and Marine Research',
#      'dataProviderUrl': 'https://niomr.gov.ng/',
#      'instanceid': '1f305515-cf98-47f3-8a91-e65af401a6d6',
#      'metaid': '1f305515-cf98-47f3-8a91-e65af401a6d6',
#      'uid': '1f305515-cf98-47f3-8a91-e65af401a6d6'},
#     {'country': 'US',
#      'dataProviderLegalName': 'NOAA National Ocean Service',
#      'dataProviderUrl': 'https://oceanservice.noaa.gov/',
#      'instanceid': '6f10ef5a-c443-4258-89de-b30c115bb80a',
#      'metaid': '6f10ef5a-c443-4258-89de-b30c115bb80a',
#      'uid': '6f10ef5a-c443-4258-89de-b30c115bb80a'},
#     {'country': 'NO',
#      'dataProviderLegalName': 'Norwegian Hydrographic Service',
#      'dataProviderUrl': 'https://norway.cartography.no/governmental-institutions/hydrographic-service/',
#      'instanceid': '44fb70e2-c583-4190-8848-6e68254328b4',
#      'metaid': '44fb70e2-c583-4190-8848-6e68254328b4',
#      'uid': '44fb70e2-c583-4190-8848-6e68254328b4'},
#     {'country': 'MR',
#      'dataProviderLegalName': 'Nouakchott Autonomous Port',
#      'dataProviderUrl': 'http://www.port-nouakchott.com/fr',
#      'instanceid': '58bc6a1b-9e1a-4647-a388-d15722206dd6',
#      'metaid': '58bc6a1b-9e1a-4647-a388-d15722206dd6',
#      'uid': '58bc6a1b-9e1a-4647-a388-d15722206dd6'},
#     {'country': 'GB',
#      'dataProviderLegalName': 'OceanWise',
#      'dataProviderUrl': 'https://www.oceanwise.eu/',
#      'instanceid': 'c0e4d3bb-45a3-43af-a2de-276f8963a889',
#      'metaid': 'c0e4d3bb-45a3-43af-a2de-276f8963a889',
#      'uid': 'c0e4d3bb-45a3-43af-a2de-276f8963a889'},
#     {'country': 'MR',
#      'dataProviderLegalName': 'Office National de la Météorologie',
#      'dataProviderUrl': 'https://meteomauritanie.mr/',
#      'instanceid': 'f2c85c6f-bd8d-4591-bd14-ce553be59d7e',
#      'metaid': 'f2c85c6f-bd8d-4591-bd14-ce553be59d7e',
#      'uid': 'f2c85c6f-bd8d-4591-bd14-ce553be59d7e'},
#     {'country': 'IE',
#      'dataProviderLegalName': 'Office of Public Works',
#      'dataProviderUrl': 'https://www.gov.ie/en/organisation/office-of-public-works/',
#      'instanceid': 'a2e86a11-f888-421e-a153-e43b40b927bd',
#      'metaid': 'a2e86a11-f888-421e-a153-e43b40b927bd',
#      'uid': 'a2e86a11-f888-421e-a153-e43b40b927bd'},
#     {'country': 'US',
#      'dataProviderLegalName': 'Office of the Port Director',
#      'dataProviderUrl': 'https://cnmiports.com/',
#      'instanceid': 'dc65650c-f511-4b7a-9654-65d1c40a753a',
#      'metaid': 'dc65650c-f511-4b7a-9654-65d1c40a753a',
#      'uid': 'dc65650c-f511-4b7a-9654-65d1c40a753a'},
#     {'country': 'PR',
#      'dataProviderLegalName': 'Pacific Tsunami Warning Center',
#      'dataProviderUrl': 'https://www.weather.gov/safety/tsunami-twc',
#      'instanceid': '6891ab99-ead6-41fb-8696-00ad2ca6fb94',
#      'metaid': '6891ab99-ead6-41fb-8696-00ad2ca6fb94',
#      'uid': '6891ab99-ead6-41fb-8696-00ad2ca6fb94'},
#     {'country': 'PK',
#      'dataProviderLegalName': 'Pakistan Navy Hydrographic Department',
#      'dataProviderUrl': 'https://hydrography.paknavy.gov.pk/',
#      'instanceid': '41645580-745d-4b6f-b579-4647db4ce319',
#      'metaid': '41645580-745d-4b6f-b579-4647db4ce319',
#      'uid': '41645580-745d-4b6f-b579-4647db4ce319'},
#     {'country': 'CG',
#      'dataProviderLegalName': 'Port Autonome de Pointe Noire',
#      'dataProviderUrl': 'https://papn-cg.org/',
#      'instanceid': 'fa052542-a89f-4c52-be76-c1b0459f6231',
#      'metaid': 'fa052542-a89f-4c52-be76-c1b0459f6231',
#      'uid': 'fa052542-a89f-4c52-be76-c1b0459f6231'},
#     {'country': 'DJ',
#      'dataProviderLegalName': 'Port of Djibouti',
#      'dataProviderUrl': 'https://www.portdedjibouti.com/',
#      'instanceid': '90ec36d7-ca40-43bb-a1b6-871a64d67c32',
#      'metaid': '90ec36d7-ca40-43bb-a1b6-871a64d67c32',
#      'uid': '90ec36d7-ca40-43bb-a1b6-871a64d67c32'},
#     {'country': 'PT',
#      'dataProviderLegalName': 'Portuguese Institute of the Sea and Atmosphere',
#      'dataProviderUrl': 'https://www.ipma.pt/pt/',
#      'instanceid': '3a36de47-307b-461e-8dff-41e60139cfd5',
#      'metaid': '3a36de47-307b-461e-8dff-41e60139cfd5',
#      'uid': '3a36de47-307b-461e-8dff-41e60139cfd5'},
#     {'country': 'MC',
#      'dataProviderLegalName': "Principauté de Monaco - Direction de l'Environnement ",
#      'dataProviderUrl': 'https://www.gouv.mc/Gouvernement-et-Institutions/Le-Gouvernement/Departement-de-l-Equipement-de-l-Environnement-et-de-l-Urbanisme/Direction-de-l-Environnement',
#      'instanceid': '98198a7e-b5cf-4e06-8849-31ebec3d760a',
#      'metaid': '98198a7e-b5cf-4e06-8849-31ebec3d760a',
#      'uid': '98198a7e-b5cf-4e06-8849-31ebec3d760a'},
#     {'country': 'PR',
#      'dataProviderLegalName': 'Puerto Rico Seismic Network ',
#      'dataProviderUrl': 'https://redsismica.uprm.edu/index.php',
#      'instanceid': '7e189b4d-0d69-4b3c-8cb2-058cd0da2e0e',
#      'metaid': '7e189b4d-0d69-4b3c-8cb2-058cd0da2e0e',
#      'uid': '7e189b4d-0d69-4b3c-8cb2-058cd0da2e0e'},
#     {'country': 'ES',
#      'dataProviderLegalName': 'Puertos del Estado',
#      'dataProviderUrl': 'https://www.puertos.es/',
#      'instanceid': 'a0a3927d-3856-4299-9355-d34177e8d079',
#      'metaid': 'a0a3927d-3856-4299-9355-d34177e8d079',
#      'uid': 'a0a3927d-3856-4299-9355-d34177e8d079'},
#     {'country': 'NL',
#      'dataProviderLegalName': 'Rijkswaterstaat',
# ...
#    {'country': 'BR',
#     'dataProviderLegalName': 'Navy Hydrography Center - Marine Meteorological Service',
#     'dataProviderUrl': 'https://oceanexpert.org/institution/14418',
#     'instanceid': '91a11f06-270d-49ee-b377-e131872c5963',
#     'metaid': '91a11f06-270d-49ee-b377-e131872c5963',
#     'uid': '91a11f06-270d-49ee-b377-e131872c5963'},
#    {'country': 'NG',
#     'dataProviderLegalName': 'Nigerian Institute for Oceanography and Marine Research',
#     'dataProviderUrl': 'https://niomr.gov.ng/',
#     'instanceid': '1f305515-cf98-47f3-8a91-e65af401a6d6',
#     'metaid': '1f305515-cf98-47f3-8a91-e65af401a6d6',
#     'uid': '1f305515-cf98-47f3-8a91-e65af401a6d6'},
#    {'country': 'US',
#     'dataProviderLegalName': 'NOAA National Ocean Service',
#     'dataProviderUrl': 'https://oceanservice.noaa.gov/',
#     'instanceid': '6f10ef5a-c443-4258-89de-b30c115bb80a',
#     'metaid': '6f10ef5a-c443-4258-89de-b30c115bb80a',
#     'uid': '6f10ef5a-c443-4258-89de-b30c115bb80a'},
#    {'country': 'NO',
#     'dataProviderLegalName': 'Norwegian Hydrographic Service',
#     'dataProviderUrl': 'https://norway.cartography.no/governmental-institutions/hydrographic-service/',
#     'instanceid': '44fb70e2-c583-4190-8848-6e68254328b4',
#     'metaid': '44fb70e2-c583-4190-8848-6e68254328b4',
#     'uid': '44fb70e2-c583-4190-8848-6e68254328b4'},
#    {'country': 'MR',
#     'dataProviderLegalName': 'Nouakchott Autonomous Port',
#     'dataProviderUrl': 'http://www.port-nouakchott.com/fr',
#     'instanceid': '58bc6a1b-9e1a-4647-a388-d15722206dd6',
#     'metaid': '58bc6a1b-9e1a-4647-a388-d15722206dd6',
#     'uid': '58bc6a1b-9e1a-4647-a388-d15722206dd6'},
#    {'country': 'GB',
#     'dataProviderLegalName': 'OceanWise',
#     'dataProviderUrl': 'https://www.oceanwise.eu/',
#     'instanceid': 'c0e4d3bb-45a3-43af-a2de-276f8963a889',
#     'metaid': 'c0e4d3bb-45a3-43af-a2de-276f8963a889',
#     'uid': 'c0e4d3bb-45a3-43af-a2de-276f8963a889'},
#    {'country': 'MR',
#     'dataProviderLegalName': 'Office National de la Météorologie',
#     'dataProviderUrl': 'https://meteomauritanie.mr/',
#     'instanceid': 'f2c85c6f-bd8d-4591-bd14-ce553be59d7e',
#     'metaid': 'f2c85c6f-bd8d-4591-bd14-ce553be59d7e',
#     'uid': 'f2c85c6f-bd8d-4591-bd14-ce553be59d7e'},
#    {'country': 'IE',
#     'dataProviderLegalName': 'Office of Public Works',
#     'dataProviderUrl': 'https://www.gov.ie/en/organisation/office-of-public-works/',
#     'instanceid': 'a2e86a11-f888-421e-a153-e43b40b927bd',
#     'metaid': 'a2e86a11-f888-421e-a153-e43b40b927bd',
#     'uid': 'a2e86a11-f888-421e-a153-e43b40b927bd'},
#    {'country': 'US',
#     'dataProviderLegalName': 'Office of the Port Director',
#     'dataProviderUrl': 'https://cnmiports.com/',
#     'instanceid': 'dc65650c-f511-4b7a-9654-65d1c40a753a',
#     'metaid': 'dc65650c-f511-4b7a-9654-65d1c40a753a',
#     'uid': 'dc65650c-f511-4b7a-9654-65d1c40a753a'},
#    {'country': 'PR',
#     'dataProviderLegalName': 'Pacific Tsunami Warning Center',
#     'dataProviderUrl': 'https://www.weather.gov/safety/tsunami-twc',
#     'instanceid': '6891ab99-ead6-41fb-8696-00ad2ca6fb94',
#     'metaid': '6891ab99-ead6-41fb-8696-00ad2ca6fb94',
#     'uid': '6891ab99-ead6-41fb-8696-00ad2ca6fb94'},
#    {'country': 'PK',
#     'dataProviderLegalName': 'Pakistan Navy Hydrographic Department',
#     'dataProviderUrl': 'https://hydrography.paknavy.gov.pk/',
#     'instanceid': '41645580-745d-4b6f-b579-4647db4ce319',
#     'metaid': '41645580-745d-4b6f-b579-4647db4ce319',
#     'uid': '41645580-745d-4b6f-b579-4647db4ce319'},
#    {'country': 'CG',
#     'dataProviderLegalName': 'Port Autonome de Pointe Noire',
#     'dataProviderUrl': 'https://papn-cg.org/',
#     'instanceid': 'fa052542-a89f-4c52-be76-c1b0459f6231',
#     'metaid': 'fa052542-a89f-4c52-be76-c1b0459f6231',
#     'uid': 'fa052542-a89f-4c52-be76-c1b0459f6231'},
#    {'country': 'DJ',
#     'dataProviderLegalName': 'Port of Djibouti',
#     'dataProviderUrl': 'https://www.portdedjibouti.com/',
#     'instanceid': '90ec36d7-ca40-43bb-a1b6-871a64d67c32',
#     'metaid': '90ec36d7-ca40-43bb-a1b6-871a64d67c32',
#     'uid': '90ec36d7-ca40-43bb-a1b6-871a64d67c32'},
#    {'country': 'PT',
#     'dataProviderLegalName': 'Portuguese Institute of the Sea and Atmosphere',
#     'dataProviderUrl': 'https://www.ipma.pt/pt/',
#     'instanceid': '3a36de47-307b-461e-8dff-41e60139cfd5',
#     'metaid': '3a36de47-307b-461e-8dff-41e60139cfd5',
#     'uid': '3a36de47-307b-461e-8dff-41e60139cfd5'},
#    {'country': 'MC',
#     'dataProviderLegalName': "Principauté de Monaco - Direction de l'Environnement ",
#     'dataProviderUrl': 'https://www.gouv.mc/Gouvernement-et-Institutions/Le-Gouvernement/Departement-de-l-Equipement-de-l-Environnement-et-de-l-Urbanisme/Direction-de-l-Environnement',
#     'instanceid': '98198a7e-b5cf-4e06-8849-31ebec3d760a',
#     'metaid': '98198a7e-b5cf-4e06-8849-31ebec3d760a',
#     'uid': '98198a7e-b5cf-4e06-8849-31ebec3d760a'},
#    {'country': 'PR',
#     'dataProviderLegalName': 'Puerto Rico Seismic Network ',
#     'dataProviderUrl': 'https://redsismica.uprm.edu/index.php',
#     'instanceid': '7e189b4d-0d69-4b3c-8cb2-058cd0da2e0e',
#     'metaid': '7e189b4d-0d69-4b3c-8cb2-058cd0da2e0e',
#     'uid': '7e189b4d-0d69-4b3c-8cb2-058cd0da2e0e'},
#    {'country': 'ES',
#     'dataProviderLegalName': 'Puertos del Estado',
#     'dataProviderUrl': 'https://www.puertos.es/',
#     'instanceid': 'a0a3927d-3856-4299-9355-d34177e8d079',
#     'metaid': 'a0a3927d-3856-4299-9355-d34177e8d079',
#     'uid': 'a0a3927d-3856-4299-9355-d34177e8d079'},
#    {'country': 'NL',
#     'dataProviderLegalName': 'Rijkswaterstaat',
#     'dataProviderUrl': 'www.rijkswaterstaat.nl',
#     'instanceid': 'b5ec7737-ae89-4c97-bb65-c8001906d015',
#     'metaid': 'b5ec7737-ae89-4c97-bb65-c8001906d015',
#     'uid': 'b5ec7737-ae89-4c97-bb65-c8001906d015'},
#    {'country': 'TH',
#     'dataProviderLegalName': 'Royal Thai Navy ',
#     'dataProviderUrl': 'https://www.navy.mi.th/',
#     'instanceid': 'e66caf75-a2fc-4274-81e0-361ba3e592d4',
#     'metaid': 'e66caf75-a2fc-4274-81e0-361ba3e592d4',
#     'uid': 'e66caf75-a2fc-4274-81e0-361ba3e592d4'},
#    {'country': 'LC',
#     'dataProviderLegalName': 'Saint Lucia Meteorological Services',
#     'dataProviderUrl': 'https://met.gov.lc/',
#     'instanceid': '6d617a67-454b-4807-97f3-50ddc22de89e',
#     'metaid': '6d617a67-454b-4807-97f3-50ddc22de89e',
#     'uid': '6d617a67-454b-4807-97f3-50ddc22de89e'},
#    {'country': 'ZA',
#     'dataProviderLegalName': 'SARAO Hartebeesthoek Radio Astronomy Observatory',
#     'dataProviderUrl': 'https://www.sarao.ac.za/about/hartrao/',
#     'instanceid': '8a080edf-e880-417a-b2b3-252a57f32a5a',
#     'metaid': '8a080edf-e880-417a-b2b3-252a57f32a5a',
#     'uid': '8a080edf-e880-417a-b2b3-252a57f32a5a'},
#    {'country': 'FR',
#     'dataProviderLegalName': 'Service Hydrographique et Océanographique de la Marine',
#     'dataProviderUrl': 'http://www.shom.fr/en/',
#     'instanceid': '2aeabf5f-7c8e-4369-80a2-4cbd24e3ac0a',
#     'metaid': '2aeabf5f-7c8e-4369-80a2-4cbd24e3ac0a',
#     'uid': '2aeabf5f-7c8e-4369-80a2-4cbd24e3ac0a'},
#    {'country': 'HT',
#     'dataProviderLegalName': 'Service Maritime et de Navigation d´Haiti',
#     'dataProviderUrl': 'http://www.servicespublics.gouv.ht/site/rsmo/SEMANAH',
#     'instanceid': 'c07ae62f-1895-46d4-acc2-f9f4edce01f4',
#     'metaid': 'c07ae62f-1895-46d4-acc2-f9f4edce01f4',
#     'uid': 'c07ae62f-1895-46d4-acc2-f9f4edce01f4'},
#    {'country': 'AR',
#     'dataProviderLegalName': 'Servicio de Hidrografía Naval',
#     'dataProviderUrl': 'www.hidro.gov.ar/',
#     'instanceid': 'a4d31b03-af3f-446b-982b-fbc8fd8f1fca',
#     'metaid': 'a4d31b03-af3f-446b-982b-fbc8fd8f1fca',
#     'uid': 'a4d31b03-af3f-446b-982b-fbc8fd8f1fca'},
#    {'country': 'CL',
#     'dataProviderLegalName': 'Servicio Hidrográfico y Oceanográfico de la Armada',
#     'dataProviderUrl': 'www.shoa.cl',
#     'instanceid': '9b155b46-5c1f-490f-97f4-76af6a57c1b0',
#     'metaid': '9b155b46-5c1f-490f-97f4-76af6a57c1b0',
#     'uid': '9b155b46-5c1f-490f-97f4-76af6a57c1b0'},
#    {'country': 'SC',
#     'dataProviderLegalName': 'Seychelles National Meteorological Services',
#     'dataProviderUrl': 'https://www.meteo.sc/',
#     'instanceid': 'db9c0e0a-3edd-4706-8ef8-68c94ed1b2eb',
#     'metaid': 'db9c0e0a-3edd-4706-8ef8-68c94ed1b2eb',
#     'uid': 'db9c0e0a-3edd-4706-8ef8-68c94ed1b2eb'},
#    {'country': 'US',
#     'dataProviderLegalName': 'Smithsonian Marine Station',
#     'dataProviderUrl': 'http://www.sms.si.edu/',
#     'instanceid': 'f65bc9c4-ce62-4447-868f-ccb0636ca655',
#     'metaid': 'f65bc9c4-ce62-4447-868f-ccb0636ca655',
#     'uid': 'f65bc9c4-ce62-4447-868f-ccb0636ca655'},
#    {'country': 'US',
#     'dataProviderLegalName': 'Smithsonian Tropical Research Institute',
#     'dataProviderUrl': 'https://stri.si.edu/',
#     'instanceid': '76e04f62-55c3-4313-a2c0-cf2a421e1b9f',
#     'metaid': '76e04f62-55c3-4313-a2c0-cf2a421e1b9f',
#     'uid': '76e04f62-55c3-4313-a2c0-cf2a421e1b9f'},
#    {'country': 'CM',
#     'dataProviderLegalName': 'Societé National de Raffinage',
#     'dataProviderUrl': 'https://sonara-cm.cm/accueil/',
#     'instanceid': 'd52bd888-03d9-467f-9cc6-e6f02ddb52b6',
#     'metaid': 'd52bd888-03d9-467f-9cc6-e6f02ddb52b6',
#     'uid': 'd52bd888-03d9-467f-9cc6-e6f02ddb52b6'},
#    {'country': 'ZA',
#     'dataProviderLegalName': 'South African Hydrographic Office',
#     'dataProviderUrl': 'https://www.sanho.co.za/Default.htm',
#     'instanceid': '27a7eaa8-7064-4de5-94c1-83ab8c89b8f3',
#     'metaid': '27a7eaa8-7064-4de5-94c1-83ab8c89b8f3',
#     'uid': '27a7eaa8-7064-4de5-94c1-83ab8c89b8f3'},
#    {'country': 'HN',
#     'dataProviderLegalName': 'Standing Committee on Contingencies',
#     'dataProviderUrl': 'https://copeco.gob.hn/',
#     'instanceid': '83dbf2f4-263d-4b95-b4bf-a91e524d4bfa',
#     'metaid': '83dbf2f4-263d-4b95-b4bf-a91e524d4bfa',
#     'uid': '83dbf2f4-263d-4b95-b4bf-a91e524d4bfa'},
#    {'country': 'ES',
#     'dataProviderLegalName': 'State Meteorological Agency',
#     'dataProviderUrl': 'http://www.aemet.es/en/portada',
#     'instanceid': 'c438d5bc-a07d-423d-93bf-2f662b36d0b2',
#     'metaid': 'c438d5bc-a07d-423d-93bf-2f662b36d0b2',
#     'uid': 'c438d5bc-a07d-423d-93bf-2f662b36d0b2'},
#    {'country': 'BD',
#     'dataProviderLegalName': 'Survey of Bangladesh, Ministry of Defense',
#     'dataProviderUrl': 'https://sob.gov.bd/',
#     'instanceid': 'e32438a4-00cd-4111-b6b8-d555752d614d',
#     'metaid': 'e32438a4-00cd-4111-b6b8-d555752d614d',
#     'uid': 'e32438a4-00cd-4111-b6b8-d555752d614d'},
#    {'country': 'SE',
#     'dataProviderLegalName': 'Swedish Maritime Administration',
#     'dataProviderUrl': 'www.sjofartsverket.se/',
#     'instanceid': '380d26ea-9429-4ef1-be20-8443e8ae2e9d',
#     'metaid': '380d26ea-9429-4ef1-be20-8443e8ae2e9d',
#     'uid': '380d26ea-9429-4ef1-be20-8443e8ae2e9d'},
#    {'country': 'SE',
#     'dataProviderLegalName': 'Swedish Meteorological and Hydrological Institute',
#     'dataProviderUrl': 'https://www.smhi.se/',
#     'instanceid': 'b71e35b1-ad8a-4b79-8d2f-e2a062f452aa',
#     'metaid': 'b71e35b1-ad8a-4b79-8d2f-e2a062f452aa',
#     'uid': 'b71e35b1-ad8a-4b79-8d2f-e2a062f452aa'},
#    {'country': 'TZ',
#     'dataProviderLegalName': 'Tanzania Ports Authority',
#     'dataProviderUrl': 'https://www.ports.go.tz/index.php/en/',
#     'instanceid': '46234de8-bcc0-466e-9dc6-4a9195319745',
#     'metaid': '46234de8-bcc0-466e-9dc6-4a9195319745',
#     'uid': '46234de8-bcc0-466e-9dc6-4a9195319745'},
#    {'country': 'SN',
#     'dataProviderLegalName': 'The Centre De Recherches Océanographiques De Dakar-Thiaroye',
#     'dataProviderUrl': 'https://isra.sn/',
#     'instanceid': '0a0012d5-9254-41fb-b866-d0797cebd7eb',
#     'metaid': '0a0012d5-9254-41fb-b866-d0797cebd7eb',
#     'uid': '0a0012d5-9254-41fb-b866-d0797cebd7eb'},
#    {'country': 'DE',
#     'dataProviderLegalName': 'The Federal Waterways and Shipping Administration',
#     'dataProviderUrl': 'www.wsv.de/',
#     'instanceid': '7d155087-c72d-4c5f-92d9-ddb29fed285f',
#     'metaid': '7d155087-c72d-4c5f-92d9-ddb29fed285f',
#     'uid': '7d155087-c72d-4c5f-92d9-ddb29fed285f'},
#    {'country': 'US',
#     'dataProviderLegalName': 'UNAVCO',
#     'dataProviderUrl': 'https://www.unavco.org/',
#     'instanceid': '69f10b6a-102b-4538-8bab-c25110377359',
#     'metaid': '69f10b6a-102b-4538-8bab-c25110377359',
#     'uid': '69f10b6a-102b-4538-8bab-c25110377359'},
#    {'country': 'GB',
#     'dataProviderLegalName': 'United Kingdom Hydrographic Office',
#     'dataProviderUrl': 'www.ukho.gov.uk',
#     'instanceid': '28d76651-a004-457a-ae04-5e00e66616f1',
#     'metaid': '28d76651-a004-457a-ae04-5e00e66616f1',
#     'uid': '28d76651-a004-457a-ae04-5e00e66616f1'},
#    {'country': 'MX',
#     'dataProviderLegalName': 'Universidad Nacional Autónoma de México',
#     'dataProviderUrl': 'http://www.unam.mx',
#     'instanceid': '06a811c9-1989-438c-90e3-4b612a92e2f4',
#     'metaid': '06a811c9-1989-438c-90e3-4b612a92e2f4',
#     'uid': '06a811c9-1989-438c-90e3-4b612a92e2f4'},
#    {'country': 'CR',
#     'dataProviderLegalName': 'Universidad Nacional Costa Rica, SINAMOT ',
#     'dataProviderUrl': 'https://www.sinamot.una.ac.cr/',
#     'instanceid': '8c6b8eb8-fef6-43e1-89e9-3a4f9f58fe53',
#     'metaid': '8c6b8eb8-fef6-43e1-89e9-3a4f9f58fe53',
#     'uid': '8c6b8eb8-fef6-43e1-89e9-3a4f9f58fe53'},
#    {'country': 'PF',
#     'dataProviderLegalName': 'University of French Polynesia',
#     'dataProviderUrl': 'https://www.upf.pf',
#     'instanceid': '7b8499b1-1ce1-4645-a64a-90a7afa35ea4',
#     'metaid': '7b8499b1-1ce1-4645-a64a-90a7afa35ea4',
#     'uid': '7b8499b1-1ce1-4645-a64a-90a7afa35ea4'},
#    {'country': 'US',
#     'dataProviderLegalName': 'University of Hawaii Sea Level Center ',
#     'dataProviderUrl': 'https://uhslc.soest.hawaii.edu/',
#     'instanceid': 'e0a182fa-d38f-4754-9758-a9a586671f35',
#     'metaid': 'e0a182fa-d38f-4754-9758-a9a586671f35',
#     'uid': 'e0a182fa-d38f-4754-9758-a9a586671f35'},
#    {'country': 'MT',
#     'dataProviderLegalName': 'University of Malta',
#     'dataProviderUrl': 'www.um.edu.mt',
#     'instanceid': '75d2c2ff-7060-4f43-8a47-5ef4342f73f6',
#     'metaid': '75d2c2ff-7060-4f43-8a47-5ef4342f73f6',
#     'uid': '75d2c2ff-7060-4f43-8a47-5ef4342f73f6'},
#    {'country': 'PR',
#     'dataProviderLegalName': 'University of Puerto Rico',
#     'dataProviderUrl': 'www.upr.clu.edu/home1600.html',
#     'instanceid': 'ff24fdde-9055-4bbe-820b-6f078f98dfae',
#     'metaid': 'ff24fdde-9055-4bbe-820b-6f078f98dfae',
#     'uid': 'ff24fdde-9055-4bbe-820b-6f078f98dfae'},
#    {'country': 'ES',
#     'dataProviderLegalName': 'University of the Balearic Islands',
#     'dataProviderUrl': 'https://www.uib.eu/',
#     'instanceid': 'dc9ba6d3-8358-403e-90a4-5e65ab21646a',
#     'metaid': 'dc9ba6d3-8358-403e-90a4-5e65ab21646a',
#     'uid': 'dc9ba6d3-8358-403e-90a4-5e65ab21646a'},
#    {'country': 'FM',
#     'dataProviderLegalName': 'Yap Weather Service Office',
#     'dataProviderUrl': 'https://www.weather.gov/gum/WSOYap',
#     'instanceid': '3f624220-f687-4a10-aaaa-b2ef327e39b5',
#     'metaid': '3f624220-f687-4a10-aaaa-b2ef327e39b5',
#     'uid': '3f624220-f687-4a10-aaaa-b2ef327e39b5'},
#    {'country': 'YE',
#     'dataProviderLegalName': 'Yemen Gulf of Aden Ports Corporation',
#     'dataProviderUrl': 'https://www.portofaden.net/en',
#     'instanceid': '753d2cb1-0abc-4f82-b735-bef3b373dc6d',
#     'metaid': '753d2cb1-0abc-4f82-b735-bef3b373dc6d',
#     'uid': '753d2cb1-0abc-4f82-b735-bef3b373dc6d'},
#    {'country': 'TR',
#     'dataProviderLegalName': 'Yildiz Technical University',
#     'dataProviderUrl': 'www.yildiz.edu.tr/',
#     'instanceid': '6b1c2b93-3596-4c8c-98a5-d84b0030a51c',
#     'metaid': '6b1c2b93-3596-4c8c-98a5-d84b0030a51c',
#     'uid': '6b1c2b93-3596-4c8c-98a5-d84b0030a51c'}],
#   'uid': '39eb54f7-9536-40d6-91fc-b10379aa1ac0'},
#  'serviceTemporalCoverage': {},
#  'spatial': {'paths': [[[-178.1602285632045, -69.00777938015557],
#     [-178.1602285632045, 82.49000164979999],
#     [179.195203583904, 82.49000164979999],
#     [179.195203583904, -69.00777938015557],
#     [-178.1602285632045, -69.00777938015557]]],
#   'wkid': 4326},
#  'temporalCoverage': {'startDate': '2006-01-01T00:00:00Z'},
#  'title': 'IOC Sealevel Monitoring Station List (as OGC WMS layer)',
#  'type': 'WEB_SERVICE',
#  'uid': 'file:///sealevels_dist_stations_wms',
#  'versioningStatus': 'PUBLISHED'}

# %%
for available_format in json_sealevel_result['availableFormats']:
    if available_format['originalFormat'] == 'image/png':
            base_url = available_format['href']
#base_url = json_sealevel_result['serviceEndpoint'].split('?')[0]

# %%
service_parameters = json_sealevel_result['serviceParameters']

for parameter in service_parameters:
    if parameter['name'] == 'layers':
        layer = parameter['defaultValue']
    if 'property' in parameter:
        if parameter['property'] == 'epos:easternmostLongitude':
            maxlong = parameter['defaultValue']
        if parameter['property'] == 'epos:southernmostLatitude':
            minlat = parameter['defaultValue']
        if parameter['property'] == 'epos:northernmostLatitude':
            maxlat = parameter['defaultValue']
        if parameter['property'] == 'epos:westernmostLongitude':
            minlong = parameter['defaultValue']

# %% [markdown]
# ### Visualize the data
#
# Then he decide to visualize the waves using owslib library.

# %%
from owslib.wms import WebMapService

wms = WebMapService(base_url, version="1.3.0")

print(f'WMS title: {wms.identification.title}')

print(f'WMS abstract: {wms.identification.abstract}')

print(f'Provider name: {wms.provider.name}')

print(f'Provider address: {wms.provider.contact.address}')
# Out:
# WMS title: Flanders Marine Institute (VLIZ) - Geoserver WMS Service
# WMS abstract: A compliant implementation of OGC WMS.
# Provider name: VLIZ
# Provider address: None

# %%
img = wms.getmap(
    layers=[layer],
    size=[768, 330],
    srs="EPSG:4326",
    bbox=[minlong, minlat, maxlong, maxlat],
    format="image/png")

save_fp = 'wms.png'
with open(save_fp, 'wb') as out:
	out.write(img.read())

# %%
from IPython.display import Image
Image(filename=save_fp)

# %%
from owslib.wfs import WebFeatureService

wfs = WebFeatureService(base_url, version='2.0.0')
print(f'WFS title: {wfs.identification.title}')

print(f'WFS abstract: {wfs.identification.abstract}')

print(f'Provider name: {wfs.provider.name}')

print(f'Provider address: {wfs.provider.contact.address}')
# Out:
# WFS title: Flanders Marine Institute (VLIZ) - WFS Service
# WFS abstract: This is the reference implementation of OGC WFS 1.0.0 and WFS 1.1.0, supports all WFS operations including Transaction.
# Provider name: VLIZ
# Provider address: None

# %%
list(wfs.contents)
# Out:
# ['Sealevels:sealevels']

# %%
response = wfs.getfeature(typename=layer, bbox=(minlong, minlat, maxlong, maxlat), outputFormat='json')
with open('sea_level_wfs.json', 'w', encoding='UTF-8') as out:
	out.write(str(response.read(), 'UTF-8'))

# %%
import json

with open('sea_level_wfs.json') as f:
    d = json.load(f)

# %%
import geopandas

df = geopandas.read_file("sea_level_wfs.json")

# %%
df
# Out:
#                                         id   code   latitude   longitude  \
# 0     sealevels.fid-b440fb_19de328e310_5c5   aarh  56.150000   10.220000
# 1     sealevels.fid-b440fb_19de328e310_5c6   abas  44.020000  144.290000
# 2     sealevels.fid-b440fb_19de328e310_5c7   abed  57.140000   -2.080000
# 3     sealevels.fid-b440fb_19de328e310_5c8   abur  31.580000  131.410000
# 4     sealevels.fid-b440fb_19de328e310_5c9   acaj  13.573792  -89.838128
# ...                                    ...    ...        ...         ...
# 1740  sealevels.fid-b440fb_19de328e310_c91   zkth  37.781420   20.905200
# 1741  sealevels.fid-b440fb_19de328e310_c92   zldw  51.346389    3.200278
# 1742  sealevels.fid-b440fb_19de328e310_c93   zwdw  51.355278    3.178056
# 1743  sealevels.fid-b440fb_19de328e310_c94   zygi  34.727083   33.338375
# 1744  sealevels.fid-b440fb_19de328e310_c95  zygi1  34.726315   33.340228
#
#                        Location country type  XMtInt GlossID       status  \
# 0                        Aarhus     DMK   SF    10.0     NaN  operational
# 1                      Abashiri     JAP   SL    10.0     327  operational
# 2                      Aberdeen     GRB   SF    15.0     NaN  operational
# 3                      Aburatsu     JAP   SL    10.0      82  operational
# 4                   Acajutla_SV     SVD   SL     5.0     182  operational
# ...                         ...     ...  ...     ...     ...          ...
# 1740  Zakynthos, Ionian Islands     HEL   SB     1.0     NaN         down
# 1741   Zeebrugge Leopold II dam     BEL   SW     5.0     NaN  operational
# 1742     Zeebrugge Wielingendok     BEL   SW     5.0     NaN  operational
# 1743                      Zygi      CYP   SF     1.0     NaN         down
# 1744                       Zygi     CYP   SB     1.0     NaN         down
#
#                          date_created  \
# 0    2025-07-15 13:30:01.070000+00:00
# 1    2012-03-21 09:54:59.357000+00:00
# 2    2012-09-04 21:04:28.220000+00:00
# 3    2012-03-21 10:09:41.317000+00:00
# 4           2008-06-20 12:17:00+00:00
# ...                               ...
# 1740 2023-09-29 06:31:39.240000+00:00
# 1741 2023-10-05 17:30:00.580000+00:00
# 1742 2023-10-05 17:31:48.323000+00:00
# 1743 2011-09-07 14:55:04.817000+00:00
# 1744 2018-03-16 05:24:01.080000+00:00
#
#                                             stationlink  \
# 0     http://www.ioc-sealevelmonitoring.org/station....
# 1     http://www.ioc-sealevelmonitoring.org/station....
# 2     http://www.ioc-sealevelmonitoring.org/station....
# 3     http://www.ioc-sealevelmonitoring.org/station....
# 4     http://www.ioc-sealevelmonitoring.org/station....
# ...                                                 ...
# 1740  http://www.ioc-sealevelmonitoring.org/station....
# 1741  http://www.ioc-sealevelmonitoring.org/station....
# 1742  http://www.ioc-sealevelmonitoring.org/station....
# 1743  http://www.ioc-sealevelmonitoring.org/station....
# 1744  http://www.ioc-sealevelmonitoring.org/station....
#
#                                                datalink  \
# 0     http://www.ioc-sealevelmonitoring.org/station....
# 1     http://www.ioc-sealevelmonitoring.org/station....
# 2     http://www.ioc-sealevelmonitoring.org/station....
# 3     http://www.ioc-sealevelmonitoring.org/station....
# 4     http://www.ioc-sealevelmonitoring.org/station....
# ...                                                 ...
# 1740  http://www.ioc-sealevelmonitoring.org/station....
# 1741  http://www.ioc-sealevelmonitoring.org/station....
# 1742  http://www.ioc-sealevelmonitoring.org/station....
# 1743  http://www.ioc-sealevelmonitoring.org/station....
# 1744  http://www.ioc-sealevelmonitoring.org/station....
#
#                                            downloadlink  \
# 0     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 2     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 3     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 4     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# ...                                                 ...
# 1740  http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1741  http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1742  http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1743  http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1744  http://www.ioc-sealevelmonitoring.org/bgraph.p...
#
#                         geometry
# 0            POINT (10.22 56.15)
# 1           POINT (144.29 44.02)
# 2            POINT (-2.08 57.14)
# 3           POINT (131.41 31.58)
# 4     POINT (-89.83813 13.57379)
# ...                          ...
# 1740    POINT (20.9052 37.78142)
# 1741    POINT (3.20028 51.34639)
# 1742    POINT (3.17806 51.35528)
# 1743   POINT (33.33838 34.72708)
# 1744   POINT (33.34023 34.72632)
#
# [1745 rows x 15 columns]
