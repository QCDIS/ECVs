# %%
! pip list
# Out:
# Package                   Version
# ------------------------- ------------
# aiohappyeyeballs          2.6.1
# aiohttp                   3.12.15
# aiosignal                 1.4.0
# annotated-types           0.7.0
# anyio                     4.13.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# argopy                    1.4.0
# asttokens                 3.0.1
# async-timeout             5.0.1
# attrs                     26.1.0
# Brotli                    1.2.0
# cached-property           1.5.2
# certifi                   2026.4.22
# cffi                      2.0.0
# cftime                    1.6.5
# chardet                   7.4.3
# charset-normalizer        3.4.7
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.20
# decorator                 5.2.1
# envrihub                  0.1.3
# erddapy                   3.1.1
# exceptiongroup            1.3.1
# executing                 2.2.1
# fonttools                 4.62.1
# frozenlist                1.7.0
# fsspec                    2026.3.0
# geopandas                 1.1.3
# h11                       0.16.0
# h2                        4.3.0
# h5netcdf                  1.8.1
# h5py                      3.16.0
# hpack                     4.1.0
# httpcore                  1.0.9
# httpx                     0.28.1
# hyperframe                6.1.0
# idna                      3.13
# ipykernel                 6.29.5
# ipython                   9.13.0
# ipython_pygments_lexers   1.1.1
# isodate                   0.7.2
# jedi                      0.19.2
# jsonschema                4.26.0
# jsonschema-path           0.4.6
# jsonschema-specifications 2025.9.1
# jupyter_client            8.8.0
# jupyter_core              5.9.1
# kiwisolver                1.5.0
# lazy-object-proxy         1.12.0
# lxml                      6.1.0
# matplotlib                3.10.9
# matplotlib-inline         0.2.1
# minio                     7.2.15
# multidict                 6.7.1
# munkres                   1.1.4
# nest_asyncio              1.6.0
# netCDF4                   1.7.4
# numpy                     2.4.3
# openapi-schema-validator  0.8.1
# openapi-spec-validator    0.8.5
# OWSLib                    0.35.0
# packaging                 26.2
# pandas                    3.0.2
# parso                     0.8.6
# pathable                  0.5.0
# pexpect                   4.9.0
# pillow                    12.2.0
# pip                       25.0.1
# platformdirs              4.9.6
# prance                    25.4.8.0
# prompt_toolkit            3.0.52
# propcache                 0.3.1
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# py                        1.11.0
# pycparser                 2.22
# pycryptodome              3.23.0
# pydantic                  2.13.3
# pydantic_core             2.46.3
# pydantic-settings         2.14.0
# Pygments                  2.20.0
# pyogrio                   0.12.1
# pyparsing                 3.3.2
# pyproj                    3.7.2
# PySide6                   6.9.2
# PySocks                   1.7.1
# python-dateutil           2.9.0.post0
# python-dotenv             1.2.2
# pytz                      2026.1.post1
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# rdflib                    7.6.0
# referencing               0.37.0
# requests                  2.33.1
# retry                     0.9.2
# rfc3339-validator         0.1.4
# rpds-py                   0.30.0
# ruamel.yaml               0.19.1
# scipy                     1.17.1
# SecretsProvider           2.0.3
# setuptools                82.0.1
# shapely                   2.1.2
# shiboken6                 6.9.2
# six                       1.17.0
# sniffio                   1.3.1
# SPARQLWrapper             2.0.0
# stack_data                0.6.3
# toolz                     1.1.0
# tornado                   6.5.5
# traitlets                 5.14.3
# typing_extensions         4.15.0
# typing-inspection         0.4.2
# unicodedata2              17.0.1
# urllib3                   2.6.3
# wcwidth                   0.6.0
# xarray                    2025.9.0
# yarl                      1.23.0

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# Get from AERIS Catalogue mapping EXV to CF (P07).
# To replace with NERC catalogue when P07 I-ADOPT mapping done.
# Test for ECV precursors --> carbon monoxide in IAGOS.
sparql = SPARQLWrapper("https://skosmos.aeris-data.fr/sparql")
sparql.setReturnFormat(JSON)
sparql.setQuery("""
   PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT * FROM <https://vocab.aeris-data.fr/parameter>
WHERE {
  # ?param skos:relatedMatch <http://vocab.nerc.ac.uk/collection/EXV/current/EXV015/> .
  # ?param skos:narrowMatch ?o .
} 
    """)
try:
    retEXV = sparql.queryAndConvert()
    for r in retEXV["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
# Out:
# {'param': {'type': 'uri', 'value': 'https://vocab.aeris-data.fr/parameter/a2cbdc84-2129-7437-4a16-4d2d4f850ae4'}, 'o': {'type': 'uri', 'value': 'http://vocab.nerc.ac.uk/collection/P07/current/CFSN0817/'}}
# {'param': {'type': 'uri', 'value': 'https://vocab.aeris-data.fr/parameter/c31f72a0-7737-8f30-8271-dcf843ebfb45'}, 'o': {'type': 'uri', 'value': 'http://vocab.nerc.ac.uk/collection/P07/current/CFSN0812/'}}

# %%
# Extract CF names from results.
sparql2 = SPARQLWrapper(
    "http://vocab.nerc.ac.uk/sparql/sparql"
)
sparql2.setReturnFormat(JSON)
# list of CF names.
variables = []
for r in retEXV["results"]["bindings"]:
    # gets the first 3 geological ages
    # from a Geological Timescale database,
    # via a SPARQL endpoint
    sparql2.setQuery("""
      PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT * WHERE {
      <%s> skos:prefLabel ?obj .
    } 
        """ % r['o']['value']
    )
    try:
        retCF = sparql2.queryAndConvert()
        for b in retCF["results"]["bindings"]:
            variables.append(b['obj']['value'])
    except Exception as e:
        print(e)
print(variables)
# Out:
# ['mole_fraction_of_nitrogen_dioxide_in_air', 'mole_fraction_of_carbon_monoxide_in_air']

# %%
# Mapping CF to IAGOS variables shortname.
# Update API to search by CF name.
mapping_CF_IAGOS = {'mole_fraction_of_carbon_monoxide_in_air' : ['CO'],
                   'mole_fraction_of_carbon_dioxide_in_air' : ['CO2']}

# Get airports matching the spatial extent.
# 1st step necessary, will be removed when search service updated (taking bbox instead of stations list).
import requests
import json
bbox="0,0,50,90"
parameters=[]
for x in mapping_CF_IAGOS:
    for y in mapping_CF_IAGOS[x]:
        parameters.append(y)
parameters=",".join(parameters)
start="2021-08-01"
end="2021-10-20"
indexPage=0
sizePage=20
url="https://services.iagos-data.fr/prod/v2.0/airports/public?active=true&bbox="+bbox+"&from="+start+"&to="+end+"&cursor="+str(indexPage)+"&size="+str(sizePage)
response=requests.get(url)
data = json.loads(response.text)
airports = []
for dataset in data:
    airports.append(dataset['iata_code'])
airports=",".join(airports)
print(airports)
# Out:
# MLE,PHL,BKK,DFW,ALA,TSE,JFK,MCO,MIA,ORD,DXB,DMM,SSG,KWI,IKA,SJO,FRA,ATL,NBO,IAH

# %%
# For each airport, read data in xarray and load the relevant variables.
import io
import xarray as xr
import matplotlib.pyplot as plt
url="https://services.iagos-data.fr/prod/v2.0/l3/search?codes="+airports+"&from="+start+"&to="+end+"&level=2&parameters="+parameters
print(url)
response=requests.get(url)
data = json.loads(response.text)
datasets = {}
for dataset in data:
    datasets[dataset['title']] = dataset
    print(dataset['title'])

# Limiting to Frankfurt airport dataset for this test.
# dataset=datasets['IAGOS Daily median profiles at FRA, Frankfurt, Germany airport (FRA)']
dataset=datasets['IAGOS Daily mean profiles at FRA, Frankfurt, Germany airport (FRA)']

# Retrieving the endpoint dataset URI.
url = None
for _url_info in dataset['urls']:
    if _url_info['type'].upper() == 'LANDING_PAGE':
        url = _url_info['url']
# Loading the data.
urlDl="https://services.iagos-data.fr/prod/v2.0/l3/loadNetcdfFile?fileId=" + url.replace("#", "%23")
print(urlDl)
response = requests.get(urlDl)
response.raise_for_status()
with io.BytesIO(response.content) as buf:
    with xr.open_dataset(buf) as ds:
        varlist = []
        for varname, da in ds.data_vars.items():
            if 'standard_name' not in da.attrs:
                continue
            std_name = da.attrs['standard_name']
            if std_name in variables:
                varlist.append(varname)
        ds = ds[varlist].load()
# Plotting the data.
# 4 layers available for each variable. Only reading the first level (surface).
# Subsetting by temporal extent used for searching.
for var in ds.data_vars:
    varData = ds.get(var)[0]
    print(varData)
    varPlot = varData.sel(time=slice(start, end))
    varPlot.plot()
# Out:
# https://services.iagos-data.fr/prod/v2.0/l3/search?codes=MLE,PHL,BKK,DFW,ALA,TSE,JFK,MCO,MIA,ORD,DXB,DMM,SSG,KWI,IKA,SJO,FRA,ATL,NBO,IAH&from=2021-08-01&to=2021-10-20&level=2&parameters=CO,CO2
# IAGOS Daily mean profiles at ALA, Almaty, Kazakhstan airport (ALA)
# IAGOS Daily mean profiles at ATL, Atlanta, United States airport (ATL)
# IAGOS Daily mean profiles at BKK, Bangkok, Thailand airport (BKK)
# IAGOS Daily mean profiles at DFW, Dallas, United States airport (DFW)
# IAGOS Daily mean profiles at DMM, Dammam, Saudi Arabia airport (DMM)
# IAGOS Daily mean profiles at DXB, Dubai, United Arab Emirates airport (DXB)
# IAGOS Daily mean profiles at FRA, Frankfurt, Germany airport (FRA)
# IAGOS Daily mean profiles at IAH, Houston, United States airport (IAH)
# IAGOS Daily mean profiles at IKA, Tehran, Iran airport (IKA)
# IAGOS Daily mean profiles at JFK, New York, United States airport (JFK)
# IAGOS Daily mean profiles at KWI, Kuwait City, Kuwait airport (KWI)
# IAGOS Daily mean profiles at MIA, Miami, United States airport (MIA)
# IAGOS Daily mean profiles at NBO, Nairobi, Kenya airport (NBO)
# IAGOS Daily mean profiles at ORD, Chicago, United States airport (ORD)
# IAGOS Daily mean profiles at PHL, Philadelphia, United States airport (PHL)
# IAGOS Daily mean profiles at SSG, Malabo, Equatorial Guinea airport (SSG)
# IAGOS Daily mean profiles at TSE, Astana, Kazakhstan airport (TSE)
# https://services.iagos-data.fr/prod/v2.0/l3/loadNetcdfFile?fileId=https://doi.org/10.25326/638%23vp_daily_FRA.nc
# <xarray.DataArray 'CO' (time: 10802)> Size: 43kB
# array([    nan,     nan,     nan, ..., 176.32 , 186.16 , 222.245],
#       shape=(10802,), dtype=float32)
# Coordinates:
#     layer    <U4 16B '500m'
#   * time     (time) datetime64[ns] 86kB 1994-08-01T12:00:00 ... 2024-02-26T12...
# Attributes:
#     standard_name:  mole_fraction_of_carbon_monoxide_in_air
#     long_name:      Daily median of carbon monoxide mixing ratio
#     units:          ppb
