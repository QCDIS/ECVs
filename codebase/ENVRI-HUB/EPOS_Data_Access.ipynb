# %% [markdown]
# # ENVRI-Hub NEXT - Hand On the EPOS API

# %% [markdown]
# ## Prerequisites
# Install python libraries

# %%
! pip install requests --break-system-packages
! pip install owslib --break-system-packages
! pip install pyproj --break-system-packages
! pip install geopandas --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /usr/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.13/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.13/site-packages (from requests) (2.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: owslib in /home/valerio/.local/lib/python3.13/site-packages (0.33.0)
# Requirement already satisfied: lxml in /home/valerio/.local/lib/python3.13/site-packages (from owslib) (5.3.2)
# Requirement already satisfied: python-dateutil in /usr/lib/python3.13/site-packages (from owslib) (2.9.0)
# Requirement already satisfied: pyyaml in /usr/lib/python3.13/site-packages (from owslib) (6.0.2)
# Requirement already satisfied: requests in /usr/lib/python3.13/site-packages (from owslib) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.13/site-packages (from python-dateutil->owslib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.13/site-packages (from requests->owslib) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.13/site-packages (from requests->owslib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.13/site-packages (from requests->owslib) (2.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyproj in /home/valerio/.local/lib/python3.13/site-packages (3.7.1)
# Requirement already satisfied: certifi in /usr/lib/python3.13/site-packages (from pyproj) (2025.1.31)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.22 in /usr/lib/python3.13/site-packages (from geopandas) (2.2.4)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging in /usr/lib/python3.13/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/lib/python3.13/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in /home/valerio/.local/lib/python3.13/site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/lib/python3.13/site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas) (2025.1)
# Collecting tzdata>=2022.7 (from pandas>=1.4.0->geopandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: certifi in /usr/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading pyogrio-0.10.0-cp313-cp313-manylinux_2_28_x86_64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, pyogrio, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.10.0 tzdata-2025.2

# %% [markdown]
# ## Search
# The search function of the EPOS API allows users to query the database of metadata contained into the EPOS. The API uses a RESTful architecture, which means that users can send HTTP requests to the API endpoints and receive responses in JSON.
#
# *import requests* is a Python statement that imports the *requests* library, which is a popular Python library for making HTTP requests. The *requests* library provides an interface for sending HTTP requests and handling their responses, making it a popular good choice for RESTful API access.

# %%
import requests

# %% [markdown]
# *api_url* is assigned to 'https://www.ics-c.epos-eu.org/api/v1'. This represents the base URL for the EPOS API. Documentation: 'https://www.ics-c.epos-eu.org/api/v1/ui/'

# %%
api_url = 'https://www.ics-c.epos-eu.org/api/v1'

# %% [markdown]
# From the *EXV* using the EPOS Vocabulary tool (https://registry.epos-eu.org/ncl/ui/sparql-form#) to retrieve the value to be used in the EPOS API. (TODO)

# %%
exv_variable = 'http://vocab.nerc.ac.uk/collection/EXV/current/EXV023/'

# %% [markdown]
# We can use the *requests* library to send an HTTP GET request to the EPOS API search endpoint, and then extract the JSON data from the response.
# The parameters in the query for this request:
# - *facets* is set to false, this parameter is set to true when the client want the API to return the information in a categorized structure, it can  show the information as in different category on multiple levels.
# - *q* is the search by free text, it narrows down the results based on which resource contains in the title or in the description or as keyword the specific string

# %%
search_endpoint = api_url + '/resources/search?q=&facets=false'

response_search = requests.get(search_endpoint)
data = response_search.json()

# %% [markdown]
# This is a JSON object with two key:
#
# 1. "*filters*" which has an array of four objects as its value: "*keyword*", "*organisations*", "*sciencedomains*" and "*servicetype*". Each object represents a filter category and has two key-value pairs:
#     - "*name*": a string that represents the name of the filter category.
#     - "*children*": an array of objects that represent the subcategories for the filter category. Each subcategory object has two key-value pairs:
#         - "*id*": a string that represents a unique identifier for the subcategory.
#         - "*name*": a string that represents the name of the subcategory.
# 2. "*results*" that holds an array named *distributions* that is an array of object representing all the resources available in the system.

# %% [markdown]
# Each one of the *results* object has these properties:
# - "**availableFormats**": an array of elements each representing a file format that can be downloaded for this resource, including the format type, the url to get the resource with that specific format, a label, and type which define if the format is natively available of it needs a conversion.
# - "**description**": a string containing a detailed description of the dataset, including the purpose, content, and objectives.
# - "**href**": a string representing the URL where the EPOS ICS-C API serve the details of the resources.
# - "**hrefExtended**": a string representing the URL where the EPOS ICS-C API serve the more deeper details of the resources.
# - "**id**": a string representing the unique identifier of this dataset.
# - "**status**": an integer representing the status of the resource.
# - "**title**": a string representing the title of the resource.
# - "**uid**": a string representing the unique identifier of the resource.

# %% [markdown]
# Here it is an instance of the first resource:

# %%
data['results']['distributions'][0]
# Out:
# {'availableFormats': [{'format': 'text',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/dfe4986c-1877-4e95-8524-a6f027996b4a?format=text',
#    'label': 'TEXT',
#    'originalFormat': 'text',
#    'type': 'ORIGINAL'},
#   {'format': 'xml',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/dfe4986c-1877-4e95-8524-a6f027996b4a?format=xml',
#    'label': 'XML',
#    'originalFormat': 'xml',
#    'type': 'ORIGINAL'},
#   {'format': 'application/epos.geo+json',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/dfe4986c-1877-4e95-8524-a6f027996b4a?format=application/epos.geo+json',
#    'inputFormat': 'application/xml',
#    'label': 'GEOJSON',
#    'originalFormat': 'application/xml',
#    'pluginId': 'aa888751-517e-4b8e-84a7-ddbbecef1aef',
#    'type': 'CONVERTED'},
#   {'format': 'application/epos.covjson',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/dfe4986c-1877-4e95-8524-a6f027996b4a?format=application/epos.covjson',
#    'inputFormat': 'application/xml',
#    'label': 'COVJSON',
#    'originalFormat': 'application/xml',
#    'pluginId': 'd3c14580-9dd9-419a-867d-78f899fb002e',
#    'type': 'CONVERTED'}],
#  'description': 'Access to instrumental earthquakes data (location and magnitude) through FDSN Event web service. Dataset covers the time period since 2000 and is limited to the Corinth Rift Laboratory (Greece) Near Fault Observatory.  Dataset is encoded in QuakeML and text format.',
#  'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/dfe4986c-1877-4e95-8524-a6f027996b4a',
#  'hrefExtended': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/dfe4986c-1877-4e95-8524-a6f027996b4a?extended=true',
#  'id': 'dfe4986c-1877-4e95-8524-a6f027996b4a',
#  'status': 1,
#  'statusTimestamp': '1970-01-01T12:00:00Z',
#  'title': 'CRL Seismic Events',
#  'uid': 'https://www.epos-eu.org/epos-dcat-ap/NearFaultObservatory/CRL/event/Distribution/001'}

# %% [markdown]
# ## Details
#
# The details function of the EPOS API allows users to retrieve detailed information about a specific seismic event. Users can query the API using the unique ID assigned to each resource in the database.
#
# To retrieve all the detailed information about this resource is enough to do a GET request, using also this time the *requests* library, on the *href* property.

# %%
response_detail = requests.get(data['results']['distributions'][0]['href'])
data_details = response_detail.json()

# %% [markdown]
# The details response payload have this structure:
# - **availableFormats**: an array that contains multiple object with details about the available format for the data, one for each available format.
# - **dataProvider**: an array that contains objects with details about the data provider of the resource, one resource can have multiple dataprovider and each one of these can have multiple dataproviders related, also, if available is present an url to the page of the dataprovider.
# - **description**: a string that describes the purpose and objectives of the resource.
# - **downloadURL**: This property contains a URL that is a direct link to a downloadable file in a given format. An empty string indicating that there is no download URL available.
# - **endpoint**: a string that provides the URL endpoint for accessing the data.
# - **frequencyUpdate**: a string that indicates the frequency or the strategy of updates to the data.
# - **hasQualityAnnotation**: a string that provides a link to information about the quality assurance of the data.
# - **href**: a string that provides a link to the details of the resource.
# - **id**: a string that serves as a unique identifier for the resource.
# - **internalID**: an array that contains the internal identifier for the resource.
# - **keywords**: an array of strings that contain keywords related to the data.
# - **license**: a string that provides a link to the license agreement for accessing the data.
# - **operationid**: a string that provides a link to the operation of the resource, it contains the unique identifier of the operation.
# - **scienceDomain**: an array that provides the science domain of the resource.
# - **serviceDescription**: a string that describes the purpose of the web service.
# - **serviceDocumentation**: a string that provides a link to the documentation for the web service.
# - **serviceEndpoint**: a string that provides the URL endpoint for accessing the web service.
# - **serviceName**: a string that provides the name of the web service.
# - **serviceParameters**: an array that contains an object with details about the parameters required to use the web service (in this case, the parameter "start" is required and has a default value of "19821001").
# - **serviceProvider**: an object with details about the service provider of the resource, one resource can have one service provider and each one of these can have multiple service providers related, also, if available is present an url to the page of the serviceprovider.
# - **serviceSpatial**: an object that contains spatial information about the service like a path of coordinates.
# - **serviceTemporalCoverage**: an object that provides temporal coverage information for the service.
# - **serviceType**: an array that provides the type of the service.
# - **spatial**: an object that contains spatial information about the resource like a path defined by a set of coordinates.
# - **temporalCoverage**: an object that provides temporal coverage information for the resource.
# - **title**: a string that provides the title of the resource.
# - **type**: a string that provides the type of the resource.
# - **uid**: a string that serves as a unique identifier of the resource.

# %%
data_details
# Out:
# {'availableContactPoints': [{'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=3e91b699-875e-44de-b1d7-37816e121f60&contactType=DATAPROVIDERS',
#    'type': 'DATAPROVIDERS'}],
#  'availableFormats': [{'format': 'text',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/dfe4986c-1877-4e95-8524-a6f027996b4a?format=text',
#    'label': 'TEXT',
#    'originalFormat': 'text',
#    'type': 'ORIGINAL'},
#   {'format': 'xml',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/dfe4986c-1877-4e95-8524-a6f027996b4a?format=xml',
#    'label': 'XML',
#    'originalFormat': 'xml',
#    'type': 'ORIGINAL'},
#   {'format': 'application/epos.geo+json',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/dfe4986c-1877-4e95-8524-a6f027996b4a?format=application/epos.geo+json',
#    'inputFormat': 'application/xml',
#    'label': 'GEOJSON',
#    'originalFormat': 'application/xml',
#    'pluginId': 'aa888751-517e-4b8e-84a7-ddbbecef1aef',
#    'type': 'CONVERTED'},
#   {'format': 'application/epos.covjson',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute/dfe4986c-1877-4e95-8524-a6f027996b4a?format=application/epos.covjson',
#    'inputFormat': 'application/xml',
#    'label': 'COVJSON',
#    'originalFormat': 'application/xml',
#    'pluginId': 'd3c14580-9dd9-419a-867d-78f899fb002e',
#    'type': 'CONVERTED'}],
#  'categories': {'children': [{'children': [{'children': [{'children': [{'ddss': 'category:earthquakesdata',
#           'name': 'Earthquakes data'}],
#         'ddss': 'category:seismologicalproducts',
#         'name': 'Seismological products'}],
#       'ddss': 'category:seismologicaldata',
#       'name': 'Seismological Data'}],
#     'code': 'NFO',
#     'color': '#5e3160',
#     'id': '2',
#     'imgUrl': 'assets/img/logo/NFO_logo.png',
#     'linkUrl': 'https://www.epos-eu.org/tcs/near-fault-observatories',
#     'name': 'Near Fault Observatories'}],
#   'name': 'domains'},
#  'dataProvider': [{'country': 'FR',
#    'dataProviderLegalName': 'RÉSIF - Réseau sismologique & géodésique français',
#    'dataProviderUrl': 'http://seismology.resif.fr/',
#    'instanceid': 'ee47ccaa-0e16-40c8-8f41-9bc5a107f212',
#    'metaid': 'ee47ccaa-0e16-40c8-8f41-9bc5a107f212',
#    'uid': 'ee47ccaa-0e16-40c8-8f41-9bc5a107f212'}],
#  'description': 'Access to instrumental earthquakes data (location and magnitude) through FDSN Event web service. Dataset covers the time period since 2000 and is limited to the Corinth Rift Laboratory (Greece) Near Fault Observatory.  Dataset is encoded in QuakeML and text format.',
#  'downloadURL': '',
#  'endpoint': 'https://nfocrl.u-strasbg.fr/fdsnws/event/1/query{?starttime, endtime, minlatitude, maxlatitude, minlongitude, maxlongitude, mindepth, maxdepth, minmagnitude, maxmagnitude, magnitudetype, includeallorigins, includeallmagnitudes, includearrivals, limit, offset, orderby, format, latitude, longitude, minradius, maxradius}',
#  'frequencyUpdate': 'http://purl.org/cld/freq/irregular',
#  'hasQualityAnnotation': 'https://fridge.ingv.it/docs/API_prototype_documentation_NFO_QA.pdf',
#  'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/dfe4986c-1877-4e95-8524-a6f027996b4a',
#  'hrefExtended': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/dfe4986c-1877-4e95-8524-a6f027996b4a?extended=true',
#  'id': 'dfe4986c-1877-4e95-8524-a6f027996b4a',
#  'internalID': ['WP09-DDSS-006'],
#  'keywords': ['fridge',
#   'near fault observatories',
#   'seismology',
#   'earthquake',
#   'seismic catalog',
#   'nfo',
#   'corinth rift laboratory',
#   'seismic waves propagation',
#   'event',
#   'crl',
#   'seismicity',
#   'seismic source'],
#  'license': 'https://creativecommons.org/licenses/by-sa/4.0/',
#  'operationid': 'https://www.epos-eu.org/epos-dcat-ap/NearFaultObservatory/CRL/event/Webservice/001/Operation/001',
#  'scienceDomain': ['Earthquakes data'],
#  'serviceDescription': 'Corinth Rift Laboratory (Greece) - The fdsnws-event web service returns event (earthquake) information',
#  'serviceDocumentation': 'https://www.fdsn.org/webservices/fdsnws-event-1.2.pdf',
#  'serviceEndpoint': 'https://nfocrl.u-strasbg.fr/fdsnws/event/1/query',
#  'serviceName': 'Corinth Rift Laboratory (CRL) - FDSN Event Web Service',
#  'serviceParameters': [{'label': 'Offset',
#    'minValue': '1',
#    'name': 'offset',
#    'required': False,
#    'type': 'integer'},
#   {'label': 'Type of Magnitude',
#    'name': 'magnitudetype',
#    'required': False,
#    'type': 'string'},
#   {'defaultValue': '1',
#    'label': 'Minimum Magnitude',
#    'name': 'minmagnitude',
#    'required': False,
#    'type': 'float'},
#   {'defaultValue': '38.0',
#    'label': 'Minimum Latitude',
#    'maxValue': '90',
#    'minValue': '-90',
#    'name': 'minlatitude',
#    'property': 'epos:southernmostLatitude',
#    'required': False,
#    'type': 'float'},
#   {'Enum': ['false', 'true'],
#    'defaultValue': 'false',
#    'label': 'Include All Magnitudes',
#    'name': 'includeallmagnitudes',
#    'required': False,
#    'type': 'boolean'},
#   {'defaultValue': '2016-01-01T05:00',
#    'label': 'End Time',
#    'maxValue': '2999-01-01T00:00',
#    'minValue': '2000-05-20T00:00',
#    'name': 'endtime',
#    'property': 'schema:endDate',
#    'required': False,
#    'type': 'dateTime',
#    'valuePattern': 'YYYY-MM-DDThh:mm:ssZ'},
#   {'defaultValue': '21.35',
#    'label': 'Minimum Longitude',
#    'maxValue': '180',
#    'minValue': '-180',
#    'name': 'minlongitude',
#    'property': 'epos:westernmostLongitude',
#    'required': False,
#    'type': 'float'},
#   {'defaultValue': '20',
#    'label': 'Maximum Depth',
#    'maxValue': '6378',
#    'minValue': '-10',
#    'name': 'maxdepth',
#    'required': False,
#    'type': 'integer'},
#   {'defaultValue': '22.5',
#    'label': 'Maximum Longitude',
#    'maxValue': '180',
#    'minValue': '-180',
#    'name': 'maxlongitude',
#    'property': 'epos:easternmostLongitude',
#    'required': False,
#    'type': 'float'},
#   {'Enum': ['magnitude-asc', 'magnitude', 'time-asc', 'time'],
#    'defaultValue': 'time',
#    'label': 'Order By',
#    'name': 'orderby',
#    'required': False,
#    'type': 'string'},
#   {'Enum': ['false', 'true'],
#    'defaultValue': 'false',
#    'label': 'Include All Origins',
#    'name': 'includeallorigins',
#    'required': False,
#    'type': 'boolean'},
#   {'label': 'Longitude (Radius Search)',
#    'maxValue': '180',
#    'minValue': '-180',
#    'name': 'longitude',
#    'required': False,
#    'type': 'float'},
#   {'Enum': ['text', 'xml'],
#    'defaultValue': 'xml',
#    'label': 'Output Format',
#    'name': 'format',
#    'property': 'schema:encodingFormat',
#    'readOnlyValue': 'true',
#    'required': False,
#    'type': 'string'},
#   {'defaultValue': '0',
#    'label': 'Minimum Depth',
#    'maxValue': '6378',
#    'minValue': '-10',
#    'name': 'mindepth',
#    'required': False,
#    'type': 'integer'},
#   {'defaultValue': '30',
#    'label': 'Limit',
#    'minValue': '1',
#    'name': 'limit',
#    'required': False,
#    'type': 'integer'},
#   {'defaultValue': '38.65',
#    'label': 'Maximum Latitude',
#    'maxValue': '90',
#    'minValue': '-90',
#    'name': 'maxlatitude',
#    'property': 'epos:northernmostLatitude',
#    'required': False,
#    'type': 'float'},
#   {'label': 'Latitude (Radius Search)',
#    'maxValue': '90',
#    'minValue': '-90',
#    'name': 'latitude',
#    'required': False,
#    'type': 'float'},
#   {'defaultValue': '2016-01-01T00:00',
#    'label': 'Start Time',
#    'maxValue': '2999-01-01T00:00',
#    'minValue': '2000-05-20T00:00',
#    'name': 'starttime',
#    'property': 'schema:startDate',
#    'required': False,
#    'type': 'dateTime',
#    'valuePattern': 'YYYY-MM-DDThh:mm:ssZ'},
#   {'label': 'Maximum Radius (Radius Search)',
#    'maxValue': '180',
#    'minValue': '-180',
#    'name': 'maxradius',
#    'required': False,
#    'type': 'float'},
#   {'Enum': ['false', 'true'],
#    'defaultValue': 'false',
#    'label': 'Include All Arrivals',
#    'name': 'includearrivals',
#    'required': False,
#    'type': 'boolean'},
#   {'defaultValue': '7',
#    'label': 'Maximum Magnitude',
#    'name': 'maxmagnitude',
#    'required': False,
#    'type': 'float'},
#   {'label': 'Minimum Radius (Radius Search)',
#    'maxValue': '180',
#    'minValue': '-180',
#    'name': 'minradius',
#    'required': False,
#    'type': 'float'}],
#  'serviceProvider': {'country': 'FR',
#   'dataProviderLegalName': 'RÉSIF - Réseau sismologique & géodésique français',
#   'dataProviderUrl': 'http://seismology.resif.fr/',
#   'instanceid': 'ee47ccaa-0e16-40c8-8f41-9bc5a107f212',
#   'metaid': 'ee47ccaa-0e16-40c8-8f41-9bc5a107f212',
#   'uid': 'ee47ccaa-0e16-40c8-8f41-9bc5a107f212'},
#  'serviceSpatial': {'paths': [[[22.5, 38.0],
#     [21.35, 38.0],
#     [21.35, 38.65],
#     [22.5, 38.65],
#     [22.5, 38.0]]],
#   'wkid': 4326},
#  'serviceTemporalCoverage': {'startDate': '2000-05-20T00:00:00Z'},
#  'spatial': {'paths': [[[22.5, 38.0],
#     [21.35, 38.0],
#     [21.35, 38.65],
#     [22.5, 38.65],
#     [22.5, 38.0]]],
#   'wkid': 4326},
#  'temporalCoverage': {'startDate': '2000-05-20T00:00:00Z'},
#  'title': 'CRL Seismic Events',
#  'type': 'WEB_SERVICE',
#  'uid': 'https://www.epos-eu.org/epos-dcat-ap/NearFaultObservatory/CRL/event/Distribution/001'}

# %% [markdown]
# ## Download original data
#
# To download the original data of one of the resource is enough to use the *requests* to execute a GET request using the id of  the resource and on the original URL endpoint

# %%
import urllib.parse
response_original_url = requests.get(api_url + '/getoriginalurl/' + urllib.parse.quote(data_details['id'].encode('utf8')))
data_original_url = response_original_url.json()

# %% [markdown]
# The response is a Json Object with only one property: *url*.
# The url is where the resource is located.

# %%
data_original_url
# Out:
# {'url': 'https://nfocrl.u-strasbg.fr/fdsnws/event/1/query'}

# %% [markdown]
# Using *requests* is possible to get the information located at that URL

# %%
response_original_data = requests.get(data_original_url['url'])
original_data = response_original_data.content
original_data
# Out:
# b'Error 413: Request Entity Too Large\n\nThe result set of your request exceeds the configured maximum number of objects (100000). Refine your request parameters.\n\nUsage details are available from /fdsnws/event/1/\n\nRequest:\n/fdsnws/event/1/query\n\nRequest Submitted:\n2025-04-09T10:36:49.109998\n\nService Version:\n1.1.1\n'

# %% [markdown]
# ## Access the RI’s data - Use Case
#
# A user want to do some analysis on some Sea Level Time Series Data using the station code

# %% [markdown]
# ### Search of the data
#
# The user do the search request asking to filter on this string: "sealevel" (The string needs to be url encoded)

# %%
response_search_filtered = requests.get(api_url + "/resources/search?q=" + urllib.parse.quote('sealevel'.encode('utf8')) + "&facets=false")
filtered_data = response_search_filtered.json()
filtered_data
# Out:
# {'filters': [{'children': [{'id': 'cmVhbCB0aW1l', 'name': 'real time'},
#     {'id': 'c2VhbGV2ZWxz', 'name': 'sealevels'},
#     {'id': 'c3RhdGlvbnM=', 'name': 'stations'}],
#    'name': 'keywords'},
#   {'children': [{'id': 'b5d6522b-1f5c-4d98-99f1-d7f5141cacea',
#      'name': 'VLIZ - Vlaams Insitituut voor de Zee'}],
#    'name': 'organisations'},
#   {'children': [{'id': '9d617707-0831-4c0c-bf03-b488fd68f13f',
#      'name': 'Tsunami Data'}],
#    'name': 'sciencedomains'},
#   {'name': 'servicetypes'}],
#  'results': {'distributions': [{'availableFormats': [{'format': 'application/vnd.ogc.wms_xml',
#       'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#       'label': 'WMS',
#       'originalFormat': 'image/gif',
#       'type': 'ORIGINAL'},
#      {'format': 'application/vnd.ogc.wms_xml',
#       'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#       'label': 'WMS',
#       'originalFormat': 'image/png',
#       'type': 'ORIGINAL'},
#      {'format': 'application/vnd.ogc.wms_xml',
#       'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#       'label': 'WMS',
#       'originalFormat': 'image/vnd.jpeg-png',
#       'type': 'ORIGINAL'}],
#     'description': 'This WMS layer allows adding the the station-list into OGC compliant GIS tools. The list of dataproviders can be found on http://www.ioc-sealevelmonitoring.org',
#     'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#     'hrefExtended': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/0d596e60-d35d-4dcc-b0b0-f81d484287f1?extended=true',
#     'id': '0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#     'status': 1,
#     'statusTimestamp': '1970-01-01T12:00:00Z',
#     'title': 'IOC Sealevel Monitoring Station List (as OGC WMS layer)',
#     'uid': 'sealevels_dist_stations_wms'}]}}

# %%
num_result = len(filtered_data['results']['distributions'])
num_result
# Out:
# 1

# %% [markdown]
# It returned only one result

# %% [markdown]
# ### Get the data
#
# The user get the data of the resource from the source. Before he get from the EPOS API the url of the original resource, then he queries the service to get the actual data.
# In our case we want to select the image/png available format.

# %%
details_sealevel_result = requests.get(api_url + '/resources/details/' + filtered_data['results']['distributions'][0]['id'])
json_sealevel_result = details_sealevel_result.json()
json_sealevel_result
# Out:
# {'availableContactPoints': [{'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=99998345-4d2a-4dc1-9f29-c30aaca0fcfc&contactType=SERVICEPROVIDERS',
#    'type': 'SERVICEPROVIDERS'},
#   {'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=177d7879-33f1-4942-be08-087a0c116633&contactType=DATAPROVIDERS',
#    'type': 'DATAPROVIDERS'},
#   {'href': 'https://www.ics-c.epos-eu.org/api/v1/sender/send-email?id=0d596e60-d35d-4dcc-b0b0-f81d484287f1&contactType=ALL',
#    'type': 'ALL'}],
#  'availableFormats': [{'format': 'application/vnd.ogc.wms_xml',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#    'label': 'WMS',
#    'originalFormat': 'image/gif',
#    'type': 'ORIGINAL'},
#   {'format': 'application/vnd.ogc.wms_xml',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#    'label': 'WMS',
#    'originalFormat': 'image/png',
#    'type': 'ORIGINAL'},
#   {'format': 'application/vnd.ogc.wms_xml',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/ogcexecute/0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#    'label': 'WMS',
#    'originalFormat': 'image/vnd.jpeg-png',
#    'type': 'ORIGINAL'}],
#  'categories': {'children': [{'children': [{'ddss': 'category:tsunamidata',
#       'name': 'Tsunami Data'}],
#     'code': 'TSU',
#     'color': '#6f9ea8',
#     'id': '10',
#     'imgUrl': 'assets/img/logo/TSU_logo.png',
#     'linkUrl': 'https://www.epos-eu.org/tcs/tsunami',
#     'name': 'Tsunami'}],
#   'name': 'domains'},
#  'dataProvider': [{'country': 'BE',
#    'dataProviderLegalName': 'VLIZ - Vlaams Insitituut voor de Zee',
#    'dataProviderUrl': 'https://www.vliz.be/',
#    'instanceid': 'b5d6522b-1f5c-4d98-99f1-d7f5141cacea',
#    'metaid': 'b5d6522b-1f5c-4d98-99f1-d7f5141cacea',
#    'uid': 'b5d6522b-1f5c-4d98-99f1-d7f5141cacea'}],
#  'description': 'This WMS layer allows adding the the station-list into OGC compliant GIS tools. The list of dataproviders can be found on http://www.ioc-sealevelmonitoring.org',
#  'downloadURL': '',
#  'endpoint': 'https://geo.vliz.be/geoserver/Sealevels/ows?service=WMS&version=1.3.0&request=GetMap{&layers,width,height,srs,format}&bbox={minlatitude, minlongitude, maxlatitude, maxlongitude}',
#  'hasQualityAnnotation': 'http://www.ioc-sealevelmonitoring.org/disclaimer.php',
#  'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#  'hrefExtended': 'https://www.ics-c.epos-eu.org/api/v1/resources/details/0d596e60-d35d-4dcc-b0b0-f81d484287f1?extended=true',
#  'id': '0d596e60-d35d-4dcc-b0b0-f81d484287f1',
#  'internalID': ['WP18-DDSS-001'],
#  'keywords': ['stations', 'sealevels', 'real time'],
#  'license': 'https://creativecommons.org/licenses/by-nc/4.0',
#  'operationid': 'sealevels_wms_stations_op',
#  'scienceDomain': ['Tsunami Data'],
#  'serviceDescription': 'IOC Sealevels stations Layer via OGC WMS.',
#  'serviceDocumentation': 'https://docs.geoserver.org/main/en/user/services/index.html',
#  'serviceEndpoint': 'https://geo.vliz.be/geoserver/Sealevels/ows?service=WMS&version=1.3.0&request=GetMap',
#  'serviceName': 'IOC Sealevels stations Layer via OGC WMS.',
#  'serviceParameters': [{'defaultValue': '-69.00777938015557',
#    'label': 'Minimum Latitude',
#    'maxValue': '90.0',
#    'minValue': '-90.0',
#    'name': 'minlatitude',
#    'property': 'epos:southernmostLatitude',
#    'required': True,
#    'type': 'float'},
#   {'Enum': ['768'],
#    'defaultValue': '768',
#    'label': 'Image width',
#    'name': 'width',
#    'readOnlyValue': 'true',
#    'required': True,
#    'type': 'integer'},
#   {'defaultValue': '179.195203583904',
#    'label': 'Maximum Longitude',
#    'maxValue': '180.0',
#    'minValue': '-180.0',
#    'name': 'maxlongitude',
#    'property': 'epos:easternmostLongitude',
#    'required': True,
#    'type': 'float'},
#   {'defaultValue': '82.49000164979999',
#    'label': 'Maximum Latitude',
#    'maxValue': '90.0',
#    'minValue': '-90.0',
#    'name': 'maxlatitude',
#    'property': 'epos:northernmostLatitude',
#    'required': True,
#    'type': 'float'},
#   {'Enum': ['image/gif', 'image/png', 'image/vnd.jpeg-png'],
#    'defaultValue': 'image/png',
#    'label': 'Output format',
#    'name': 'format',
#    'property': 'schema:encodingFormat',
#    'required': False,
#    'type': 'string'},
#   {'defaultValue': '-178.1602285632045',
#    'label': 'Minimum Longitude',
#    'maxValue': '180.0',
#    'minValue': '-180.0',
#    'name': 'minlongitude',
#    'property': 'epos:westernmostLongitude',
#    'required': True,
#    'type': 'float'},
#   {'Enum': ['EPSG:4326'],
#    'defaultValue': 'EPSG:4326',
#    'label': 'Coordinate (Spatial) Reference System',
#    'name': 'srs',
#    'readOnlyValue': 'true',
#    'required': False,
#    'type': 'string'},
#   {'Enum': ['Sealevels:sealevels'],
#    'defaultValue': 'Sealevels:sealevels',
#    'label': 'Layers',
#    'name': 'layers',
#    'readOnlyValue': 'true',
#    'required': True,
#    'type': 'string'},
#   {'Enum': ['330'],
#    'defaultValue': '330',
#    'label': 'Image height',
#    'name': 'height',
#    'readOnlyValue': 'true',
#    'required': True,
#    'type': 'integer'}],
#  'serviceProvider': {'country': 'BE',
#   'dataProviderLegalName': 'VLIZ - Vlaams Insitituut voor de Zee',
#   'dataProviderUrl': 'https://www.vliz.be/',
#   'instanceid': 'b5d6522b-1f5c-4d98-99f1-d7f5141cacea',
#   'metaid': 'b5d6522b-1f5c-4d98-99f1-d7f5141cacea',
#   'uid': 'b5d6522b-1f5c-4d98-99f1-d7f5141cacea'},
#  'serviceTemporalCoverage': {},
#  'spatial': {'paths': [[[-178.1602285632045, -69.00777938015557],
#     [-178.1602285632045, 82.49000164979999],
#     [179.195203583904, 82.49000164979999],
#     [179.195203583904, -69.00777938015557],
#     [-178.1602285632045, -69.00777938015557]]],
#   'wkid': 4326},
#  'temporalCoverage': {'startDate': '2006-01-01T00:00:00Z'},
#  'title': 'IOC Sealevel Monitoring Station List (as OGC WMS layer)',
#  'type': 'WEB_SERVICE',
#  'uid': 'sealevels_dist_stations_wms'}

# %%
for available_format in json_sealevel_result['availableFormats']:
    if available_format['originalFormat'] == 'image/png':
            base_url = available_format['href']
#base_url = json_sealevel_result['serviceEndpoint'].split('?')[0]

# %%
service_parameters = json_sealevel_result['serviceParameters']

for parameter in service_parameters:
    if parameter['name'] == 'layers':
        layer = parameter['defaultValue']
    if 'property' in parameter:
        if parameter['property'] == 'epos:easternmostLongitude':
            maxlong = parameter['defaultValue']
        if parameter['property'] == 'epos:southernmostLatitude':
            minlat = parameter['defaultValue']
        if parameter['property'] == 'epos:northernmostLatitude':
            maxlat = parameter['defaultValue']
        if parameter['property'] == 'epos:westernmostLongitude':
            minlong = parameter['defaultValue']

# %% [markdown]
# ### Visualize the data
#
# Then he decide to visualize the waves using owslib library.

# %%
from owslib.wms import WebMapService

wms = WebMapService(base_url, version="1.3.0")

print(f'WMS title: {wms.identification.title}')

print(f'WMS abstract: {wms.identification.abstract}')

print(f'Provider name: {wms.provider.name}')

print(f'Provider address: {wms.provider.contact.address}')
# Out:
# WMS title: Flanders Marine Institute (VLIZ) - Geoserver WMS Service
# WMS abstract: A compliant implementation of OGC WMS.
# Provider name: VLIZ
# Provider address: None

# %%
img = wms.getmap(
    layers=[layer],
    size=[768, 330],
    srs="EPSG:4326",
    bbox=[minlong, minlat, maxlong, maxlat],
    format="image/png")

save_fp = 'wms.png'
with open(save_fp, 'wb') as out:
	out.write(img.read())

# %%
from IPython.display import Image
Image(filename=save_fp)

# %%
from owslib.wfs import WebFeatureService

wfs = WebFeatureService(base_url, version='2.0.0')
print(f'WFS title: {wfs.identification.title}')

print(f'WFS abstract: {wfs.identification.abstract}')

print(f'Provider name: {wfs.provider.name}')

print(f'Provider address: {wfs.provider.contact.address}')
# Out:
# WFS title: Flanders Marine Institute (VLIZ) - WFS Service
# WFS abstract: This is the reference implementation of OGC WFS 1.0.0 and WFS 1.1.0, supports all WFS operations including Transaction.
# Provider name: VLIZ
# Provider address: None

# %%
list(wfs.contents)
# Out:
# ['Sealevels:sealevels']

# %%
response = wfs.getfeature(typename=layer, bbox=(minlong, minlat, maxlong, maxlat), outputFormat='json')
with open('sea_level_wfs.json', 'w', encoding='UTF-8') as out:
	out.write(str(response.read(), 'UTF-8'))

# %%
import json

with open('sea_level_wfs.json') as f:
    d = json.load(f)

# %%
import geopandas

df = geopandas.read_file("sea_level_wfs.json")

# %%
df
# Out:
#                                            id   code   latitude   longitude  \
# 0     sealevels.fid-4001cb13_1961a0c295e_4b65   abas  44.020000  144.290000
# 1     sealevels.fid-4001cb13_1961a0c295e_4b66   abed  57.140000   -2.080000
# 2     sealevels.fid-4001cb13_1961a0c295e_4b67   abur  31.580000  131.410000
# 3     sealevels.fid-4001cb13_1961a0c295e_4b68   acaj  13.573792  -89.838128
# 4     sealevels.fid-4001cb13_1961a0c295e_4b69   acap  16.833300  -99.916600
# ...                                       ...    ...        ...         ...
# 1644  sealevels.fid-4001cb13_1961a0c295e_51d1   zkth  37.781420   20.905200
# 1645  sealevels.fid-4001cb13_1961a0c295e_51d2   zldw  51.346389    3.200278
# 1646  sealevels.fid-4001cb13_1961a0c295e_51d3   zwdw  51.355278    3.178056
# 1647  sealevels.fid-4001cb13_1961a0c295e_51d4   zygi  34.727083   33.338375
# 1648  sealevels.fid-4001cb13_1961a0c295e_51d5  zygi1  34.726315   33.340228
#
#                        Location country type  XMtInt GlossID       status  \
# 0                      Abashiri     JAP   SL    10.0     327  operational
# 1                      Aberdeen     GRB   SF    15.0    None  operational
# 2                      Aburatsu     JAP   SL    10.0      82  operational
# 3                   Acajutla_SV     SVD   SL     5.0     182  operational
# 4                   Acapulco_MX     MEX   SL     5.0     267         down
# ...                         ...     ...  ...     ...     ...          ...
# 1644  Zakynthos, Ionian Islands     HEL   SB     1.0    None  operational
# 1645   Zeebrugge Leopold II dam     BEL   SW     5.0    None  operational
# 1646     Zeebrugge Wielingendok     BEL   SW     5.0    None  operational
# 1647                      Zygi      CYP   SF     1.0    None         down
# 1648                       Zygi     CYP   SB     1.0    None  operational
#
#                          date_created  \
# 0    2012-03-21 09:54:59.357000+00:00
# 1    2012-09-04 21:04:28.220000+00:00
# 2    2012-03-21 10:09:41.317000+00:00
# 3           2008-06-20 12:17:00+00:00
# 4           2008-04-28 12:36:00+00:00
# ...                               ...
# 1644 2023-09-29 06:31:39.240000+00:00
# 1645 2023-10-05 17:30:00.580000+00:00
# 1646 2023-10-05 17:31:48.323000+00:00
# 1647 2011-09-07 14:55:04.817000+00:00
# 1648 2018-03-16 05:24:01.080000+00:00
#
#                                             stationlink  \
# 0     http://www.ioc-sealevelmonitoring.org/station....
# 1     http://www.ioc-sealevelmonitoring.org/station....
# 2     http://www.ioc-sealevelmonitoring.org/station....
# 3     http://www.ioc-sealevelmonitoring.org/station....
# 4     http://www.ioc-sealevelmonitoring.org/station....
# ...                                                 ...
# 1644  http://www.ioc-sealevelmonitoring.org/station....
# 1645  http://www.ioc-sealevelmonitoring.org/station....
# 1646  http://www.ioc-sealevelmonitoring.org/station....
# 1647  http://www.ioc-sealevelmonitoring.org/station....
# 1648  http://www.ioc-sealevelmonitoring.org/station....
#
#                                                datalink  \
# 0     http://www.ioc-sealevelmonitoring.org/station....
# 1     http://www.ioc-sealevelmonitoring.org/station....
# 2     http://www.ioc-sealevelmonitoring.org/station....
# 3     http://www.ioc-sealevelmonitoring.org/station....
# 4     http://www.ioc-sealevelmonitoring.org/station....
# ...                                                 ...
# 1644  http://www.ioc-sealevelmonitoring.org/station....
# 1645  http://www.ioc-sealevelmonitoring.org/station....
# 1646  http://www.ioc-sealevelmonitoring.org/station....
# 1647  http://www.ioc-sealevelmonitoring.org/station....
# 1648  http://www.ioc-sealevelmonitoring.org/station....
#
#                                            downloadlink  \
# 0     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 2     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 3     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 4     http://www.ioc-sealevelmonitoring.org/bgraph.p...
# ...                                                 ...
# 1644  http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1645  http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1646  http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1647  http://www.ioc-sealevelmonitoring.org/bgraph.p...
# 1648  http://www.ioc-sealevelmonitoring.org/bgraph.p...
#
#                         geometry
# 0           POINT (144.29 44.02)
# 1            POINT (-2.08 57.14)
# 2           POINT (131.41 31.58)
# 3     POINT (-89.83813 13.57379)
# 4       POINT (-99.9166 16.8333)
# ...                          ...
# 1644    POINT (20.9052 37.78142)
# 1645    POINT (3.20028 51.34639)
# 1646    POINT (3.17806 51.35528)
# 1647   POINT (33.33838 34.72708)
# 1648   POINT (33.34023 34.72632)
#
# [1649 rows x 15 columns]
